# %%
# Run this on the same docker environment, just to confirm if it really
# is this slowww ... and yep, it's this slow!
# Run Date: Wednesday, February 08, 2023
# Run Time: 00:50:06

# So this run absolutely DID use the GPU and it was slower! What the hell am I missing here?
# Run Date: Wednesday, February 08, 2023
# Run Time: 00:50:58


# Dammit! This is NOT using the GPU! ... 

# CPU run time ... slow, right!?
# Run Date: Wednesday, February 08, 2023
# Run Time: 00:36:29

# %%
import time
from datetime import date

startTime = time.time()
todaysDate = date.today()

# %% [markdown]
# **Chapter 11 – Training Deep Neural Networks**

# %% [markdown]
# _This notebook contains all the sample code and solutions to the exercises in chapter 11._

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/ageron/handson-ml3/blob/main/11_training_deep_neural_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/ageron/handson-ml3/blob/main/11_training_deep_neural_networks.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# # Setup

# %% [markdown]
# This project requires Python 3.7 or above:

# %%
import sys

assert sys.version_info >= (3, 7)

# %% [markdown]
# And TensorFlow ≥ 2.8:

# %%
from packaging import version
import tensorflow as tf

assert version.parse(tf.__version__) >= version.parse("2.8.0")
# Out:
# 2023-02-08 19:30:02.207821: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-08 19:30:02.566848: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# As we did in previous chapters, let's define the default font sizes to make the figures prettier:

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# And let's create the `images/deep` folder (if it doesn't already exist), and define the `save_fig()` function which is used through this notebook to save the figures in high-res for the book:

# %%
from pathlib import Path

IMAGES_PATH = Path() / "images" / "deep"
IMAGES_PATH.mkdir(parents=True, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# # Vanishing/Exploding Gradients Problem

# %%
# extra code – this cell generates and saves Figure 11–1

import numpy as np

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

z = np.linspace(-5, 5, 200)

plt.plot([-5, 5], [0, 0], 'k-')
plt.plot([-5, 5], [1, 1], 'k--')
plt.plot([0, 0], [-0.2, 1.2], 'k-')
plt.plot([-5, 5], [-3/4, 7/4], 'g--')
plt.plot(z, sigmoid(z), "b-", linewidth=2,
         label=r"$\sigma(z) = \dfrac{1}{1+e^{-z}}$")
props = dict(facecolor='black', shrink=0.1)
plt.annotate('Saturating', xytext=(3.5, 0.7), xy=(5, 1), arrowprops=props,
             fontsize=14, ha="center")
plt.annotate('Saturating', xytext=(-3.5, 0.3), xy=(-5, 0), arrowprops=props,
             fontsize=14, ha="center")
plt.annotate('Linear', xytext=(2, 0.2), xy=(0, 0.5), arrowprops=props,
             fontsize=14, ha="center")
plt.grid(True)
plt.axis([-5, 5, -0.2, 1.2])
plt.xlabel("$z$")
plt.legend(loc="upper left", fontsize=16)

save_fig("sigmoid_saturation_plot")
plt.show()

# %% [markdown]
# ## Xavier and He Initialization

# %%
dense = tf.keras.layers.Dense(50, activation="relu",
                              kernel_initializer="he_normal")

# %%
he_avg_init = tf.keras.initializers.VarianceScaling(scale=2., mode="fan_avg",
                                                    distribution="uniform")
dense = tf.keras.layers.Dense(50, activation="sigmoid",
                              kernel_initializer=he_avg_init)

# %% [markdown]
# ## Nonsaturating Activation Functions

# %% [markdown]
# ### Leaky ReLU

# %%
# extra code – this cell generates and saves Figure 11–2

def leaky_relu(z, alpha):
    return np.maximum(alpha * z, z)

z = np.linspace(-5, 5, 200)
plt.plot(z, leaky_relu(z, 0.1), "b-", linewidth=2, label=r"$LeakyReLU(z) = max(\alpha z, z)$")
plt.plot([-5, 5], [0, 0], 'k-')
plt.plot([0, 0], [-1, 3.7], 'k-')
plt.grid(True)
props = dict(facecolor='black', shrink=0.1)
plt.annotate('Leak', xytext=(-3.5, 0.5), xy=(-5, -0.3), arrowprops=props,
             fontsize=14, ha="center")
plt.xlabel("$z$")
plt.axis([-5, 5, -1, 3.7])
plt.gca().set_aspect("equal")
plt.legend()

save_fig("leaky_relu_plot")
plt.show()

# %%
leaky_relu = tf.keras.layers.LeakyReLU(alpha=0.2)  # defaults to alpha=0.3
dense = tf.keras.layers.Dense(50, activation=leaky_relu,
                              kernel_initializer="he_normal")

# %%
model = tf.keras.models.Sequential([
    # [...]  # more layers
    tf.keras.layers.Dense(50, kernel_initializer="he_normal"),  # no activation
    tf.keras.layers.LeakyReLU(alpha=0.2),  # activation as a separate layer
    # [...]  # more layers
])
# Out:
# 2023-02-08 19:30:05.564525: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-08 19:30:05.564716: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-08 19:30:05.574947: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-08 19:30:05.575102: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-08 19:30:05.575236: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-08 19:30:05.575419: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-08 19:30:05.575531: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2006] Ignoring visible gpu device (device: 1, name: NVIDIA GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1) with core count: 5. The minimum required count is 8. You can adjust this requirement with the env var TF_MIN_GPU_MULTIPROCESSOR_COUNT.
# 2023-02-08 19:30:05.576402: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-08 19:30:05.577028: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-08 19:30:05.577177: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-08 19:30:05.577307: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-08 19:30:06.275631: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-08 19:30:06.276160: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-08 19:30:06.276293: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-08 19:30:06.276412: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6649 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:02:00.0, compute capability: 7.5

# %% [markdown]
# ### ELU

# %% [markdown]
# Implementing ELU in TensorFlow is trivial, just specify the activation function when building each layer, and use He initialization:

# %%
dense = tf.keras.layers.Dense(50, activation="elu",
                              kernel_initializer="he_normal")

# %% [markdown]
# ### SELU

# %% [markdown]
# By default, the SELU hyperparameters (`scale` and `alpha`) are tuned in such a way that the mean output of each neuron remains close to 0, and the standard deviation remains close to 1 (assuming the inputs are standardized with mean 0 and standard deviation 1 too, and other constraints are respected, as explained in the book). Using this activation function, even a 1,000 layer deep neural network preserves roughly mean 0 and standard deviation 1 across all layers, avoiding the exploding/vanishing gradients problem:

# %%
# extra code – this cell generates and saves Figure 11–3

from scipy.special import erfc

# alpha and scale to self normalize with mean 0 and standard deviation 1
# (see equation 14 in the paper):
alpha_0_1 = -np.sqrt(2 / np.pi) / (erfc(1 / np.sqrt(2)) * np.exp(1 / 2) - 1)
scale_0_1 = (
    (1 - erfc(1 / np.sqrt(2)) * np.sqrt(np.e))
    * np.sqrt(2 * np.pi)
    * (
        2 * erfc(np.sqrt(2)) * np.e ** 2
        + np.pi * erfc(1 / np.sqrt(2)) ** 2 * np.e
        - 2 * (2 + np.pi) * erfc(1 / np.sqrt(2)) * np.sqrt(np.e)
        + np.pi
        + 2
    ) ** (-1 / 2)
)

def elu(z, alpha=1):
    return np.where(z < 0, alpha * (np.exp(z) - 1), z)

def selu(z, scale=scale_0_1, alpha=alpha_0_1):
    return scale * elu(z, alpha)

z = np.linspace(-5, 5, 200)
plt.plot(z, elu(z), "b-", linewidth=2, label=r"ELU$_\alpha(z) = \alpha (e^z - 1)$ if $z < 0$, else $z$")
plt.plot(z, selu(z), "r--", linewidth=2, label=r"SELU$(z) = 1.05 \, $ELU$_{1.67}(z)$")
plt.plot([-5, 5], [0, 0], 'k-')
plt.plot([-5, 5], [-1, -1], 'k:', linewidth=2)
plt.plot([-5, 5], [-1.758, -1.758], 'k:', linewidth=2)
plt.plot([0, 0], [-2.2, 3.2], 'k-')
plt.grid(True)
plt.axis([-5, 5, -2.2, 3.2])
plt.xlabel("$z$")
plt.gca().set_aspect("equal")
plt.legend()

save_fig("elu_selu_plot")
plt.show()

# %% [markdown]
# Using SELU is straightforward:

# %%
dense = tf.keras.layers.Dense(50, activation="selu",
                              kernel_initializer="lecun_normal")

# %% [markdown]
# **Extra material – an example of a self-regularized network using SELU**
#
# Let's create a neural net for Fashion MNIST with 100 hidden layers, using the SELU activation function:

# %%
tf.random.set_seed(42)
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[28, 28]))
for layer in range(100):
    model.add(tf.keras.layers.Dense(100, activation="selu",
                                    kernel_initializer="lecun_normal"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              metrics=["accuracy"])

# %% [markdown]
# Now let's train it. Do not forget to scale the inputs to mean 0 and standard deviation 1:

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]
X_train, X_valid, X_test = X_train / 255, X_valid / 255, X_test / 255

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
pixel_means = X_train.mean(axis=0, keepdims=True)
pixel_stds = X_train.std(axis=0, keepdims=True)
X_train_scaled = (X_train - pixel_means) / pixel_stds
X_valid_scaled = (X_valid - pixel_means) / pixel_stds
X_test_scaled = (X_test - pixel_means) / pixel_stds

# %%
history = model.fit(X_train_scaled, y_train, epochs=5,
                    validation_data=(X_valid_scaled, y_valid))
# Out:
# Epoch 1/5
# 1719/1719 [==============================] - 15s 7ms/step - loss: 1.4293 - accuracy: 0.4375 - val_loss: 0.9775 - val_accuracy: 0.6294
# Epoch 2/5
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.8030 - accuracy: 0.6939 - val_loss: 0.6742 - val_accuracy: 0.7496
# Epoch 3/5
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.6535 - accuracy: 0.7591 - val_loss: 0.8453 - val_accuracy: 0.7028
# Epoch 4/5
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.5872 - accuracy: 0.7887 - val_loss: 0.5816 - val_accuracy: 0.7928
# Epoch 5/5
# 1719/1719 [==============================] - 11s 7ms/step - loss: 0.5325 - accuracy: 0.8133 - val_loss: 0.5197 - val_accuracy: 0.8184

# %% [markdown]
# The network managed to learn, despite how deep it is. Now look at what happens if we try to use the ReLU activation function instead:

# %%
tf.random.set_seed(42)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[28, 28]))
for layer in range(100):
    model.add(tf.keras.layers.Dense(100, activation="relu",
                                    kernel_initializer="he_normal"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              metrics=["accuracy"])

# %%
history = model.fit(X_train_scaled, y_train, epochs=5,
                    validation_data=(X_valid_scaled, y_valid))
# Out:
# Epoch 1/5
# 1719/1719 [==============================] - 14s 7ms/step - loss: 1.8449 - accuracy: 0.2625 - val_loss: 1.4279 - val_accuracy: 0.3760
# Epoch 2/5
# 1719/1719 [==============================] - 12s 7ms/step - loss: 1.2436 - accuracy: 0.4541 - val_loss: 1.1022 - val_accuracy: 0.5144
# Epoch 3/5
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.9748 - accuracy: 0.5990 - val_loss: 0.9945 - val_accuracy: 0.5842
# Epoch 4/5
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.9550 - accuracy: 0.6045 - val_loss: 0.8230 - val_accuracy: 0.6852
# Epoch 5/5
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.8778 - accuracy: 0.6464 - val_loss: 0.7999 - val_accuracy: 0.6956

# %% [markdown]
# Not great at all, we suffered from the vanishing/exploding gradients problem.

# %% [markdown]
# ### GELU, Swish and Mish

# %%
# extra code – this cell generates and saves Figure 11–4

def swish(z, beta=1):
    return z * sigmoid(beta * z)

def approx_gelu(z):
    return swish(z, beta=1.702)

def softplus(z):
    return np.log(1 + np.exp(z))

def mish(z):
    return z * np.tanh(softplus(z))

z = np.linspace(-4, 2, 200)

beta = 0.6
plt.plot(z, approx_gelu(z), "b-", linewidth=2,
         label=r"GELU$(z) = z\,\Phi(z)$")
plt.plot(z, swish(z), "r--", linewidth=2,
         label=r"Swish$(z) = z\,\sigma(z)$")
plt.plot(z, swish(z, beta), "r:", linewidth=2,
         label=fr"Swish$_{{\beta={beta}}}(z)=z\,\sigma({beta}\,z)$")
plt.plot(z, mish(z), "g:", linewidth=3,
         label=fr"Mish$(z) = z\,\tanh($softplus$(z))$")
plt.plot([-4, 2], [0, 0], 'k-')
plt.plot([0, 0], [-2.2, 3.2], 'k-')
plt.grid(True)
plt.axis([-4, 2, -1, 2])
plt.gca().set_aspect("equal")
plt.xlabel("$z$")
plt.legend(loc="upper left")

save_fig("gelu_swish_mish_plot")
plt.show()

# %% [markdown]
# # Batch Normalization

# %%
# extra code - clear the name counters and set the random seed
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(300, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  batch_normalization (BatchN  (None, 784)              3136
#  ormalization)
#
#  dense (Dense)               (None, 300)               235500
#
#  batch_normalization_1 (Batc  (None, 300)              1200
#  hNormalization)
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  batch_normalization_2 (Batc  (None, 100)              400
#  hNormalization)
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 271,346
# Trainable params: 268,978
# Non-trainable params: 2,368
# _________________________________________________________________

# %%
[(var.name, var.trainable) for var in model.layers[1].variables]
# Out:
# [('batch_normalization/gamma:0', True),
#  ('batch_normalization/beta:0', True),
#  ('batch_normalization/moving_mean:0', False),
#  ('batch_normalization/moving_variance:0', False)]

# %%
# extra code – just show that the model works! 😊
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd",
              metrics="accuracy")
model.fit(X_train, y_train, epochs=2, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/2
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.5541 - accuracy: 0.8062 - val_loss: 0.4005 - val_accuracy: 0.8544
# Epoch 2/2
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.4036 - accuracy: 0.8563 - val_loss: 0.3635 - val_accuracy: 0.8674

# %% [markdown]
# Sometimes applying BN before the activation function works better (there's a debate on this topic). Moreover, the layer before a `BatchNormalization` layer does not need to have bias terms, since the `BatchNormalization` layer some as well, it would be a waste of parameters, so you can set `use_bias=False` when creating those layers:

# %%
# extra code - clear the name counters and set the random seed
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(300, kernel_initializer="he_normal", use_bias=False),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.Dense(100, kernel_initializer="he_normal", use_bias=False),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
# extra code – just show that the model works! 😊
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd",
              metrics="accuracy")
model.fit(X_train, y_train, epochs=2, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/2
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.6119 - accuracy: 0.7956 - val_loss: 0.4264 - val_accuracy: 0.8458
# Epoch 2/2
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.4303 - accuracy: 0.8506 - val_loss: 0.3733 - val_accuracy: 0.8658

# %% [markdown]
# ## Gradient Clipping

# %% [markdown]
# All `tf.keras.optimizers` accept `clipnorm` or `clipvalue` arguments:

# %%
optimizer = tf.keras.optimizers.SGD(clipvalue=1.0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer)

# %%
optimizer = tf.keras.optimizers.SGD(clipnorm=1.0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer)

# %% [markdown]
# ## Reusing Pretrained Layers

# %% [markdown]
# ### Reusing a Keras model

# %% [markdown]
# Let's split the fashion MNIST training set in two:
# * `X_train_A`: all images of all items except for T-shirts/tops and pullovers (classes 0 and 2).
# * `X_train_B`: a much smaller training set of just the first 200 images of T-shirts/tops and pullovers.
#
# The validation set and the test set are also split this way, but without restricting the number of images.
#
# We will train a model on set A (classification task with 8 classes), and try to reuse it to tackle set B (binary classification). We hope to transfer a little bit of knowledge from task A to task B, since classes in set A (trousers, dresses, coats, sandals, shirts, sneakers, bags, and ankle boots) are somewhat similar to classes in set B (T-shirts/tops and pullovers). However, since we are using `Dense` layers, only patterns that occur at the same location can be reused (in contrast, convolutional layers will transfer much better, since learned patterns can be detected anywhere on the image, as we will see in the chapter 14).

# %%
# extra code – split Fashion MNIST into tasks A and B, then train and save
#              model A to "my_model_A".

pos_class_id = class_names.index("Pullover")
neg_class_id = class_names.index("T-shirt/top")

def split_dataset(X, y):
    y_for_B = (y == pos_class_id) | (y == neg_class_id)
    y_A = y[~y_for_B]
    y_B = (y[y_for_B] == pos_class_id).astype(np.float32)
    old_class_ids = list(set(range(10)) - set([neg_class_id, pos_class_id]))
    for old_class_id, new_class_id in zip(old_class_ids, range(8)):
        y_A[y_A == old_class_id] = new_class_id  # reorder class ids for A
    return ((X[~y_for_B], y_A), (X[y_for_B], y_B))

(X_train_A, y_train_A), (X_train_B, y_train_B) = split_dataset(X_train, y_train)
(X_valid_A, y_valid_A), (X_valid_B, y_valid_B) = split_dataset(X_valid, y_valid)
(X_test_A, y_test_A), (X_test_B, y_test_B) = split_dataset(X_test, y_test)
X_train_B = X_train_B[:200]
y_train_B = y_train_B[:200]

tf.random.set_seed(42)

model_A = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(8, activation="softmax")
])

model_A.compile(loss="sparse_categorical_crossentropy",
                optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
                metrics=["accuracy"])
history = model_A.fit(X_train_A, y_train_A, epochs=20,
                      validation_data=(X_valid_A, y_valid_A))
model_A.save("my_model_A")
# Out:
# Epoch 1/20
# 1376/1376 [==============================] - 2s 2ms/step - loss: 1.0762 - accuracy: 0.6632 - val_loss: 0.6511 - val_accuracy: 0.7887
# Epoch 2/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.5713 - accuracy: 0.8157 - val_loss: 0.4912 - val_accuracy: 0.8431
# Epoch 3/20
# 1376/1376 [==============================] - 2s 2ms/step - loss: 0.4669 - accuracy: 0.8514 - val_loss: 0.4238 - val_accuracy: 0.8614
# Epoch 4/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.4115 - accuracy: 0.8685 - val_loss: 0.3836 - val_accuracy: 0.8716
# Epoch 5/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.3759 - accuracy: 0.8788 - val_loss: 0.3579 - val_accuracy: 0.8777
# Epoch 6/20
# 1376/1376 [==============================] - 2s 2ms/step - loss: 0.3512 - accuracy: 0.8831 - val_loss: 0.3383 - val_accuracy: 0.8812
# Epoch 7/20
# 1376/1376 [==============================] - 2s 2ms/step - loss: 0.3334 - accuracy: 0.8883 - val_loss: 0.3263 - val_accuracy: 0.8852
# Epoch 8/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.3190 - accuracy: 0.8909 - val_loss: 0.3202 - val_accuracy: 0.8879
# Epoch 9/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.3081 - accuracy: 0.8945 - val_loss: 0.3069 - val_accuracy: 0.8897
# Epoch 10/20
# 1376/1376 [==============================] - 2s 2ms/step - loss: 0.2985 - accuracy: 0.8968 - val_loss: 0.3028 - val_accuracy: 0.8927
# Epoch 11/20
# 1376/1376 [==============================] - 2s 2ms/step - loss: 0.2903 - accuracy: 0.9003 - val_loss: 0.2963 - val_accuracy: 0.8962
# Epoch 12/20
# 1376/1376 [==============================] - 2s 2ms/step - loss: 0.2837 - accuracy: 0.9021 - val_loss: 0.2965 - val_accuracy: 0.8982
# Epoch 13/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.2784 - accuracy: 0.9037 - val_loss: 0.2865 - val_accuracy: 0.8992
# Epoch 14/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.2727 - accuracy: 0.9050 - val_loss: 0.2811 - val_accuracy: 0.8972
# Epoch 15/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.2683 - accuracy: 0.9068 - val_loss: 0.2777 - val_accuracy: 0.9037
# Epoch 16/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.2639 - accuracy: 0.9081 - val_loss: 0.2757 - val_accuracy: 0.9032
# Epoch 17/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.2599 - accuracy: 0.9094 - val_loss: 0.2709 - val_accuracy: 0.9052
# Epoch 18/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.2557 - accuracy: 0.9108 - val_loss: 0.2697 - val_accuracy: 0.9052
# Epoch 19/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.2525 - accuracy: 0.9123 - val_loss: 0.2688 - val_accuracy: 0.9080
# Epoch 20/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.2491 - accuracy: 0.9129 - val_loss: 0.2707 - val_accuracy: 0.9087
# INFO:tensorflow:Assets written to: my_model_A/assets

# %%
# extra code – train and evaluate model B, without reusing model A

tf.random.set_seed(42)
model_B = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

model_B.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
                metrics=["accuracy"])
history = model_B.fit(X_train_B, y_train_B, epochs=20,
                      validation_data=(X_valid_B, y_valid_B))
model_B.evaluate(X_test_B, y_test_B)
# Out:
# Epoch 1/20
# 7/7 [==============================] - 0s 26ms/step - loss: 0.8407 - accuracy: 0.4450 - val_loss: 0.7699 - val_accuracy: 0.4847
# Epoch 2/20
# 7/7 [==============================] - 0s 9ms/step - loss: 0.7644 - accuracy: 0.4450 - val_loss: 0.7114 - val_accuracy: 0.4847
# Epoch 3/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.7073 - accuracy: 0.4450 - val_loss: 0.6630 - val_accuracy: 0.4857
# Epoch 4/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6584 - accuracy: 0.4500 - val_loss: 0.6315 - val_accuracy: 0.4906
# Epoch 5/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6260 - accuracy: 0.4850 - val_loss: 0.6056 - val_accuracy: 0.5480
# Epoch 6/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5991 - accuracy: 0.6350 - val_loss: 0.5852 - val_accuracy: 0.7003
# Epoch 7/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5775 - accuracy: 0.7700 - val_loss: 0.5694 - val_accuracy: 0.7705
# Epoch 8/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5613 - accuracy: 0.8200 - val_loss: 0.5546 - val_accuracy: 0.8210
# Epoch 9/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5454 - accuracy: 0.8800 - val_loss: 0.5407 - val_accuracy: 0.8516
# Epoch 10/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5304 - accuracy: 0.8950 - val_loss: 0.5269 - val_accuracy: 0.8813
# Epoch 11/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5159 - accuracy: 0.9100 - val_loss: 0.5149 - val_accuracy: 0.8902
# Epoch 12/20
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5029 - accuracy: 0.9150 - val_loss: 0.5035 - val_accuracy: 0.9001
# Epoch 13/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4907 - accuracy: 0.9350 - val_loss: 0.4933 - val_accuracy: 0.9110
# Epoch 14/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4797 - accuracy: 0.9450 - val_loss: 0.4834 - val_accuracy: 0.9189
# Epoch 15/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4693 - accuracy: 0.9500 - val_loss: 0.4738 - val_accuracy: 0.9209
# Epoch 16/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4591 - accuracy: 0.9500 - val_loss: 0.4644 - val_accuracy: 0.9238
# Epoch 17/20
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4493 - accuracy: 0.9500 - val_loss: 0.4555 - val_accuracy: 0.9278
# Epoch 18/20
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4400 - accuracy: 0.9550 - val_loss: 0.4463 - val_accuracy: 0.9268
# Epoch 19/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4304 - accuracy: 0.9500 - val_loss: 0.4377 - val_accuracy: 0.9298
# Epoch 20/20
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4218 - accuracy: 0.9500 - val_loss: 0.4301 - val_accuracy: 0.9308
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4348 - accuracy: 0.9320
# [0.4347813129425049, 0.9319999814033508]

# %% [markdown]
# Model B reaches 91.85% accuracy on the test set. Now let's try reusing the pretrained model A.

# %%
model_A = tf.keras.models.load_model("my_model_A")
model_B_on_A = tf.keras.Sequential(model_A.layers[:-1])
model_B_on_A.add(tf.keras.layers.Dense(1, activation="sigmoid"))

# %% [markdown]
# Note that `model_B_on_A` and `model_A` actually share layers now, so when we train one, it will update both models. If we want to avoid that, we need to build `model_B_on_A` on top of a *clone* of `model_A`:

# %%
tf.random.set_seed(42)  # extra code – ensure reproducibility

# %%
model_A_clone = tf.keras.models.clone_model(model_A)
model_A_clone.set_weights(model_A.get_weights())

# %%
# extra code – creating model_B_on_A just like in the previous cell
model_B_on_A = tf.keras.Sequential(model_A_clone.layers[:-1])
model_B_on_A.add(tf.keras.layers.Dense(1, activation="sigmoid"))

# %%
for layer in model_B_on_A.layers[:-1]:
    layer.trainable = False

optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model_B_on_A.compile(loss="binary_crossentropy", optimizer=optimizer,
                     metrics=["accuracy"])

# %%
history = model_B_on_A.fit(X_train_B, y_train_B, epochs=4,
                           validation_data=(X_valid_B, y_valid_B))

for layer in model_B_on_A.layers[:-1]:
    layer.trainable = True

optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model_B_on_A.compile(loss="binary_crossentropy", optimizer=optimizer,
                     metrics=["accuracy"])
history = model_B_on_A.fit(X_train_B, y_train_B, epochs=16,
                           validation_data=(X_valid_B, y_valid_B))
# Out:
# Epoch 1/4
# 7/7 [==============================] - 0s 25ms/step - loss: 2.0766 - accuracy: 0.4450 - val_loss: 1.4129 - val_accuracy: 0.4817
# Epoch 2/4
# 7/7 [==============================] - 0s 10ms/step - loss: 1.3041 - accuracy: 0.4150 - val_loss: 1.0145 - val_accuracy: 0.3551
# Epoch 3/4
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0230 - accuracy: 0.2350 - val_loss: 0.9366 - val_accuracy: 0.1771
# Epoch 4/4
# 7/7 [==============================] - 0s 9ms/step - loss: 0.9490 - accuracy: 0.1850 - val_loss: 0.9200 - val_accuracy: 0.2087
# Epoch 1/16
# 7/7 [==============================] - 0s 25ms/step - loss: 0.8914 - accuracy: 0.2400 - val_loss: 0.8165 - val_accuracy: 0.3452
# Epoch 2/16
# 7/7 [==============================] - 0s 10ms/step - loss: 0.7947 - accuracy: 0.3450 - val_loss: 0.7231 - val_accuracy: 0.4807
# Epoch 3/16
# 7/7 [==============================] - 0s 10ms/step - loss: 0.7021 - accuracy: 0.4900 - val_loss: 0.6707 - val_accuracy: 0.5529
# Epoch 4/16
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6201 - accuracy: 0.6800 - val_loss: 0.5982 - val_accuracy: 0.7270
# Epoch 5/16
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5658 - accuracy: 0.7900 - val_loss: 0.5482 - val_accuracy: 0.8348
# Epoch 6/16
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5137 - accuracy: 0.8700 - val_loss: 0.5090 - val_accuracy: 0.8704
# Epoch 7/16
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4697 - accuracy: 0.9350 - val_loss: 0.4837 - val_accuracy: 0.8704
# Epoch 8/16
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4478 - accuracy: 0.9200 - val_loss: 0.4513 - val_accuracy: 0.9031
# Epoch 9/16
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4112 - accuracy: 0.9500 - val_loss: 0.4278 - val_accuracy: 0.9090
# Epoch 10/16
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3874 - accuracy: 0.9450 - val_loss: 0.4087 - val_accuracy: 0.9120
# Epoch 11/16
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3668 - accuracy: 0.9600 - val_loss: 0.3903 - val_accuracy: 0.9149
# Epoch 12/16
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3476 - accuracy: 0.9550 - val_loss: 0.3749 - val_accuracy: 0.9219
# Epoch 13/16
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3300 - accuracy: 0.9600 - val_loss: 0.3644 - val_accuracy: 0.9248
# Epoch 14/16
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3174 - accuracy: 0.9600 - val_loss: 0.3493 - val_accuracy: 0.9288
# Epoch 15/16
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3041 - accuracy: 0.9650 - val_loss: 0.3368 - val_accuracy: 0.9258
# Epoch 16/16
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2913 - accuracy: 0.9650 - val_loss: 0.3286 - val_accuracy: 0.9308

# %% [markdown]
# So, what's the final verdict?

# %%
model_B_on_A.evaluate(X_test_B, y_test_B)
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3418 - accuracy: 0.9190
# [0.3418193757534027, 0.9190000295639038]

# %% [markdown]
# Great! We got a bit of transfer: the model's accuracy went up 2 percentage points, from 91.85% to 93.85%. This means the error rate dropped by almost 25%:

# %%
1 - (100 - 93.85) / (100 - 91.85)
# Out:
# 0.24539877300613477

# %% [markdown]
# # Faster Optimizers

# %%
# extra code – a little function to test an optimizer on Fashion MNIST

def build_model(seed=42):
    tf.random.set_seed(seed)
    return tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=[28, 28]),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(10, activation="softmax")
    ])

def build_and_train_model(optimizer):
    model = build_model()
    model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
                  metrics=["accuracy"])
    return model.fit(X_train, y_train, epochs=10,
                     validation_data=(X_valid, y_valid))

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)

# %%
history_sgd = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.6953 - accuracy: 0.7648 - val_loss: 0.5032 - val_accuracy: 0.8208
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4673 - accuracy: 0.8349 - val_loss: 0.4429 - val_accuracy: 0.8372
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4220 - accuracy: 0.8515 - val_loss: 0.4114 - val_accuracy: 0.8512
# Epoch 4/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3962 - accuracy: 0.8605 - val_loss: 0.3886 - val_accuracy: 0.8570
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3751 - accuracy: 0.8669 - val_loss: 0.3703 - val_accuracy: 0.8642
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3613 - accuracy: 0.8715 - val_loss: 0.3699 - val_accuracy: 0.8668
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3450 - accuracy: 0.8767 - val_loss: 0.3580 - val_accuracy: 0.8700
# Epoch 8/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3356 - accuracy: 0.8781 - val_loss: 0.3518 - val_accuracy: 0.8716
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3267 - accuracy: 0.8820 - val_loss: 0.3781 - val_accuracy: 0.8594
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3166 - accuracy: 0.8847 - val_loss: 0.3569 - val_accuracy: 0.8702

# %% [markdown]
# ## Momentum optimization

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)

# %%
history_momentum = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.6972 - accuracy: 0.7657 - val_loss: 0.5079 - val_accuracy: 0.8142
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4687 - accuracy: 0.8357 - val_loss: 0.4454 - val_accuracy: 0.8386
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4256 - accuracy: 0.8513 - val_loss: 0.4221 - val_accuracy: 0.8478
# Epoch 4/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.3980 - accuracy: 0.8611 - val_loss: 0.3840 - val_accuracy: 0.8646
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3761 - accuracy: 0.8678 - val_loss: 0.3719 - val_accuracy: 0.8670
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3626 - accuracy: 0.8721 - val_loss: 0.3747 - val_accuracy: 0.8648
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3457 - accuracy: 0.8765 - val_loss: 0.3639 - val_accuracy: 0.8680
# Epoch 8/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3354 - accuracy: 0.8794 - val_loss: 0.3507 - val_accuracy: 0.8728
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3263 - accuracy: 0.8833 - val_loss: 0.3866 - val_accuracy: 0.8578
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3168 - accuracy: 0.8857 - val_loss: 0.3775 - val_accuracy: 0.8644

# %% [markdown]
# ## Nesterov Accelerated Gradient

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9,
                                    nesterov=True)

# %%
history_nesterov = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.6839 - accuracy: 0.7667 - val_loss: 0.5036 - val_accuracy: 0.8220
# Epoch 2/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4615 - accuracy: 0.8400 - val_loss: 0.4372 - val_accuracy: 0.8450
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4160 - accuracy: 0.8547 - val_loss: 0.3982 - val_accuracy: 0.8580
# Epoch 4/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3898 - accuracy: 0.8640 - val_loss: 0.3800 - val_accuracy: 0.8636
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3696 - accuracy: 0.8704 - val_loss: 0.3673 - val_accuracy: 0.8672
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3561 - accuracy: 0.8733 - val_loss: 0.3701 - val_accuracy: 0.8734
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3413 - accuracy: 0.8788 - val_loss: 0.3705 - val_accuracy: 0.8638
# Epoch 8/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3313 - accuracy: 0.8797 - val_loss: 0.3546 - val_accuracy: 0.8718
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3223 - accuracy: 0.8841 - val_loss: 0.3586 - val_accuracy: 0.8662
# Epoch 10/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.3124 - accuracy: 0.8865 - val_loss: 0.3775 - val_accuracy: 0.8614

# %% [markdown]
# ## AdaGrad

# %%
optimizer = tf.keras.optimizers.Adagrad(learning_rate=0.001)

# %%
history_adagrad = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.9995 - accuracy: 0.6846 - val_loss: 0.6774 - val_accuracy: 0.7776
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.6362 - accuracy: 0.7905 - val_loss: 0.5767 - val_accuracy: 0.8082
# Epoch 3/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.5672 - accuracy: 0.8125 - val_loss: 0.5319 - val_accuracy: 0.8210
# Epoch 4/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.5314 - accuracy: 0.8229 - val_loss: 0.5069 - val_accuracy: 0.8308
# Epoch 5/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.5074 - accuracy: 0.8299 - val_loss: 0.4871 - val_accuracy: 0.8354
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4902 - accuracy: 0.8344 - val_loss: 0.4750 - val_accuracy: 0.8368
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4771 - accuracy: 0.8378 - val_loss: 0.4641 - val_accuracy: 0.8420
# Epoch 8/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4667 - accuracy: 0.8414 - val_loss: 0.4551 - val_accuracy: 0.8444
# Epoch 9/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4578 - accuracy: 0.8445 - val_loss: 0.4489 - val_accuracy: 0.8456
# Epoch 10/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4500 - accuracy: 0.8463 - val_loss: 0.4426 - val_accuracy: 0.8474

# %% [markdown]
# ## RMSProp

# %%
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9)

# %%
history_rmsprop = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.5210 - accuracy: 0.8129 - val_loss: 0.4204 - val_accuracy: 0.8404
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3919 - accuracy: 0.8591 - val_loss: 0.4065 - val_accuracy: 0.8524
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3681 - accuracy: 0.8693 - val_loss: 0.3994 - val_accuracy: 0.8654
# Epoch 4/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3620 - accuracy: 0.8749 - val_loss: 0.4072 - val_accuracy: 0.8680
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3574 - accuracy: 0.8771 - val_loss: 0.4179 - val_accuracy: 0.8620
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3542 - accuracy: 0.8787 - val_loss: 0.4594 - val_accuracy: 0.8598
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3534 - accuracy: 0.8785 - val_loss: 0.4334 - val_accuracy: 0.8682
# Epoch 8/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3491 - accuracy: 0.8824 - val_loss: 0.4536 - val_accuracy: 0.8636
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3464 - accuracy: 0.8834 - val_loss: 0.5186 - val_accuracy: 0.8748
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3431 - accuracy: 0.8825 - val_loss: 0.4971 - val_accuracy: 0.8746

# %% [markdown]
# ## Adam Optimization

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9,
                                     beta_2=0.999)

# %%
history_adam = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4982 - accuracy: 0.8192 - val_loss: 0.4162 - val_accuracy: 0.8342
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3763 - accuracy: 0.8612 - val_loss: 0.4073 - val_accuracy: 0.8422
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3406 - accuracy: 0.8738 - val_loss: 0.3500 - val_accuracy: 0.8732
# Epoch 4/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3165 - accuracy: 0.8834 - val_loss: 0.3506 - val_accuracy: 0.8736
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2987 - accuracy: 0.8878 - val_loss: 0.3177 - val_accuracy: 0.8784
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2839 - accuracy: 0.8935 - val_loss: 0.3489 - val_accuracy: 0.8764
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2733 - accuracy: 0.8972 - val_loss: 0.3373 - val_accuracy: 0.8796
# Epoch 8/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2611 - accuracy: 0.9021 - val_loss: 0.3247 - val_accuracy: 0.8850
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2516 - accuracy: 0.9057 - val_loss: 0.3811 - val_accuracy: 0.8708
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2434 - accuracy: 0.9073 - val_loss: 0.3843 - val_accuracy: 0.8754

# %% [markdown]
# **Adamax Optimization**

# %%
optimizer = tf.keras.optimizers.Adamax(learning_rate=0.001, beta_1=0.9,
                                       beta_2=0.999)

# %%
history_adamax = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.5347 - accuracy: 0.8147 - val_loss: 0.4482 - val_accuracy: 0.8300
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3974 - accuracy: 0.8586 - val_loss: 0.3993 - val_accuracy: 0.8482
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3596 - accuracy: 0.8701 - val_loss: 0.3532 - val_accuracy: 0.8704
# Epoch 4/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3353 - accuracy: 0.8786 - val_loss: 0.3444 - val_accuracy: 0.8744
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3150 - accuracy: 0.8852 - val_loss: 0.3307 - val_accuracy: 0.8770
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3013 - accuracy: 0.8902 - val_loss: 0.3441 - val_accuracy: 0.8748
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2869 - accuracy: 0.8939 - val_loss: 0.3253 - val_accuracy: 0.8822
# Epoch 8/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2777 - accuracy: 0.8974 - val_loss: 0.3185 - val_accuracy: 0.8862
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2676 - accuracy: 0.9016 - val_loss: 0.3363 - val_accuracy: 0.8778
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2571 - accuracy: 0.9043 - val_loss: 0.3443 - val_accuracy: 0.8800

# %% [markdown]
# **Nadam Optimization**

# %%
optimizer = tf.keras.optimizers.Nadam(learning_rate=0.001, beta_1=0.9,
                                      beta_2=0.999)

# %%
history_nadam = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.4878 - accuracy: 0.8256 - val_loss: 0.4281 - val_accuracy: 0.8360
# Epoch 2/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3628 - accuracy: 0.8673 - val_loss: 0.3773 - val_accuracy: 0.8572
# Epoch 3/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3293 - accuracy: 0.8790 - val_loss: 0.3480 - val_accuracy: 0.8752
# Epoch 4/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3076 - accuracy: 0.8887 - val_loss: 0.3276 - val_accuracy: 0.8780
# Epoch 5/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2905 - accuracy: 0.8922 - val_loss: 0.3301 - val_accuracy: 0.8768
# Epoch 6/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2754 - accuracy: 0.8993 - val_loss: 0.3696 - val_accuracy: 0.8754
# Epoch 7/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2649 - accuracy: 0.9007 - val_loss: 0.3462 - val_accuracy: 0.8764
# Epoch 8/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2548 - accuracy: 0.9044 - val_loss: 0.3479 - val_accuracy: 0.8726
# Epoch 9/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2462 - accuracy: 0.9079 - val_loss: 0.3391 - val_accuracy: 0.8784
# Epoch 10/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2374 - accuracy: 0.9113 - val_loss: 0.3648 - val_accuracy: 0.8794

# %% [markdown]
# **AdamW Optimization**

# %% [markdown]
# On Colab or Kaggle, we need to install the TensorFlow-Addons library:

# %%
if "google.colab" in sys.modules:
    # %pip install -q -U tensorflow-addons

# %%
import tensorflow_addons as tfa

optimizer = tfa.optimizers.AdamW(weight_decay=1e-5, learning_rate=0.001,
                                 beta_1=0.9, beta_2=0.999)

# %%
history_adamw = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4978 - accuracy: 0.8212 - val_loss: 0.4166 - val_accuracy: 0.8356
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3754 - accuracy: 0.8619 - val_loss: 0.3920 - val_accuracy: 0.8456
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3446 - accuracy: 0.8719 - val_loss: 0.3465 - val_accuracy: 0.8744
# Epoch 4/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3196 - accuracy: 0.8827 - val_loss: 0.3501 - val_accuracy: 0.8746
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3017 - accuracy: 0.8886 - val_loss: 0.3205 - val_accuracy: 0.8798
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2858 - accuracy: 0.8939 - val_loss: 0.3672 - val_accuracy: 0.8698
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2739 - accuracy: 0.8967 - val_loss: 0.3441 - val_accuracy: 0.8798
# Epoch 8/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2651 - accuracy: 0.8994 - val_loss: 0.3250 - val_accuracy: 0.8858
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2568 - accuracy: 0.9030 - val_loss: 0.3600 - val_accuracy: 0.8758
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2475 - accuracy: 0.9051 - val_loss: 0.3531 - val_accuracy: 0.8808

# %%
# extra code – visualize the learning curves of all the optimizers

for loss in ("loss", "val_loss"):
    plt.figure(figsize=(12, 8))
    opt_names = "SGD Momentum Nesterov AdaGrad RMSProp Adam Adamax Nadam AdamW"
    for history, opt_name in zip((history_sgd, history_momentum, history_nesterov,
                                  history_adagrad, history_rmsprop, history_adam,
                                  history_adamax, history_nadam, history_adamw),
                                 opt_names.split()):
        plt.plot(history.history[loss], label=f"{opt_name}", linewidth=3)

    plt.grid()
    plt.xlabel("Epochs")
    plt.ylabel({"loss": "Training loss", "val_loss": "Validation loss"}[loss])
    plt.legend(loc="upper left")
    plt.axis([0, 9, 0.1, 0.7])
    plt.show()

# %% [markdown]
# ## Learning Rate Scheduling

# %% [markdown]
# ### Power Scheduling

# %% [markdown]
# ```lr = lr0 / (1 + steps / s)**c```
# * Keras uses `c=1` and `s = 1 / decay`

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, decay=1e-4)

# %%
history_power_scheduling = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.7256 - accuracy: 0.7490 - val_loss: 0.5014 - val_accuracy: 0.8234
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4809 - accuracy: 0.8323 - val_loss: 0.4531 - val_accuracy: 0.8380
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4335 - accuracy: 0.8490 - val_loss: 0.4288 - val_accuracy: 0.8462
# Epoch 4/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4097 - accuracy: 0.8568 - val_loss: 0.4024 - val_accuracy: 0.8590
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3905 - accuracy: 0.8637 - val_loss: 0.3938 - val_accuracy: 0.8590
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3766 - accuracy: 0.8662 - val_loss: 0.4033 - val_accuracy: 0.8576
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3660 - accuracy: 0.8709 - val_loss: 0.3800 - val_accuracy: 0.8646
# Epoch 8/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.3570 - accuracy: 0.8734 - val_loss: 0.3775 - val_accuracy: 0.8608
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3486 - accuracy: 0.8773 - val_loss: 0.3610 - val_accuracy: 0.8690
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3413 - accuracy: 0.8785 - val_loss: 0.3653 - val_accuracy: 0.8678

# %%
# extra code – this cell plots power scheduling

import math

learning_rate = 0.01
decay = 1e-4
batch_size = 32
n_steps_per_epoch = math.ceil(len(X_train) / batch_size)
n_epochs = 25

epochs = np.arange(n_epochs)
lrs = learning_rate / (1 + decay * epochs * n_steps_per_epoch)

plt.plot(epochs, lrs,  "o-")
plt.axis([0, n_epochs - 1, 0, 0.01])
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.title("Power Scheduling", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exponential Scheduling

# %% [markdown]
# ```lr = lr0 * 0.1 ** (epoch / s)```

# %%
def exponential_decay_fn(epoch):
    return 0.01 * 0.1 ** (epoch / 20)

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 ** (epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(lr0=0.01, s=20)

# %%
# extra code – build and compile a model for Fashion MNIST

tf.random.set_seed(42)
model = build_model()
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])

# %%
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler])
# Out:
# Epoch 1/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.7051 - accuracy: 0.7562 - val_loss: 0.4810 - val_accuracy: 0.8320 - lr: 0.0100
# Epoch 2/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4669 - accuracy: 0.8357 - val_loss: 0.4562 - val_accuracy: 0.8388 - lr: 0.0089
# Epoch 3/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4203 - accuracy: 0.8506 - val_loss: 0.4172 - val_accuracy: 0.8558 - lr: 0.0079
# Epoch 4/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3972 - accuracy: 0.8603 - val_loss: 0.3930 - val_accuracy: 0.8612 - lr: 0.0071
# Epoch 5/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3783 - accuracy: 0.8659 - val_loss: 0.3874 - val_accuracy: 0.8628 - lr: 0.0063
# Epoch 6/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3647 - accuracy: 0.8703 - val_loss: 0.3905 - val_accuracy: 0.8610 - lr: 0.0056
# Epoch 7/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3544 - accuracy: 0.8727 - val_loss: 0.3746 - val_accuracy: 0.8644 - lr: 0.0050
# Epoch 8/25
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.3458 - accuracy: 0.8762 - val_loss: 0.3663 - val_accuracy: 0.8668 - lr: 0.0045
# Epoch 9/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3380 - accuracy: 0.8796 - val_loss: 0.3593 - val_accuracy: 0.8712 - lr: 0.0040
# Epoch 10/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3312 - accuracy: 0.8818 - val_loss: 0.3590 - val_accuracy: 0.8678 - lr: 0.0035
# Epoch 11/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3256 - accuracy: 0.8838 - val_loss: 0.3553 - val_accuracy: 0.8698 - lr: 0.0032
# Epoch 12/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3206 - accuracy: 0.8852 - val_loss: 0.3552 - val_accuracy: 0.8722 - lr: 0.0028
# Epoch 13/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3166 - accuracy: 0.8882 - val_loss: 0.3449 - val_accuracy: 0.8724 - lr: 0.0025
# Epoch 14/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3129 - accuracy: 0.8887 - val_loss: 0.3467 - val_accuracy: 0.8764 - lr: 0.0022
# Epoch 15/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3099 - accuracy: 0.8902 - val_loss: 0.3454 - val_accuracy: 0.8768 - lr: 0.0020
# Epoch 16/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3064 - accuracy: 0.8905 - val_loss: 0.3412 - val_accuracy: 0.8760 - lr: 0.0018
# Epoch 17/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3042 - accuracy: 0.8903 - val_loss: 0.3414 - val_accuracy: 0.8742 - lr: 0.0016
# Epoch 18/25
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.3019 - accuracy: 0.8920 - val_loss: 0.3407 - val_accuracy: 0.8772 - lr: 0.0014
# Epoch 19/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3000 - accuracy: 0.8924 - val_loss: 0.3384 - val_accuracy: 0.8754 - lr: 0.0013
# Epoch 20/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2980 - accuracy: 0.8927 - val_loss: 0.3383 - val_accuracy: 0.8768 - lr: 0.0011
# Epoch 21/25
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.2965 - accuracy: 0.8941 - val_loss: 0.3365 - val_accuracy: 0.8768 - lr: 0.0010
# Epoch 22/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2951 - accuracy: 0.8946 - val_loss: 0.3383 - val_accuracy: 0.8758 - lr: 8.9125e-04
# Epoch 23/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2938 - accuracy: 0.8949 - val_loss: 0.3365 - val_accuracy: 0.8776 - lr: 7.9433e-04
# Epoch 24/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2926 - accuracy: 0.8955 - val_loss: 0.3377 - val_accuracy: 0.8766 - lr: 7.0795e-04
# Epoch 25/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2917 - accuracy: 0.8960 - val_loss: 0.3365 - val_accuracy: 0.8776 - lr: 6.3096e-04

# %%
# extra code – this cell plots exponential scheduling

plt.plot(history.epoch, history.history["lr"], "o-")
plt.axis([0, n_epochs - 1, 0, 0.011])
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.title("Exponential Scheduling", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# The schedule function can take the current learning rate as a second argument:

# %%
def exponential_decay_fn(epoch, lr):
    return lr * 0.1 ** (1 / 20)

# %% [markdown]
# **Extra material**: if you want to update the learning rate at each iteration rather than at each epoch, you can write your own callback class:

# %%
K = tf.keras.backend

class ExponentialDecay(tf.keras.callbacks.Callback):
    def __init__(self, n_steps=40_000):
        super().__init__()
        self.n_steps = n_steps

    def on_batch_begin(self, batch, logs=None):
        # Note: the `batch` argument is reset at each epoch
        lr = K.get_value(self.model.optimizer.learning_rate)
        new_learning_rate = lr * 0.1 ** (1 / self.n_steps)
        K.set_value(self.model.optimizer.learning_rate, new_learning_rate)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = K.get_value(self.model.optimizer.learning_rate)

# %%
lr0 = 0.01
model = build_model()
optimizer = tf.keras.optimizers.SGD(learning_rate=lr0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])

# %%
n_epochs = 25
batch_size = 32
n_steps = n_epochs * math.ceil(len(X_train) / batch_size)
exp_decay = ExponentialDecay(n_steps)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[exp_decay])
# Out:
# Epoch 1/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.6915 - accuracy: 0.7686 - val_loss: 0.4872 - val_accuracy: 0.8350 - lr: 0.0091
# Epoch 2/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4740 - accuracy: 0.8336 - val_loss: 0.4448 - val_accuracy: 0.8400 - lr: 0.0083
# Epoch 3/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4269 - accuracy: 0.8491 - val_loss: 0.4086 - val_accuracy: 0.8576 - lr: 0.0076
# Epoch 4/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.4029 - accuracy: 0.8589 - val_loss: 0.3872 - val_accuracy: 0.8620 - lr: 0.0069
# Epoch 5/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3831 - accuracy: 0.8653 - val_loss: 0.3828 - val_accuracy: 0.8624 - lr: 0.0063
# Epoch 6/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3690 - accuracy: 0.8692 - val_loss: 0.3907 - val_accuracy: 0.8638 - lr: 0.0058
# Epoch 7/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3585 - accuracy: 0.8722 - val_loss: 0.3683 - val_accuracy: 0.8688 - lr: 0.0052
# Epoch 8/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3486 - accuracy: 0.8761 - val_loss: 0.3710 - val_accuracy: 0.8650 - lr: 0.0048
# Epoch 9/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3408 - accuracy: 0.8795 - val_loss: 0.3514 - val_accuracy: 0.8726 - lr: 0.0044
# Epoch 10/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3332 - accuracy: 0.8820 - val_loss: 0.3527 - val_accuracy: 0.8740 - lr: 0.0040
# Epoch 11/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3273 - accuracy: 0.8832 - val_loss: 0.3574 - val_accuracy: 0.8638 - lr: 0.0036
# Epoch 12/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3217 - accuracy: 0.8848 - val_loss: 0.3489 - val_accuracy: 0.8726 - lr: 0.0033
# Epoch 13/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3171 - accuracy: 0.8878 - val_loss: 0.3369 - val_accuracy: 0.8796 - lr: 0.0030
# Epoch 14/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3126 - accuracy: 0.8889 - val_loss: 0.3409 - val_accuracy: 0.8770 - lr: 0.0028
# Epoch 15/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3089 - accuracy: 0.8909 - val_loss: 0.3402 - val_accuracy: 0.8798 - lr: 0.0025
# Epoch 16/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3047 - accuracy: 0.8915 - val_loss: 0.3344 - val_accuracy: 0.8798 - lr: 0.0023
# Epoch 17/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3019 - accuracy: 0.8915 - val_loss: 0.3374 - val_accuracy: 0.8746 - lr: 0.0021
# Epoch 18/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2990 - accuracy: 0.8934 - val_loss: 0.3345 - val_accuracy: 0.8794 - lr: 0.0019
# Epoch 19/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2965 - accuracy: 0.8935 - val_loss: 0.3323 - val_accuracy: 0.8778 - lr: 0.0017
# Epoch 20/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2942 - accuracy: 0.8956 - val_loss: 0.3300 - val_accuracy: 0.8780 - lr: 0.0016
# Epoch 21/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2920 - accuracy: 0.8963 - val_loss: 0.3293 - val_accuracy: 0.8794 - lr: 0.0014
# Epoch 22/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2896 - accuracy: 0.8969 - val_loss: 0.3307 - val_accuracy: 0.8786 - lr: 0.0013
# Epoch 23/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2880 - accuracy: 0.8979 - val_loss: 0.3274 - val_accuracy: 0.8802 - lr: 0.0012
# Epoch 24/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2863 - accuracy: 0.8981 - val_loss: 0.3303 - val_accuracy: 0.8810 - lr: 0.0011
# Epoch 25/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2848 - accuracy: 0.8985 - val_loss: 0.3292 - val_accuracy: 0.8788 - lr: 1.0000e-03

# %%
n_steps = n_epochs * math.ceil(len(X_train) / batch_size)
steps = np.arange(n_steps)
decay_rate = 0.1
lrs = lr0 * decay_rate ** (steps / n_steps)

plt.plot(steps, lrs, "-", linewidth=2)
plt.axis([0, n_steps - 1, 0, lr0 * 1.1])
plt.xlabel("Batch")
plt.ylabel("Learning Rate")
plt.title("Exponential Scheduling (per batch)", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Piecewise Constant Scheduling

# %%
def piecewise_constant_fn(epoch):
    if epoch < 5:
        return 0.01
    elif epoch < 15:
        return 0.005
    else:
        return 0.001

# %%
# extra code – this cell demonstrates a more general way to define
#              piecewise constant scheduling.

def piecewise_constant(boundaries, values):
    boundaries = np.array([0] + boundaries)
    values = np.array(values)
    def piecewise_constant_fn(epoch):
        return values[(boundaries > epoch).argmax() - 1]
    return piecewise_constant_fn

piecewise_constant_fn = piecewise_constant([5, 15], [0.01, 0.005, 0.001])

# %%
# extra code – use a tf.keras.callbacks.LearningRateScheduler like earlier

n_epochs = 25

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(piecewise_constant_fn)

model = build_model()
optimizer = tf.keras.optimizers.Nadam(learning_rate=lr0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler])
# Out:
# Epoch 1/25
# 1719/1719 [==============================] - 5s 2ms/step - loss: 0.5759 - accuracy: 0.7924 - val_loss: 0.4668 - val_accuracy: 0.8202 - lr: 0.0100
# Epoch 2/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.4512 - accuracy: 0.8403 - val_loss: 0.4574 - val_accuracy: 0.8404 - lr: 0.0100
# Epoch 3/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.4248 - accuracy: 0.8529 - val_loss: 0.4052 - val_accuracy: 0.8638 - lr: 0.0100
# Epoch 4/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.4116 - accuracy: 0.8564 - val_loss: 0.5429 - val_accuracy: 0.8150 - lr: 0.0100
# Epoch 5/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.4043 - accuracy: 0.8590 - val_loss: 0.4131 - val_accuracy: 0.8580 - lr: 0.0100
# Epoch 6/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3459 - accuracy: 0.8774 - val_loss: 0.4033 - val_accuracy: 0.8640 - lr: 0.0050
# Epoch 7/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3359 - accuracy: 0.8799 - val_loss: 0.4110 - val_accuracy: 0.8616 - lr: 0.0050
# Epoch 8/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3312 - accuracy: 0.8812 - val_loss: 0.3796 - val_accuracy: 0.8700 - lr: 0.0050
# Epoch 9/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3248 - accuracy: 0.8848 - val_loss: 0.3794 - val_accuracy: 0.8684 - lr: 0.0050
# Epoch 10/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3242 - accuracy: 0.8850 - val_loss: 0.3919 - val_accuracy: 0.8714 - lr: 0.0050
# Epoch 11/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3194 - accuracy: 0.8877 - val_loss: 0.3801 - val_accuracy: 0.8714 - lr: 0.0050
# Epoch 12/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3162 - accuracy: 0.8864 - val_loss: 0.4109 - val_accuracy: 0.8640 - lr: 0.0050
# Epoch 13/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3155 - accuracy: 0.8882 - val_loss: 0.3776 - val_accuracy: 0.8718 - lr: 0.0050
# Epoch 14/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3104 - accuracy: 0.8895 - val_loss: 0.4095 - val_accuracy: 0.8712 - lr: 0.0050
# Epoch 15/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.3160 - accuracy: 0.8889 - val_loss: 0.3927 - val_accuracy: 0.8704 - lr: 0.0050
# Epoch 16/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2727 - accuracy: 0.9012 - val_loss: 0.3727 - val_accuracy: 0.8768 - lr: 0.0010
# Epoch 17/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2648 - accuracy: 0.9032 - val_loss: 0.3757 - val_accuracy: 0.8768 - lr: 0.0010
# Epoch 18/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2612 - accuracy: 0.9042 - val_loss: 0.3743 - val_accuracy: 0.8768 - lr: 0.0010
# Epoch 19/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2583 - accuracy: 0.9056 - val_loss: 0.3786 - val_accuracy: 0.8806 - lr: 0.0010
# Epoch 20/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2566 - accuracy: 0.9062 - val_loss: 0.3925 - val_accuracy: 0.8796 - lr: 0.0010
# Epoch 21/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2537 - accuracy: 0.9073 - val_loss: 0.3965 - val_accuracy: 0.8794 - lr: 0.0010
# Epoch 22/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2522 - accuracy: 0.9078 - val_loss: 0.4145 - val_accuracy: 0.8780 - lr: 0.0010
# Epoch 23/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2504 - accuracy: 0.9081 - val_loss: 0.4017 - val_accuracy: 0.8798 - lr: 0.0010
# Epoch 24/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2477 - accuracy: 0.9086 - val_loss: 0.4232 - val_accuracy: 0.8796 - lr: 0.0010
# Epoch 25/25
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2465 - accuracy: 0.9096 - val_loss: 0.4123 - val_accuracy: 0.8784 - lr: 0.0010

# %%
# extra code – this cell plots piecewise constant scheduling

plt.plot(history.epoch, history.history["lr"], "o-")
plt.axis([0, n_epochs - 1, 0, 0.011])
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.title("Piecewise Constant Scheduling", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Performance Scheduling

# %%
# extra code – build and compile the model

model = build_model()
optimizer = tf.keras.optimizers.SGD(learning_rate=lr0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler])
# Out:
# Epoch 1/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.6941 - accuracy: 0.7614 - val_loss: 0.4955 - val_accuracy: 0.8236 - lr: 0.0100
# Epoch 2/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4718 - accuracy: 0.8334 - val_loss: 0.4465 - val_accuracy: 0.8388 - lr: 0.0100
# Epoch 3/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4227 - accuracy: 0.8488 - val_loss: 0.4161 - val_accuracy: 0.8514 - lr: 0.0100
# Epoch 4/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3972 - accuracy: 0.8588 - val_loss: 0.3834 - val_accuracy: 0.8600 - lr: 0.0100
# Epoch 5/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3779 - accuracy: 0.8646 - val_loss: 0.3717 - val_accuracy: 0.8650 - lr: 0.0100
# Epoch 6/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3605 - accuracy: 0.8705 - val_loss: 0.3903 - val_accuracy: 0.8610 - lr: 0.0100
# Epoch 7/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3497 - accuracy: 0.8731 - val_loss: 0.3611 - val_accuracy: 0.8694 - lr: 0.0100
# Epoch 8/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3380 - accuracy: 0.8781 - val_loss: 0.3597 - val_accuracy: 0.8632 - lr: 0.0100
# Epoch 9/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3282 - accuracy: 0.8799 - val_loss: 0.3407 - val_accuracy: 0.8742 - lr: 0.0100
# Epoch 10/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3183 - accuracy: 0.8838 - val_loss: 0.3494 - val_accuracy: 0.8726 - lr: 0.0100
# Epoch 11/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3107 - accuracy: 0.8865 - val_loss: 0.3626 - val_accuracy: 0.8636 - lr: 0.0100
# Epoch 12/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3042 - accuracy: 0.8887 - val_loss: 0.3417 - val_accuracy: 0.8742 - lr: 0.0100
# Epoch 13/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2971 - accuracy: 0.8923 - val_loss: 0.3334 - val_accuracy: 0.8766 - lr: 0.0100
# Epoch 14/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2902 - accuracy: 0.8939 - val_loss: 0.3400 - val_accuracy: 0.8780 - lr: 0.0100
# Epoch 15/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2845 - accuracy: 0.8960 - val_loss: 0.3424 - val_accuracy: 0.8790 - lr: 0.0100
# Epoch 16/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2782 - accuracy: 0.8981 - val_loss: 0.3359 - val_accuracy: 0.8778 - lr: 0.0100
# Epoch 17/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2738 - accuracy: 0.8996 - val_loss: 0.3499 - val_accuracy: 0.8720 - lr: 0.0100
# Epoch 18/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2680 - accuracy: 0.9018 - val_loss: 0.3317 - val_accuracy: 0.8792 - lr: 0.0100
# Epoch 19/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2646 - accuracy: 0.9023 - val_loss: 0.3763 - val_accuracy: 0.8578 - lr: 0.0100
# Epoch 20/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2599 - accuracy: 0.9049 - val_loss: 0.3273 - val_accuracy: 0.8788 - lr: 0.0100
# Epoch 21/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2550 - accuracy: 0.9054 - val_loss: 0.3184 - val_accuracy: 0.8836 - lr: 0.0100
# Epoch 22/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2506 - accuracy: 0.9071 - val_loss: 0.3261 - val_accuracy: 0.8828 - lr: 0.0100
# Epoch 23/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2466 - accuracy: 0.9095 - val_loss: 0.3447 - val_accuracy: 0.8768 - lr: 0.0100
# Epoch 24/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2416 - accuracy: 0.9111 - val_loss: 0.3254 - val_accuracy: 0.8828 - lr: 0.0100
# Epoch 25/25
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2385 - accuracy: 0.9125 - val_loss: 0.3196 - val_accuracy: 0.8846 - lr: 0.0100

# %%
# extra code – this cell plots performance scheduling

plt.plot(history.epoch, history.history["lr"], "bo-")
plt.xlabel("Epoch")
plt.ylabel("Learning Rate", color='b')
plt.tick_params('y', colors='b')
plt.gca().set_xlim(0, n_epochs - 1)
plt.grid(True)

ax2 = plt.gca().twinx()
ax2.plot(history.epoch, history.history["val_loss"], "r^-")
ax2.set_ylabel('Validation Loss', color='r')
ax2.tick_params('y', colors='r')

plt.title("Reduce LR on Plateau", fontsize=14)
plt.show()

# %% [markdown]
# ### tf.keras schedulers

# %%
import math

batch_size = 32
n_epochs = 25
n_steps = n_epochs * math.ceil(len(X_train) / batch_size)
scheduled_learning_rate = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01, decay_steps=n_steps, decay_rate=0.1)
optimizer = tf.keras.optimizers.SGD(learning_rate=scheduled_learning_rate)

# %%
# extra code – build and train the model
model = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.6652 - accuracy: 0.7708 - val_loss: 0.4933 - val_accuracy: 0.8294
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4693 - accuracy: 0.8356 - val_loss: 0.4482 - val_accuracy: 0.8370
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4235 - accuracy: 0.8500 - val_loss: 0.4171 - val_accuracy: 0.8510
# Epoch 4/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3997 - accuracy: 0.8595 - val_loss: 0.3868 - val_accuracy: 0.8598
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3799 - accuracy: 0.8648 - val_loss: 0.3812 - val_accuracy: 0.8604
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3649 - accuracy: 0.8688 - val_loss: 0.3828 - val_accuracy: 0.8638
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3544 - accuracy: 0.8735 - val_loss: 0.3716 - val_accuracy: 0.8658
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3441 - accuracy: 0.8765 - val_loss: 0.3642 - val_accuracy: 0.8674
# Epoch 9/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.3362 - accuracy: 0.8793 - val_loss: 0.3532 - val_accuracy: 0.8694
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3286 - accuracy: 0.8821 - val_loss: 0.3522 - val_accuracy: 0.8716

# %% [markdown]
# For piecewise constant scheduling, try this:

# %%
# extra code – shows how to use PiecewiseConstantDecay
scheduled_learning_rate = tf.keras.optimizers.schedules.PiecewiseConstantDecay(
    boundaries=[5. * n_steps_per_epoch, 15. * n_steps_per_epoch],
    values=[0.01, 0.005, 0.001])

# %% [markdown]
# ### 1Cycle scheduling

# %% [markdown]
# The `ExponentialLearningRate` custom callback updates the learning rate during training, at the end of each batch. It multiplies it by a constant `factor`. It also saves the learning rate and loss at each batch. Since `logs["loss"]` is actually the mean loss since the start of the epoch, and we want to save the batch loss instead, we must compute the mean times the number of batches since the beginning of the epoch to get the total loss so far, then we subtract the total loss at the previous batch to get the current batch's loss.

# %%
K = tf.keras.backend

class ExponentialLearningRate(tf.keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []

    def on_epoch_begin(self, epoch, logs=None):
        self.sum_of_epoch_losses = 0

    def on_batch_end(self, batch, logs=None):
        mean_epoch_loss = logs["loss"]  # the epoch's mean loss so far 
        new_sum_of_epoch_losses = mean_epoch_loss * (batch + 1)
        batch_loss = new_sum_of_epoch_losses - self.sum_of_epoch_losses
        self.sum_of_epoch_losses = new_sum_of_epoch_losses
        self.rates.append(K.get_value(self.model.optimizer.learning_rate))
        self.losses.append(batch_loss)
        K.set_value(self.model.optimizer.learning_rate,
                    self.model.optimizer.learning_rate * self.factor)

# %% [markdown]
# The `find_learning_rate()` function trains the model using the `ExponentialLearningRate` callback, and it returns the learning rates and corresponding batch losses. At the end, it restores the model and its optimizer to their initial state.

# %%
def find_learning_rate(model, X, y, epochs=1, batch_size=32, min_rate=1e-4,
                       max_rate=1):
    init_weights = model.get_weights()
    iterations = math.ceil(len(X) / batch_size) * epochs
    factor = (max_rate / min_rate) ** (1 / iterations)
    init_lr = K.get_value(model.optimizer.learning_rate)
    K.set_value(model.optimizer.learning_rate, min_rate)
    exp_lr = ExponentialLearningRate(factor)
    history = model.fit(X, y, epochs=epochs, batch_size=batch_size,
                        callbacks=[exp_lr])
    K.set_value(model.optimizer.learning_rate, init_lr)
    model.set_weights(init_weights)
    return exp_lr.rates, exp_lr.losses

# %% [markdown]
# The `plot_lr_vs_loss()` function plots the learning rates vs the losses. The optimal learning rate to use as the maximum learning rate in 1cycle is near the bottom of the curve.

# %%
def plot_lr_vs_loss(rates, losses):
    plt.plot(rates, losses, "b")
    plt.gca().set_xscale('log')
    max_loss = losses[0] + min(losses)
    plt.hlines(min(losses), min(rates), max(rates), color="k")
    plt.axis([min(rates), max(rates), 0, max_loss])
    plt.xlabel("Learning rate")
    plt.ylabel("Loss")
    plt.grid()

# %% [markdown]
# Let's build a simple Fashion MNIST model and compile it:

# %%
model = build_model()
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              metrics=["accuracy"])

# %% [markdown]
# Now let's find the optimal max learning rate for 1cycle:

# %%
batch_size = 128
rates, losses = find_learning_rate(model, X_train, y_train, epochs=1,
                                   batch_size=batch_size)
plot_lr_vs_loss(rates, losses)
# Out:
# 430/430 [==============================] - 1s 3ms/step - loss: 1.7870 - accuracy: 0.3892

# %% [markdown]
# Looks like the max learning rate to use for 1cycle is around 10<sup>–1</sup>.

# %% [markdown]
# The `OneCycleScheduler` custom callback updates the learning rate at the beginning of each batch. It applies the logic described in the book: increase the learning rate linearly during about half of training, then reduce it linearly back to the initial learning rate, and lastly reduce it down to close to zero linearly for the very last part of training.

# %%
class OneCycleScheduler(tf.keras.callbacks.Callback):
    def __init__(self, iterations, max_lr=1e-3, start_lr=None,
                 last_iterations=None, last_lr=None):
        self.iterations = iterations
        self.max_lr = max_lr
        self.start_lr = start_lr or max_lr / 10
        self.last_iterations = last_iterations or iterations // 10 + 1
        self.half_iteration = (iterations - self.last_iterations) // 2
        self.last_lr = last_lr or self.start_lr / 1000
        self.iteration = 0

    def _interpolate(self, iter1, iter2, lr1, lr2):
        return (lr2 - lr1) * (self.iteration - iter1) / (iter2 - iter1) + lr1

    def on_batch_begin(self, batch, logs):
        if self.iteration < self.half_iteration:
            lr = self._interpolate(0, self.half_iteration, self.start_lr,
                                   self.max_lr)
        elif self.iteration < 2 * self.half_iteration:
            lr = self._interpolate(self.half_iteration, 2 * self.half_iteration,
                                   self.max_lr, self.start_lr)
        else:
            lr = self._interpolate(2 * self.half_iteration, self.iterations,
                                   self.start_lr, self.last_lr)
        self.iteration += 1
        K.set_value(self.model.optimizer.learning_rate, lr)

# %% [markdown]
# Let's build and compile a simple Fashion MNIST model, then train it using the `OneCycleScheduler` callback:

# %%
model = build_model()
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["accuracy"])
n_epochs = 25
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * n_epochs,
                             max_lr=0.1)
history = model.fit(X_train, y_train, epochs=n_epochs, batch_size=batch_size,
                    validation_data=(X_valid, y_valid),
                    callbacks=[onecycle])
# Out:
# Epoch 1/25
# 430/430 [==============================] - 1s 3ms/step - loss: 0.9815 - accuracy: 0.6843 - val_loss: 0.5973 - val_accuracy: 0.7984
# Epoch 2/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.5688 - accuracy: 0.8006 - val_loss: 0.4905 - val_accuracy: 0.8300
# Epoch 3/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.4939 - accuracy: 0.8263 - val_loss: 0.4611 - val_accuracy: 0.8408
# Epoch 4/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.4503 - accuracy: 0.8407 - val_loss: 0.4192 - val_accuracy: 0.8506
# Epoch 5/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.4246 - accuracy: 0.8492 - val_loss: 0.4164 - val_accuracy: 0.8484
# Epoch 6/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8564 - val_loss: 0.4697 - val_accuracy: 0.8284
# Epoch 7/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3851 - accuracy: 0.8611 - val_loss: 0.4024 - val_accuracy: 0.8530
# Epoch 8/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3693 - accuracy: 0.8654 - val_loss: 0.4193 - val_accuracy: 0.8440
# Epoch 9/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3541 - accuracy: 0.8703 - val_loss: 0.3701 - val_accuracy: 0.8684
# Epoch 10/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3428 - accuracy: 0.8753 - val_loss: 0.4738 - val_accuracy: 0.8470
# Epoch 11/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3306 - accuracy: 0.8787 - val_loss: 0.4075 - val_accuracy: 0.8398
# Epoch 12/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3200 - accuracy: 0.8818 - val_loss: 0.3495 - val_accuracy: 0.8698
# Epoch 13/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3002 - accuracy: 0.8903 - val_loss: 0.3234 - val_accuracy: 0.8794
# Epoch 14/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2850 - accuracy: 0.8957 - val_loss: 0.3863 - val_accuracy: 0.8620
# Epoch 15/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2721 - accuracy: 0.8992 - val_loss: 0.3764 - val_accuracy: 0.8652
# Epoch 16/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2611 - accuracy: 0.9030 - val_loss: 0.3200 - val_accuracy: 0.8788
# Epoch 17/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2531 - accuracy: 0.9071 - val_loss: 0.3157 - val_accuracy: 0.8804
# Epoch 18/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2417 - accuracy: 0.9101 - val_loss: 0.3185 - val_accuracy: 0.8870
# Epoch 19/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2341 - accuracy: 0.9143 - val_loss: 0.3101 - val_accuracy: 0.8830
# Epoch 20/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2261 - accuracy: 0.9169 - val_loss: 0.3164 - val_accuracy: 0.8816
# Epoch 21/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2203 - accuracy: 0.9201 - val_loss: 0.3065 - val_accuracy: 0.8884
# Epoch 22/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2131 - accuracy: 0.9224 - val_loss: 0.3083 - val_accuracy: 0.8862
# Epoch 23/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2082 - accuracy: 0.9246 - val_loss: 0.3057 - val_accuracy: 0.8852
# Epoch 24/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2052 - accuracy: 0.9255 - val_loss: 0.3067 - val_accuracy: 0.8876
# Epoch 25/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2031 - accuracy: 0.9261 - val_loss: 0.3056 - val_accuracy: 0.8866

# %% [markdown]
# # Avoiding Overfitting Through Regularization

# %% [markdown]
# ## $\ell_1$ and $\ell_2$ regularization

# %%
layer = tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal",
                              kernel_regularizer=tf.keras.regularizers.l2(0.01))

# %% [markdown]
# Or use `l1(0.1)` for ℓ<sub>1</sub> regularization with a factor of 0.1, or `l1_l2(0.1, 0.01)` for both ℓ<sub>1</sub> and ℓ<sub>2</sub> regularization, with factors 0.1 and 0.01 respectively.

# %%
tf.random.set_seed(42)  # extra code – for reproducibility

# %%
from functools import partial

RegularizedDense = partial(tf.keras.layers.Dense,
                           activation="relu",
                           kernel_initializer="he_normal",
                           kernel_regularizer=tf.keras.regularizers.l2(0.01))

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    RegularizedDense(100),
    RegularizedDense(100),
    RegularizedDense(10, activation="softmax")
])

# %%
# extra code – compile and train the model
optimizer = tf.keras.optimizers.SGD(learning_rate=0.02)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=2,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/2
# 1719/1719 [==============================] - 3s 2ms/step - loss: 3.1391 - accuracy: 0.7723 - val_loss: 1.8666 - val_accuracy: 0.8238
# Epoch 2/2
# 1719/1719 [==============================] - 3s 2ms/step - loss: 1.4267 - accuracy: 0.8140 - val_loss: 1.1282 - val_accuracy: 0.8144

# %% [markdown]
# ## Dropout

# %%
tf.random.set_seed(42)  # extra code – for reproducibility

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
# extra code – compile and train the model
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.6691 - accuracy: 0.7567 - val_loss: 0.4449 - val_accuracy: 0.8344
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.5091 - accuracy: 0.8151 - val_loss: 0.4018 - val_accuracy: 0.8466
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4719 - accuracy: 0.8257 - val_loss: 0.4003 - val_accuracy: 0.8512
# Epoch 4/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4483 - accuracy: 0.8347 - val_loss: 0.3817 - val_accuracy: 0.8542
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4334 - accuracy: 0.8399 - val_loss: 0.3655 - val_accuracy: 0.8598
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4231 - accuracy: 0.8439 - val_loss: 0.3658 - val_accuracy: 0.8608
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4137 - accuracy: 0.8472 - val_loss: 0.3618 - val_accuracy: 0.8636
# Epoch 8/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4075 - accuracy: 0.8491 - val_loss: 0.3577 - val_accuracy: 0.8666
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4020 - accuracy: 0.8508 - val_loss: 0.3493 - val_accuracy: 0.8682
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3912 - accuracy: 0.8545 - val_loss: 0.3449 - val_accuracy: 0.8698

# %% [markdown]
# The training accuracy looks like it's lower than the validation accuracy, but that's just because dropout is only active during training. If we evaluate the model on the training set after training (i.e., with dropout turned off), we get the "real" training accuracy, which is very slightly higher than the validation accuracy and the test accuracy:

# %%
model.evaluate(X_train, y_train)
# Out:
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3098 - accuracy: 0.8842
# [0.30981647968292236, 0.8841636180877686]

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3654 - accuracy: 0.8664
# [0.3653510510921478, 0.8664000034332275]

# %% [markdown]
# **Note**: make sure to use `AlphaDropout` instead of `Dropout` if you want to build a self-normalizing neural net using SELU.

# %% [markdown]
# ## MC Dropout

# %%
tf.random.set_seed(42)  # extra code – for reproducibility

# %%
y_probas = np.stack([model(X_test, training=True)
                     for sample in range(100)])
y_proba = y_probas.mean(axis=0)

# %%
model.predict(X_test[:1]).round(3)
# Out:
# 1/1 [==============================] - 0s 67ms/step
# array([[0.   , 0.   , 0.   , 0.   , 0.   , 0.023, 0.   , 0.16 , 0.   ,
#         0.817]], dtype=float32)

# %%
y_proba[0].round(3)
# Out:
# array([0.   , 0.   , 0.   , 0.   , 0.   , 0.084, 0.   , 0.205, 0.001,
#        0.709], dtype=float32)

# %%
y_std = y_probas.std(axis=0)
y_std[0].round(3)
# Out:
# array([0.   , 0.001, 0.   , 0.001, 0.001, 0.114, 0.001, 0.157, 0.006,
#        0.186], dtype=float32)

# %%
y_pred = y_proba.argmax(axis=1)
accuracy = (y_pred == y_test).sum() / len(y_test)
accuracy
# Out:
# 0.8662

# %%
class MCDropout(tf.keras.layers.Dropout):
    def call(self, inputs, training=None):
        return super().call(inputs, training=True)

# %%
# extra code – shows how to convert Dropout to MCDropout in a Sequential model
Dropout = tf.keras.layers.Dropout
mc_model = tf.keras.Sequential([
    MCDropout(layer.rate) if isinstance(layer, Dropout) else layer
    for layer in model.layers
])
mc_model.set_weights(model.get_weights())

# %%
mc_model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_21 (Flatten)        (None, 784)               0
#
#  mc_dropout (MCDropout)      (None, 784)               0
#
#  dense_85 (Dense)            (None, 100)               78500
#
#  mc_dropout_1 (MCDropout)    (None, 100)               0
#
#  dense_86 (Dense)            (None, 100)               10100
#
#  mc_dropout_2 (MCDropout)    (None, 100)               0
#
#  dense_87 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 89,610
# Trainable params: 89,610
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now we can use the model with MC Dropout:

# %%
# extra code – shows that the model works without retraining
tf.random.set_seed(42)
np.mean([mc_model.predict(X_test[:1])
         for sample in range(100)], axis=0).round(2)
# Out:
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# array([[0.  , 0.  , 0.  , 0.  , 0.  , 0.1 , 0.  , 0.21, 0.  , 0.69]],
#       dtype=float32)

# %% [markdown]
# ## Max norm

# %%
dense = tf.keras.layers.Dense(
    100, activation="relu", kernel_initializer="he_normal",
    kernel_constraint=tf.keras.constraints.max_norm(1.))

# %%
# extra code – shows how to apply max norm to every hidden layer in a model

MaxNormDense = partial(tf.keras.layers.Dense,
                       activation="relu", kernel_initializer="he_normal",
                       kernel_constraint=tf.keras.constraints.max_norm(1.))

tf.random.set_seed(42)
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    MaxNormDense(100),
    MaxNormDense(100),
    tf.keras.layers.Dense(10, activation="softmax")
])
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.5440 - accuracy: 0.8044 - val_loss: 0.4248 - val_accuracy: 0.8390
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4098 - accuracy: 0.8500 - val_loss: 0.4060 - val_accuracy: 0.8450
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3780 - accuracy: 0.8608 - val_loss: 0.3637 - val_accuracy: 0.8698
# Epoch 4/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3630 - accuracy: 0.8673 - val_loss: 0.3578 - val_accuracy: 0.8684
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3479 - accuracy: 0.8712 - val_loss: 0.3668 - val_accuracy: 0.8606
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3416 - accuracy: 0.8749 - val_loss: 0.4048 - val_accuracy: 0.8524
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3329 - accuracy: 0.8758 - val_loss: 0.3864 - val_accuracy: 0.8562
# Epoch 8/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3347 - accuracy: 0.8753 - val_loss: 0.3548 - val_accuracy: 0.8686
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3303 - accuracy: 0.8783 - val_loss: 0.3663 - val_accuracy: 0.8604
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3232 - accuracy: 0.8798 - val_loss: 0.3955 - val_accuracy: 0.8552

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1. to 7.

# %% [markdown]
# 1. Glorot initialization and He initialization were designed to make the output standard deviation as close as possible to the input standard deviation, at least at the beginning of training. This reduces the vanishing/exploding gradients problem.
# 2. No, all weights should be sampled independently; they should not all have the same initial value. One important goal of sampling weights randomly is to break symmetry: if all the weights have the same initial value, even if that value is not zero, then symmetry is not broken (i.e., all neurons in a given layer are equivalent), and backpropagation will be unable to break it. Concretely, this means that all the neurons in any given layer will always have the same weights. It's like having just one neuron per layer, and much slower. It is virtually impossible for such a configuration to converge to a good solution.
# 3. It is perfectly fine to initialize the bias terms to zero. Some people like to initialize them just like weights, and that's OK too; it does not make much difference.
# 4. ReLU is usually a good default for the hidden layers, as it is fast and yields good results. Its ability to output precisely zero can also be useful in some cases (e.g., see Chapter 17). Moreover, it can sometimes benefit from optimized implementations as well as from hardware acceleration. The leaky ReLU variants of ReLU can improve the model's quality without hindering its speed too much compared to ReLU. For large neural nets and more complex problems, GLU, Swish and Mish can give you a slightly higher quality model, but they have a computational cost. The hyperbolic tangent (tanh) can be useful in the output layer if you need to output a number in a fixed range (by default between –1 and 1), but nowadays it is not used much in hidden layers, except in recurrent nets. The sigmoid activation function is also useful in the output layer when you need to estimate a probability (e.g., for binary classification), but it is rarely used in hidden layers (there are exceptions—for example, for the coding layer of variational autoencoders; see Chapter 17). The softplus activation function is useful in the output layer when you need to ensure that the output will always be positive. The softmax activation function is useful in the output layer to estimate probabilities for mutually exclusive classes, but it is rarely (if ever) used in hidden layers.
# 5. If you set the `momentum` hyperparameter too close to 1 (e.g., 0.99999) when using an `SGD` optimizer, then the algorithm will likely pick up a lot of speed, hopefully moving roughly toward the global minimum, but its momentum will carry it right past the minimum. Then it will slow down and come back, accelerate again, overshoot again, and so on. It may oscillate this way many times before converging, so overall it will take much longer to converge than with a smaller `momentum` value.
# 6. One way to produce a sparse model (i.e., with most weights equal to zero) is to train the model normally, then zero out tiny weights. For more sparsity, you can apply ℓ<sub>1</sub> regularization during training, which pushes the optimizer toward sparsity. A third option is to use the TensorFlow Model Optimization Toolkit.
# 7. Yes, dropout does slow down training, in general roughly by a factor of two. However, it has no impact on inference speed since it is only turned on during training. MC Dropout is exactly like dropout during training, but it is still active during inference, so each inference is slowed down slightly. More importantly, when using MC Dropout you generally want to run inference 10 times or more to get better predictions. This means that making predictions is slowed down by a factor of 10 or more.

# %% [markdown]
# ## 8. Deep Learning on CIFAR10

# %% [markdown]
# ### a.
# *Exercise: Build a DNN with 20 hidden layers of 100 neurons each (that's too many, but it's the point of this exercise). Use He initialization and the Swish activation function.*

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                    activation="swish",
                                    kernel_initializer="he_normal"))

# %% [markdown]
# ### b.
# *Exercise: Using Nadam optimization and early stopping, train the network on the CIFAR10 dataset. You can load it with `tf.keras.datasets.cifar10.load_data()`. The dataset is composed of 60,000 32 × 32–pixel color images (50,000 for training, 10,000 for testing) with 10 classes, so you'll need a softmax output layer with 10 neurons. Remember to search for the right learning rate each time you change the model's architecture or hyperparameters.*

# %% [markdown]
# Let's add the output layer to the model:

# %%
model.add(tf.keras.layers.Dense(10, activation="softmax"))

# %% [markdown]
# Let's use a Nadam optimizer with a learning rate of 5e-5. I tried learning rates 1e-5, 3e-5, 1e-4, 3e-4, 1e-3, 3e-3 and 1e-2, and I compared their learning curves for 10 epochs each (using the TensorBoard callback, below). The learning rates 3e-5 and 1e-4 were pretty good, so I tried 5e-5, which turned out to be slightly better.

# %%
optimizer = tf.keras.optimizers.Nadam(learning_rate=5e-5)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

# %% [markdown]
# Let's load the CIFAR10 dataset. We also want to use early stopping, so we need a validation set. Let's use the first 5,000 images of the original training set as the validation set:

# %%
cifar10 = tf.keras.datasets.cifar10.load_data()
(X_train_full, y_train_full), (X_test, y_test) = cifar10

X_train = X_train_full[5000:]
y_train = y_train_full[5000:]
X_valid = X_train_full[:5000]
y_valid = y_train_full[:5000]

# %% [markdown]
# Now we can create the callbacks we need and train the model:

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=20,
                                                     restore_best_weights=True)
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("my_cifar10_model",
                                                         save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = Path() / "my_cifar10_logs" / f"run_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./my_cifar10_logs
# Out:
#       <iframe id="tensorboard-frame-8e5121b1b00d4966" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8e5121b1b00d4966");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model.fit(X_train, y_train, epochs=100,
          validation_data=(X_valid, y_valid),
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 4.1410 - accuracy: 0.1475INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 15s 9ms/step - loss: 4.1370 - accuracy: 0.1478 - val_loss: 2.4313 - val_accuracy: 0.1708
# Epoch 2/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 2.1484 - accuracy: 0.2161INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 2.1481 - accuracy: 0.2162 - val_loss: 2.4155 - val_accuracy: 0.1934
# Epoch 3/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 2.0118 - accuracy: 0.2599INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 2.0117 - accuracy: 0.2600 - val_loss: 2.0261 - val_accuracy: 0.2442
# Epoch 4/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 1.9340 - accuracy: 0.2869INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.9340 - accuracy: 0.2870 - val_loss: 1.9368 - val_accuracy: 0.3004
# Epoch 5/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.8698 - accuracy: 0.3124INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.8695 - accuracy: 0.3126 - val_loss: 1.8326 - val_accuracy: 0.3240
# Epoch 6/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.8181 - accuracy: 0.3376 - val_loss: 1.8414 - val_accuracy: 0.3250
# Epoch 7/100
# 1400/1407 [============================>.] - ETA: 0s - loss: 1.7728 - accuracy: 0.3558INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.7727 - accuracy: 0.3558 - val_loss: 1.7933 - val_accuracy: 0.3336
# Epoch 8/100
# 1407/1407 [==============================] - ETA: 0s - loss: 1.7352 - accuracy: 0.3683INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.7352 - accuracy: 0.3683 - val_loss: 1.7326 - val_accuracy: 0.3706
# Epoch 9/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.7074 - accuracy: 0.3823 - val_loss: 1.7463 - val_accuracy: 0.3672
# Epoch 10/100
# 1400/1407 [============================>.] - ETA: 0s - loss: 1.6795 - accuracy: 0.3930INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.6794 - accuracy: 0.3932 - val_loss: 1.7003 - val_accuracy: 0.3846
# Epoch 11/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.6503 - accuracy: 0.4010INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.6501 - accuracy: 0.4010 - val_loss: 1.6880 - val_accuracy: 0.3800
# Epoch 12/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 1.6308 - accuracy: 0.4107INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.6307 - accuracy: 0.4108 - val_loss: 1.6618 - val_accuracy: 0.3990
# Epoch 13/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.6121 - accuracy: 0.4162 - val_loss: 1.6654 - val_accuracy: 0.3884
# Epoch 14/100
# 1407/1407 [==============================] - ETA: 0s - loss: 1.5945 - accuracy: 0.4265INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.5945 - accuracy: 0.4265 - val_loss: 1.6205 - val_accuracy: 0.4140
# Epoch 15/100
# 1407/1407 [==============================] - ETA: 0s - loss: 1.5780 - accuracy: 0.4294INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 12s 9ms/step - loss: 1.5780 - accuracy: 0.4294 - val_loss: 1.6026 - val_accuracy: 0.4190
# Epoch 16/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5616 - accuracy: 0.4392 - val_loss: 1.6323 - val_accuracy: 0.4174
# Epoch 17/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.5457 - accuracy: 0.4430INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.5456 - accuracy: 0.4430 - val_loss: 1.5881 - val_accuracy: 0.4326
# Epoch 18/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5341 - accuracy: 0.4513 - val_loss: 1.6248 - val_accuracy: 0.4218
# Epoch 19/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5245 - accuracy: 0.4518 - val_loss: 1.5963 - val_accuracy: 0.4254
# Epoch 20/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5082 - accuracy: 0.4593 - val_loss: 1.5892 - val_accuracy: 0.4352
# Epoch 21/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 1.4972 - accuracy: 0.4627INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.4971 - accuracy: 0.4627 - val_loss: 1.5653 - val_accuracy: 0.4376
# Epoch 22/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4857 - accuracy: 0.4653 - val_loss: 1.5883 - val_accuracy: 0.4346
# Epoch 23/100
# 1407/1407 [==============================] - 9s 7ms/step - loss: 1.4738 - accuracy: 0.4700 - val_loss: 1.5969 - val_accuracy: 0.4332
# Epoch 24/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4619 - accuracy: 0.4729 - val_loss: 1.5969 - val_accuracy: 0.4280
# Epoch 25/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 1.4534 - accuracy: 0.4780INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.4535 - accuracy: 0.4780 - val_loss: 1.5579 - val_accuracy: 0.4450
# Epoch 26/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4420 - accuracy: 0.4822 - val_loss: 1.5828 - val_accuracy: 0.4344
# Epoch 27/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.4299 - accuracy: 0.4885INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.4297 - accuracy: 0.4886 - val_loss: 1.5435 - val_accuracy: 0.4520
# Epoch 28/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4243 - accuracy: 0.4889 - val_loss: 1.5461 - val_accuracy: 0.4522
# Epoch 29/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 1.4149 - accuracy: 0.4916INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.4150 - accuracy: 0.4915 - val_loss: 1.5336 - val_accuracy: 0.4636
# Epoch 30/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4037 - accuracy: 0.4957 - val_loss: 1.6265 - val_accuracy: 0.4358
# Epoch 31/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3983 - accuracy: 0.4981 - val_loss: 1.5693 - val_accuracy: 0.4398
# Epoch 32/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3895 - accuracy: 0.5012 - val_loss: 1.5531 - val_accuracy: 0.4556
# Epoch 33/100
# 1407/1407 [==============================] - 9s 7ms/step - loss: 1.3793 - accuracy: 0.5062 - val_loss: 1.5410 - val_accuracy: 0.4602
# Epoch 34/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 1.3738 - accuracy: 0.5055INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.3738 - accuracy: 0.5055 - val_loss: 1.5321 - val_accuracy: 0.4600
# Epoch 35/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.3646 - accuracy: 0.5088 - val_loss: 1.5751 - val_accuracy: 0.4504
# Epoch 36/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.3598 - accuracy: 0.5101 - val_loss: 1.5351 - val_accuracy: 0.4592
# Epoch 37/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.3491 - accuracy: 0.5167 - val_loss: 1.5410 - val_accuracy: 0.4644
# Epoch 38/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.3408 - accuracy: 0.5183 - val_loss: 1.5411 - val_accuracy: 0.4560
# Epoch 39/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.3362 - accuracy: 0.5188 - val_loss: 1.5547 - val_accuracy: 0.4412
# Epoch 40/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.3264 - accuracy: 0.5233 - val_loss: 1.5986 - val_accuracy: 0.4486
# Epoch 41/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.3226 - accuracy: 0.5268 - val_loss: 1.5692 - val_accuracy: 0.4510
# Epoch 42/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.3143 - accuracy: 0.5304 - val_loss: 1.5467 - val_accuracy: 0.4610
# Epoch 43/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.3075 - accuracy: 0.5310 - val_loss: 1.5425 - val_accuracy: 0.4632
# Epoch 44/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2989 - accuracy: 0.5362 - val_loss: 1.5857 - val_accuracy: 0.4526
# Epoch 45/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.2934 - accuracy: 0.5344INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.2936 - accuracy: 0.5343 - val_loss: 1.5108 - val_accuracy: 0.4646
# Epoch 46/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2867 - accuracy: 0.5378 - val_loss: 1.5352 - val_accuracy: 0.4658
# Epoch 47/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2802 - accuracy: 0.5391 - val_loss: 1.5460 - val_accuracy: 0.4586
# Epoch 48/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2727 - accuracy: 0.5432 - val_loss: 1.5683 - val_accuracy: 0.4576
# Epoch 49/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2655 - accuracy: 0.5459 - val_loss: 1.5412 - val_accuracy: 0.4596
# Epoch 50/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2598 - accuracy: 0.5475 - val_loss: 1.5797 - val_accuracy: 0.4590
# Epoch 51/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2566 - accuracy: 0.5468 - val_loss: 1.5750 - val_accuracy: 0.4600
# Epoch 52/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2478 - accuracy: 0.5510 - val_loss: 1.5958 - val_accuracy: 0.4586
# Epoch 53/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2429 - accuracy: 0.5567 - val_loss: 1.5628 - val_accuracy: 0.4584
# Epoch 54/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2358 - accuracy: 0.5538 - val_loss: 1.5481 - val_accuracy: 0.4656
# Epoch 55/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2294 - accuracy: 0.5593 - val_loss: 1.5648 - val_accuracy: 0.4556
# Epoch 56/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2214 - accuracy: 0.5623 - val_loss: 1.5784 - val_accuracy: 0.4566
# Epoch 57/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2171 - accuracy: 0.5626 - val_loss: 1.5446 - val_accuracy: 0.4680
# Epoch 58/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2112 - accuracy: 0.5665 - val_loss: 1.5698 - val_accuracy: 0.4600
# Epoch 59/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2073 - accuracy: 0.5659 - val_loss: 1.5483 - val_accuracy: 0.4590
# Epoch 60/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.1967 - accuracy: 0.5702 - val_loss: 1.5897 - val_accuracy: 0.4612
# Epoch 61/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.1940 - accuracy: 0.5717 - val_loss: 1.5885 - val_accuracy: 0.4520
# Epoch 62/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.1898 - accuracy: 0.5739 - val_loss: 1.5856 - val_accuracy: 0.4608
# Epoch 63/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.1805 - accuracy: 0.5767 - val_loss: 1.5687 - val_accuracy: 0.4602
# Epoch 64/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.1733 - accuracy: 0.5799 - val_loss: 1.5871 - val_accuracy: 0.4596
# Epoch 65/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.1696 - accuracy: 0.5777 - val_loss: 1.5929 - val_accuracy: 0.4606

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 157/157 [==============================] - 0s 2ms/step - loss: 1.5108 - accuracy: 0.4646
# [1.5107558965682983, 0.46459999680519104]

# %% [markdown]
# The model with the lowest validation loss gets about 46.8% accuracy on the validation set. It took 29 epochs to reach the lowest validation loss, with roughly 10 seconds per epoch on my laptop (without a GPU). Let's see if we can improve the model using Batch Normalization.

# %% [markdown]
# ### c.
# *Exercise: Now try adding Batch Normalization and compare the learning curves: Is it converging faster than before? Does it produce a better model? How does it affect training speed?*

# %% [markdown]
# The code below is very similar to the code above, with a few changes:
#
# * I added a BN layer after every Dense layer (before the activation function), except for the output layer.
# * I changed the learning rate to 5e-4. I experimented with 1e-5, 3e-5, 5e-5, 1e-4, 3e-4, 5e-4, 1e-3 and 3e-3, and I chose the one with the best validation performance after 20 epochs.
# * I renamed the run directories to run_bn_* and the model file name to `my_cifar10_bn_model`.

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100, kernel_initializer="he_normal"))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation("swish"))

model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.Nadam(learning_rate=5e-4)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=20,
                                                     restore_best_weights=True)
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("my_cifar10_bn_model",
                                                         save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = Path() / "my_cifar10_logs" / f"run_bn_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

model.fit(X_train, y_train, epochs=100,
          validation_data=(X_valid, y_valid),
          callbacks=callbacks)

model.evaluate(X_valid, y_valid)
# Out:
# Epoch 1/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 2.0357 - accuracy: 0.2592INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 33s 19ms/step - loss: 2.0355 - accuracy: 0.2593 - val_loss: 1.9337 - val_accuracy: 0.3008
# Epoch 2/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.7788 - accuracy: 0.3603INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 27s 19ms/step - loss: 1.7788 - accuracy: 0.3604 - val_loss: 1.7994 - val_accuracy: 0.3360
# Epoch 3/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.6744 - accuracy: 0.4040 - val_loss: 2.1873 - val_accuracy: 0.2958
# Epoch 4/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 1.6103 - accuracy: 0.4289INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 27s 19ms/step - loss: 1.6107 - accuracy: 0.4289 - val_loss: 1.7670 - val_accuracy: 0.3722
# Epoch 5/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.5500 - accuracy: 0.4493INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 27s 19ms/step - loss: 1.5500 - accuracy: 0.4493 - val_loss: 1.6115 - val_accuracy: 0.4266
# Epoch 6/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.5021 - accuracy: 0.4659 - val_loss: 1.6501 - val_accuracy: 0.4048
# Epoch 7/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 1.4538 - accuracy: 0.4817INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 27s 19ms/step - loss: 1.4539 - accuracy: 0.4817 - val_loss: 1.5763 - val_accuracy: 0.4322
# Epoch 8/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.4173 - accuracy: 0.4984 - val_loss: 1.5792 - val_accuracy: 0.4408
# Epoch 9/100
# 1407/1407 [==============================] - ETA: 0s - loss: 1.3873 - accuracy: 0.5115INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 27s 19ms/step - loss: 1.3873 - accuracy: 0.5115 - val_loss: 1.4915 - val_accuracy: 0.4640
# Epoch 10/100
# 1407/1407 [==============================] - 20s 15ms/step - loss: 1.3569 - accuracy: 0.5194 - val_loss: 1.5472 - val_accuracy: 0.4502
# Epoch 11/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.3291 - accuracy: 0.5294 - val_loss: 1.4961 - val_accuracy: 0.4724
# Epoch 12/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.2990 - accuracy: 0.5393 - val_loss: 1.6491 - val_accuracy: 0.4282
# Epoch 13/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.2744 - accuracy: 0.5452 - val_loss: 1.7838 - val_accuracy: 0.4012
# Epoch 14/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 1.2526 - accuracy: 0.5562INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 27s 20ms/step - loss: 1.2525 - accuracy: 0.5563 - val_loss: 1.4481 - val_accuracy: 0.4878
# Epoch 15/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.2301 - accuracy: 0.5646 - val_loss: 1.5442 - val_accuracy: 0.4724
# Epoch 16/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.2110 - accuracy: 0.5709 - val_loss: 1.4934 - val_accuracy: 0.4792
# Epoch 17/100
# 1407/1407 [==============================] - ETA: 0s - loss: 1.1911 - accuracy: 0.5782INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 28s 20ms/step - loss: 1.1911 - accuracy: 0.5782 - val_loss: 1.4324 - val_accuracy: 0.5046
# Epoch 18/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.1682 - accuracy: 0.5864 - val_loss: 1.5847 - val_accuracy: 0.4540
# Epoch 19/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.1562 - accuracy: 0.5888 - val_loss: 1.6717 - val_accuracy: 0.4400
# Epoch 20/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.1388 - accuracy: 0.5973 - val_loss: 1.7147 - val_accuracy: 0.4326
# Epoch 21/100
# 1407/1407 [==============================] - 20s 15ms/step - loss: 1.1199 - accuracy: 0.6042 - val_loss: 1.6704 - val_accuracy: 0.4574
# Epoch 22/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.1001 - accuracy: 0.6099 - val_loss: 1.4604 - val_accuracy: 0.4868
# Epoch 23/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.0896 - accuracy: 0.6155 - val_loss: 1.4965 - val_accuracy: 0.4852
# Epoch 24/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.0741 - accuracy: 0.6206 - val_loss: 1.6179 - val_accuracy: 0.4582
# Epoch 25/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.0596 - accuracy: 0.6256 - val_loss: 1.5069 - val_accuracy: 0.4864
# Epoch 26/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.0471 - accuracy: 0.6319 - val_loss: 1.4998 - val_accuracy: 0.4834
# Epoch 27/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.0292 - accuracy: 0.6351 - val_loss: 1.6454 - val_accuracy: 0.4584
# Epoch 28/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.0226 - accuracy: 0.6410 - val_loss: 1.7100 - val_accuracy: 0.4590
# Epoch 29/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.0165 - accuracy: 0.6420 - val_loss: 1.5072 - val_accuracy: 0.4904
# Epoch 30/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.0012 - accuracy: 0.6458 - val_loss: 1.4990 - val_accuracy: 0.5024
# Epoch 31/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.9860 - accuracy: 0.6523 - val_loss: 1.5272 - val_accuracy: 0.4924
# Epoch 32/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.9793 - accuracy: 0.6541 - val_loss: 1.6833 - val_accuracy: 0.4532
# Epoch 33/100
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.9678 - accuracy: 0.6583 - val_loss: 1.6907 - val_accuracy: 0.4652
# Epoch 34/100
# 1407/1407 [==============================] - 20s 15ms/step - loss: 0.9629 - accuracy: 0.6596 - val_loss: 1.5936 - val_accuracy: 0.4772
# Epoch 35/100
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.9474 - accuracy: 0.6652 - val_loss: 1.5031 - val_accuracy: 0.4960
# Epoch 36/100
# 1407/1407 [==============================] - 20s 15ms/step - loss: 0.9395 - accuracy: 0.6683 - val_loss: 1.5732 - val_accuracy: 0.4892
# Epoch 37/100
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.9221 - accuracy: 0.6740 - val_loss: 1.6236 - val_accuracy: 0.4816
# 157/157 [==============================] - 0s 3ms/step - loss: 1.4324 - accuracy: 0.5046
# [1.4324462413787842, 0.5045999884605408]

# %% [markdown]
# * *Is the model converging faster than before?* Much faster! The previous model took 29 epochs to reach the lowest validation loss, while the new model achieved that same loss in just 12 epochs and continued to make progress until the 17th epoch. The BN layers stabilized training and allowed us to use a much larger learning rate, so convergence was faster.
# * *Does BN produce a better model?* Yes! The final model is also much better, with 50.7% validation accuracy instead of 46.7%. It's still not a very good model, but at least it's much better than before (a Convolutional Neural Network would do much better, but that's a different topic, see chapter 14).
# * *How does BN affect training speed?* Although the model converged much faster, each epoch took about 15s instead of 10s, because of the extra computations required by the BN layers. But overall the training time (wall time) to reach the best model was shortened by about 10%.

# %% [markdown]
# ### d.
# *Exercise: Try replacing Batch Normalization with SELU, and make the necessary adjustements to ensure the network self-normalizes (i.e., standardize the input features, use LeCun normal initialization, make sure the DNN contains only a sequence of dense layers, etc.).*

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                    kernel_initializer="lecun_normal",
                                    activation="selu"))

model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.Nadam(learning_rate=7e-4)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    patience=20, restore_best_weights=True)
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    "my_cifar10_selu_model", save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = Path() / "my_cifar10_logs" / f"run_selu_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

X_means = X_train.mean(axis=0)
X_stds = X_train.std(axis=0)
X_train_scaled = (X_train - X_means) / X_stds
X_valid_scaled = (X_valid - X_means) / X_stds
X_test_scaled = (X_test - X_means) / X_stds

model.fit(X_train_scaled, y_train, epochs=100,
          validation_data=(X_valid_scaled, y_valid),
          callbacks=callbacks)

model.evaluate(X_valid_scaled, y_valid)
# Out:
# Epoch 1/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 1.9259 - accuracy: 0.3110INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 12s 7ms/step - loss: 1.9254 - accuracy: 0.3110 - val_loss: 1.8316 - val_accuracy: 0.3424
# Epoch 2/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 1.6972 - accuracy: 0.4000INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.6970 - accuracy: 0.4000 - val_loss: 1.7624 - val_accuracy: 0.3742
# Epoch 3/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.5978 - accuracy: 0.4364INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5978 - accuracy: 0.4364 - val_loss: 1.6701 - val_accuracy: 0.4108
# Epoch 4/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.5333 - accuracy: 0.4598INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5333 - accuracy: 0.4598 - val_loss: 1.6425 - val_accuracy: 0.4398
# Epoch 5/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 1.4790 - accuracy: 0.4776INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.4791 - accuracy: 0.4775 - val_loss: 1.5957 - val_accuracy: 0.4404
# Epoch 6/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 1.4343 - accuracy: 0.4973INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4344 - accuracy: 0.4972 - val_loss: 1.5384 - val_accuracy: 0.4598
# Epoch 7/100
# 1398/1407 [============================>.] - ETA: 0s - loss: 1.3855 - accuracy: 0.5151INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3852 - accuracy: 0.5154 - val_loss: 1.5043 - val_accuracy: 0.4824
# Epoch 8/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 1.3468 - accuracy: 0.5274INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3468 - accuracy: 0.5274 - val_loss: 1.4781 - val_accuracy: 0.4880
# Epoch 9/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3173 - accuracy: 0.5416 - val_loss: 1.5039 - val_accuracy: 0.4698
# Epoch 10/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2900 - accuracy: 0.5494 - val_loss: 1.5167 - val_accuracy: 0.4878
# Epoch 11/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2651 - accuracy: 0.5624 - val_loss: 1.4793 - val_accuracy: 0.4958
# Epoch 12/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 1.2273 - accuracy: 0.5739INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.2276 - accuracy: 0.5738 - val_loss: 1.4581 - val_accuracy: 0.4984
# Epoch 13/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2079 - accuracy: 0.5803 - val_loss: 1.4888 - val_accuracy: 0.5046
# Epoch 14/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2542 - accuracy: 0.5630 - val_loss: 1.4817 - val_accuracy: 0.4900
# Epoch 15/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.1609 - accuracy: 0.5950 - val_loss: 1.5274 - val_accuracy: 0.5006
# Epoch 16/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.1330 - accuracy: 0.6058 - val_loss: 1.4691 - val_accuracy: 0.5064
# Epoch 17/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.1252 - accuracy: 0.6102 - val_loss: 1.5099 - val_accuracy: 0.4934
# Epoch 18/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.1002 - accuracy: 0.6231 - val_loss: 1.4807 - val_accuracy: 0.5026
# Epoch 19/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.0832 - accuracy: 0.6264 - val_loss: 1.5391 - val_accuracy: 0.5060
# Epoch 20/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.0675 - accuracy: 0.6335 - val_loss: 1.5272 - val_accuracy: 0.5072
# Epoch 21/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.0465 - accuracy: 0.6401 - val_loss: 1.5522 - val_accuracy: 0.5066
# Epoch 22/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.0241 - accuracy: 0.6501 - val_loss: 1.5006 - val_accuracy: 0.5102
# Epoch 23/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.0156 - accuracy: 0.6525 - val_loss: 1.5273 - val_accuracy: 0.4950
# Epoch 24/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.9885 - accuracy: 0.6656 - val_loss: 1.5261 - val_accuracy: 0.5152
# Epoch 25/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.9829 - accuracy: 0.6646 - val_loss: 1.5965 - val_accuracy: 0.5104
# Epoch 26/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.9609 - accuracy: 0.6742 - val_loss: 1.6023 - val_accuracy: 0.5144
# Epoch 27/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.9453 - accuracy: 0.6787 - val_loss: 1.5556 - val_accuracy: 0.5010
# Epoch 28/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.9341 - accuracy: 0.6846 - val_loss: 1.6055 - val_accuracy: 0.5016
# Epoch 29/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.9227 - accuracy: 0.6858 - val_loss: 1.6320 - val_accuracy: 0.5112
# Epoch 30/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.9041 - accuracy: 0.6930 - val_loss: 1.6560 - val_accuracy: 0.5010
# Epoch 31/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.8932 - accuracy: 0.6965 - val_loss: 1.5774 - val_accuracy: 0.5080
# Epoch 32/100
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.8728 - accuracy: 0.7065 - val_loss: 1.6704 - val_accuracy: 0.5044
# 157/157 [==============================] - 0s 2ms/step - loss: 1.4581 - accuracy: 0.4984
# [1.4581472873687744, 0.4984000027179718]

# %% [markdown]
# This model reached the first model's validation loss in just 8 epochs. After 14 epochs, it reached its lowest validation loss, with about 50.3% accuracy, which is better than the original model (46.7%), but not quite as good as the model using batch normalization (50.7%). Each epoch took only 9 seconds. So it's the fastest model to train so far.

# %% [markdown]
# ### e.
# *Exercise: Try regularizing the model with alpha dropout. Then, without retraining your model, see if you can achieve better accuracy using MC Dropout.*

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                    kernel_initializer="lecun_normal",
                                    activation="selu"))

model.add(tf.keras.layers.AlphaDropout(rate=0.1))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.Nadam(learning_rate=5e-4)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    patience=20, restore_best_weights=True)
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    "my_cifar10_alpha_dropout_model", save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = Path() / "my_cifar10_logs" / f"run_alpha_dropout_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

X_means = X_train.mean(axis=0)
X_stds = X_train.std(axis=0)
X_train_scaled = (X_train - X_means) / X_stds
X_valid_scaled = (X_valid - X_means) / X_stds
X_test_scaled = (X_test - X_means) / X_stds

model.fit(X_train_scaled, y_train, epochs=100,
          validation_data=(X_valid_scaled, y_valid),
          callbacks=callbacks)

model.evaluate(X_valid_scaled, y_valid)
# Out:
# Epoch 1/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 1.9036 - accuracy: 0.3226INFO:tensorflow:Assets written to: my_cifar10_alpha_dropout_model/assets
# 1407/1407 [==============================] - 13s 8ms/step - loss: 1.9030 - accuracy: 0.3228 - val_loss: 1.7890 - val_accuracy: 0.3762
# Epoch 2/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 1.6701 - accuracy: 0.4098INFO:tensorflow:Assets written to: my_cifar10_alpha_dropout_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.6701 - accuracy: 0.4098 - val_loss: 1.6604 - val_accuracy: 0.4110
# Epoch 3/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.5780 - accuracy: 0.4457 - val_loss: 1.6757 - val_accuracy: 0.4130
# Epoch 4/100
# 1407/1407 [==============================] - ETA: 0s - loss: 1.5088 - accuracy: 0.4700INFO:tensorflow:Assets written to: my_cifar10_alpha_dropout_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5088 - accuracy: 0.4700 - val_loss: 1.5768 - val_accuracy: 0.4436
# Epoch 5/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.4471 - accuracy: 0.4942INFO:tensorflow:Assets written to: my_cifar10_alpha_dropout_model/assets
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.4470 - accuracy: 0.4942 - val_loss: 1.5579 - val_accuracy: 0.4656
# Epoch 6/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 1.4008 - accuracy: 0.5109INFO:tensorflow:Assets written to: my_cifar10_alpha_dropout_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4009 - accuracy: 0.5108 - val_loss: 1.5207 - val_accuracy: 0.4762
# Epoch 7/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.3586 - accuracy: 0.5237 - val_loss: 1.5593 - val_accuracy: 0.4792
# Epoch 8/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.3148 - accuracy: 0.5431 - val_loss: 1.5533 - val_accuracy: 0.4852
# Epoch 9/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 1.2771 - accuracy: 0.5563INFO:tensorflow:Assets written to: my_cifar10_alpha_dropout_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.2767 - accuracy: 0.5564 - val_loss: 1.4958 - val_accuracy: 0.4936
# Epoch 10/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2445 - accuracy: 0.5683 - val_loss: 1.5884 - val_accuracy: 0.5004
# Epoch 11/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.2078 - accuracy: 0.5835 - val_loss: 1.5401 - val_accuracy: 0.4928
# Epoch 12/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.1786 - accuracy: 0.5925 - val_loss: 1.5151 - val_accuracy: 0.5052
# Epoch 13/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.1439 - accuracy: 0.6057 - val_loss: 1.5928 - val_accuracy: 0.5010
# Epoch 14/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.1233 - accuracy: 0.6123 - val_loss: 1.5523 - val_accuracy: 0.5034
# Epoch 15/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.0900 - accuracy: 0.6256 - val_loss: 1.6185 - val_accuracy: 0.4990
# Epoch 16/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.0680 - accuracy: 0.6333 - val_loss: 1.6129 - val_accuracy: 0.4990
# Epoch 17/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.0466 - accuracy: 0.6411 - val_loss: 1.6016 - val_accuracy: 0.5098
# Epoch 18/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.0159 - accuracy: 0.6539 - val_loss: 1.6452 - val_accuracy: 0.5148
# Epoch 19/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.9990 - accuracy: 0.6617 - val_loss: 1.7529 - val_accuracy: 0.5024
# Epoch 20/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.9801 - accuracy: 0.6654 - val_loss: 1.6231 - val_accuracy: 0.5182
# Epoch 21/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.9534 - accuracy: 0.6759 - val_loss: 1.6961 - val_accuracy: 0.5184
# Epoch 22/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.9367 - accuracy: 0.6817 - val_loss: 1.7459 - val_accuracy: 0.5116
# Epoch 23/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.9208 - accuracy: 0.6871 - val_loss: 1.6667 - val_accuracy: 0.5086
# Epoch 24/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.9015 - accuracy: 0.6944 - val_loss: 1.7413 - val_accuracy: 0.5086
# Epoch 25/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.8919 - accuracy: 0.6963 - val_loss: 1.7549 - val_accuracy: 0.5136
# Epoch 26/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.8666 - accuracy: 0.7077 - val_loss: 1.7912 - val_accuracy: 0.5104
# Epoch 27/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.8520 - accuracy: 0.7095 - val_loss: 1.8520 - val_accuracy: 0.5166
# Epoch 28/100
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.8351 - accuracy: 0.7180 - val_loss: 1.8097 - val_accuracy: 0.5054
# Epoch 29/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.8298 - accuracy: 0.7204 - val_loss: 1.9056 - val_accuracy: 0.4992
# 157/157 [==============================] - 0s 2ms/step - loss: 1.4958 - accuracy: 0.4936
# [1.4958304166793823, 0.4936000108718872]

# %% [markdown]
# The model reaches 48.1% accuracy on the validation set. That's worse than without dropout (50.3%). With an extensive hyperparameter search, it might be possible to do better (I tried dropout rates of 5%, 10%, 20% and 40%, and learning rates 1e-4, 3e-4, 5e-4, and 1e-3), but probably not much better in this case.

# %% [markdown]
# Let's use MC Dropout now. We will need the `MCAlphaDropout` class we used earlier, so let's just copy it here for convenience:

# %%
class MCAlphaDropout(tf.keras.layers.AlphaDropout):
    def call(self, inputs):
        return super().call(inputs, training=True)

# %% [markdown]
# Now let's create a new model, identical to the one we just trained (with the same weights), but with `MCAlphaDropout` dropout layers instead of `AlphaDropout` layers:

# %%
mc_model = tf.keras.Sequential([
    (
        MCAlphaDropout(layer.rate)
        if isinstance(layer, tf.keras.layers.AlphaDropout)
        else layer
    )
    for layer in model.layers
])

# %% [markdown]
# Then let's add a couple utility functions. The first will run the model many times (10 by default) and it will return the mean predicted class probabilities. The second will use these mean probabilities to predict the most likely class for each instance:

# %%
def mc_dropout_predict_probas(mc_model, X, n_samples=10):
    Y_probas = [mc_model.predict(X) for sample in range(n_samples)]
    return np.mean(Y_probas, axis=0)

def mc_dropout_predict_classes(mc_model, X, n_samples=10):
    Y_probas = mc_dropout_predict_probas(mc_model, X, n_samples)
    return Y_probas.argmax(axis=1)

# %% [markdown]
# Now let's make predictions for all the instances in the validation set, and compute the accuracy:

# %%
tf.random.set_seed(42)

y_pred = mc_dropout_predict_classes(mc_model, X_valid_scaled)
accuracy = (y_pred == y_valid[:, 0]).mean()
accuracy
# Out:
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# 0.4916

# %% [markdown]
# We get back to roughly the accuracy of the model without dropout in this case (about 50.3% accuracy).
#
# So the best model we got in this exercise is the Batch Normalization model.

# %% [markdown]
# ### f.
# *Exercise: Retrain your model using 1cycle scheduling and see if it improves training speed and model accuracy.*

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                    kernel_initializer="lecun_normal",
                                    activation="selu"))

model.add(tf.keras.layers.AlphaDropout(rate=0.1))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.SGD()
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

# %%
batch_size = 128
rates, losses = find_learning_rate(model, X_train_scaled, y_train, epochs=1,
                                   batch_size=batch_size)
plot_lr_vs_loss(rates, losses)
# Out:
# 352/352 [==============================] - 2s 4ms/step - loss: nan - accuracy: 0.1706

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                 kernel_initializer="lecun_normal",
                                 activation="selu"))

model.add(tf.keras.layers.AlphaDropout(rate=0.1))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.SGD(learning_rate=2e-2)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

# %%
n_epochs = 15
n_iterations = math.ceil(len(X_train_scaled) / batch_size) * n_epochs
onecycle = OneCycleScheduler(n_iterations, max_lr=0.05)
history = model.fit(X_train_scaled, y_train, epochs=n_epochs, batch_size=batch_size,
                    validation_data=(X_valid_scaled, y_valid),
                    callbacks=[onecycle])
# Out:
# Epoch 1/15
# 352/352 [==============================] - 2s 4ms/step - loss: 2.0785 - accuracy: 0.2785 - val_loss: 1.7982 - val_accuracy: 0.3710
# Epoch 2/15
# 352/352 [==============================] - 1s 4ms/step - loss: 1.7624 - accuracy: 0.3760 - val_loss: 1.6938 - val_accuracy: 0.4014
# Epoch 3/15
# 352/352 [==============================] - 1s 4ms/step - loss: 1.6322 - accuracy: 0.4225 - val_loss: 1.6404 - val_accuracy: 0.4146
# Epoch 4/15
# 352/352 [==============================] - 1s 4ms/step - loss: 1.5520 - accuracy: 0.4494 - val_loss: 1.6406 - val_accuracy: 0.4338
# Epoch 5/15
# 352/352 [==============================] - 1s 4ms/step - loss: 1.5027 - accuracy: 0.4666 - val_loss: 1.6214 - val_accuracy: 0.4438
# Epoch 6/15
# 352/352 [==============================] - 1s 4ms/step - loss: 1.4590 - accuracy: 0.4841 - val_loss: 1.6103 - val_accuracy: 0.4410
# Epoch 7/15
# 352/352 [==============================] - 1s 4ms/step - loss: 1.4242 - accuracy: 0.4946 - val_loss: 1.6475 - val_accuracy: 0.4294
# Epoch 8/15
# 352/352 [==============================] - 1s 4ms/step - loss: 1.3540 - accuracy: 0.5220 - val_loss: 1.5295 - val_accuracy: 0.4762
# Epoch 9/15
# 352/352 [==============================] - 1s 4ms/step - loss: 1.2762 - accuracy: 0.5490 - val_loss: 1.5327 - val_accuracy: 0.4704
# Epoch 10/15
# 352/352 [==============================] - 1s 4ms/step - loss: 1.2080 - accuracy: 0.5712 - val_loss: 1.5526 - val_accuracy: 0.4904
# Epoch 11/15
# 352/352 [==============================] - 1s 4ms/step - loss: 1.1408 - accuracy: 0.5932 - val_loss: 1.5072 - val_accuracy: 0.5048
# Epoch 12/15
# 352/352 [==============================] - 1s 4ms/step - loss: 1.0710 - accuracy: 0.6193 - val_loss: 1.5271 - val_accuracy: 0.5102
# Epoch 13/15
# 352/352 [==============================] - 1s 4ms/step - loss: 0.9983 - accuracy: 0.6454 - val_loss: 1.5481 - val_accuracy: 0.5106
# Epoch 14/15
# 352/352 [==============================] - 1s 4ms/step - loss: 0.9362 - accuracy: 0.6679 - val_loss: 1.5908 - val_accuracy: 0.5220
# Epoch 15/15
# 352/352 [==============================] - 1s 4ms/step - loss: 0.8960 - accuracy: 0.6833 - val_loss: 1.6065 - val_accuracy: 0.5230

# %% [markdown]
# One cycle allowed us to train the model in just 15 epochs, each taking only 2 seconds (thanks to the larger batch size). This is several times faster than the fastest model we trained so far. Moreover, we improved the model's performance (from 50.7% to 52.0%).

# %%
endTime = time.time()

elapsedTime = time.strftime("%H:%M:%S", time.gmtime(endTime - startTime))

print(todaysDate.strftime('# Run Date: %A, %B %d, %Y'))
print(f"# Run Time: {elapsedTime}")
# Out:
# # Run Date: Wednesday, February 08, 2023
# # Run Time: 00:50:06
