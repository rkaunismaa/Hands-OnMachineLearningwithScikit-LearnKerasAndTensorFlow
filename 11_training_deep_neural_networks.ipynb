# %%
# Dammit! This is NOT using the GPU! ... 

# CPU run time ... slow, right!?
# Run Date: Wednesday, February 08, 2023
# Run Time: 00:36:29

# %%
import time
from datetime import date

startTime = time.time()
todaysDate = date.today()

# %% [markdown]
# **Chapter 11 – Training Deep Neural Networks**

# %% [markdown]
# _This notebook contains all the sample code and solutions to the exercises in chapter 11._

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/ageron/handson-ml3/blob/main/11_training_deep_neural_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/ageron/handson-ml3/blob/main/11_training_deep_neural_networks.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# # Setup

# %% [markdown]
# This project requires Python 3.7 or above:

# %%
import sys

assert sys.version_info >= (3, 7)

# %% [markdown]
# And TensorFlow ≥ 2.8:

# %%
from packaging import version
import tensorflow as tf

assert version.parse(tf.__version__) >= version.parse("2.8.0")
# Out:
# 2023-02-08 15:51:42.180164: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-08 15:51:42.299806: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# As we did in previous chapters, let's define the default font sizes to make the figures prettier:

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# And let's create the `images/deep` folder (if it doesn't already exist), and define the `save_fig()` function which is used through this notebook to save the figures in high-res for the book:

# %%
from pathlib import Path

IMAGES_PATH = Path() / "images" / "deep"
IMAGES_PATH.mkdir(parents=True, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# # Vanishing/Exploding Gradients Problem

# %%
# extra code – this cell generates and saves Figure 11–1

import numpy as np

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

z = np.linspace(-5, 5, 200)

plt.plot([-5, 5], [0, 0], 'k-')
plt.plot([-5, 5], [1, 1], 'k--')
plt.plot([0, 0], [-0.2, 1.2], 'k-')
plt.plot([-5, 5], [-3/4, 7/4], 'g--')
plt.plot(z, sigmoid(z), "b-", linewidth=2,
         label=r"$\sigma(z) = \dfrac{1}{1+e^{-z}}$")
props = dict(facecolor='black', shrink=0.1)
plt.annotate('Saturating', xytext=(3.5, 0.7), xy=(5, 1), arrowprops=props,
             fontsize=14, ha="center")
plt.annotate('Saturating', xytext=(-3.5, 0.3), xy=(-5, 0), arrowprops=props,
             fontsize=14, ha="center")
plt.annotate('Linear', xytext=(2, 0.2), xy=(0, 0.5), arrowprops=props,
             fontsize=14, ha="center")
plt.grid(True)
plt.axis([-5, 5, -0.2, 1.2])
plt.xlabel("$z$")
plt.legend(loc="upper left", fontsize=16)

save_fig("sigmoid_saturation_plot")
plt.show()

# %% [markdown]
# ## Xavier and He Initialization

# %%
dense = tf.keras.layers.Dense(50, activation="relu",
                              kernel_initializer="he_normal")

# %%
he_avg_init = tf.keras.initializers.VarianceScaling(scale=2., mode="fan_avg",
                                                    distribution="uniform")
dense = tf.keras.layers.Dense(50, activation="sigmoid",
                              kernel_initializer=he_avg_init)

# %% [markdown]
# ## Nonsaturating Activation Functions

# %% [markdown]
# ### Leaky ReLU

# %%
# extra code – this cell generates and saves Figure 11–2

def leaky_relu(z, alpha):
    return np.maximum(alpha * z, z)

z = np.linspace(-5, 5, 200)
plt.plot(z, leaky_relu(z, 0.1), "b-", linewidth=2, label=r"$LeakyReLU(z) = max(\alpha z, z)$")
plt.plot([-5, 5], [0, 0], 'k-')
plt.plot([0, 0], [-1, 3.7], 'k-')
plt.grid(True)
props = dict(facecolor='black', shrink=0.1)
plt.annotate('Leak', xytext=(-3.5, 0.5), xy=(-5, -0.3), arrowprops=props,
             fontsize=14, ha="center")
plt.xlabel("$z$")
plt.axis([-5, 5, -1, 3.7])
plt.gca().set_aspect("equal")
plt.legend()

save_fig("leaky_relu_plot")
plt.show()

# %%
leaky_relu = tf.keras.layers.LeakyReLU(alpha=0.2)  # defaults to alpha=0.3
dense = tf.keras.layers.Dense(50, activation=leaky_relu,
                              kernel_initializer="he_normal")

# %%
model = tf.keras.models.Sequential([
    # [...]  # more layers
    tf.keras.layers.Dense(50, kernel_initializer="he_normal"),  # no activation
    tf.keras.layers.LeakyReLU(alpha=0.2),  # activation as a separate layer
    # [...]  # more layers
])
# Out:
# 2023-02-08 15:51:44.650259: E tensorflow/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-08 15:51:44.650298: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: 927db9be23a9
# 2023-02-08 15:51:44.650305: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: 927db9be23a9
# 2023-02-08 15:51:44.650392: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: NOT_FOUND: was unable to find libcuda.so DSO loaded into this program
# 2023-02-08 15:51:44.650413: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 520.61.5
# 2023-02-08 15:51:44.651061: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### ELU

# %% [markdown]
# Implementing ELU in TensorFlow is trivial, just specify the activation function when building each layer, and use He initialization:

# %%
dense = tf.keras.layers.Dense(50, activation="elu",
                              kernel_initializer="he_normal")

# %% [markdown]
# ### SELU

# %% [markdown]
# By default, the SELU hyperparameters (`scale` and `alpha`) are tuned in such a way that the mean output of each neuron remains close to 0, and the standard deviation remains close to 1 (assuming the inputs are standardized with mean 0 and standard deviation 1 too, and other constraints are respected, as explained in the book). Using this activation function, even a 1,000 layer deep neural network preserves roughly mean 0 and standard deviation 1 across all layers, avoiding the exploding/vanishing gradients problem:

# %%
# extra code – this cell generates and saves Figure 11–3

from scipy.special import erfc

# alpha and scale to self normalize with mean 0 and standard deviation 1
# (see equation 14 in the paper):
alpha_0_1 = -np.sqrt(2 / np.pi) / (erfc(1 / np.sqrt(2)) * np.exp(1 / 2) - 1)
scale_0_1 = (
    (1 - erfc(1 / np.sqrt(2)) * np.sqrt(np.e))
    * np.sqrt(2 * np.pi)
    * (
        2 * erfc(np.sqrt(2)) * np.e ** 2
        + np.pi * erfc(1 / np.sqrt(2)) ** 2 * np.e
        - 2 * (2 + np.pi) * erfc(1 / np.sqrt(2)) * np.sqrt(np.e)
        + np.pi
        + 2
    ) ** (-1 / 2)
)

def elu(z, alpha=1):
    return np.where(z < 0, alpha * (np.exp(z) - 1), z)

def selu(z, scale=scale_0_1, alpha=alpha_0_1):
    return scale * elu(z, alpha)

z = np.linspace(-5, 5, 200)
plt.plot(z, elu(z), "b-", linewidth=2, label=r"ELU$_\alpha(z) = \alpha (e^z - 1)$ if $z < 0$, else $z$")
plt.plot(z, selu(z), "r--", linewidth=2, label=r"SELU$(z) = 1.05 \, $ELU$_{1.67}(z)$")
plt.plot([-5, 5], [0, 0], 'k-')
plt.plot([-5, 5], [-1, -1], 'k:', linewidth=2)
plt.plot([-5, 5], [-1.758, -1.758], 'k:', linewidth=2)
plt.plot([0, 0], [-2.2, 3.2], 'k-')
plt.grid(True)
plt.axis([-5, 5, -2.2, 3.2])
plt.xlabel("$z$")
plt.gca().set_aspect("equal")
plt.legend()

save_fig("elu_selu_plot")
plt.show()

# %% [markdown]
# Using SELU is straightforward:

# %%
dense = tf.keras.layers.Dense(50, activation="selu",
                              kernel_initializer="lecun_normal")

# %% [markdown]
# **Extra material – an example of a self-regularized network using SELU**
#
# Let's create a neural net for Fashion MNIST with 100 hidden layers, using the SELU activation function:

# %%
tf.random.set_seed(42)
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[28, 28]))
for layer in range(100):
    model.add(tf.keras.layers.Dense(100, activation="selu",
                                    kernel_initializer="lecun_normal"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              metrics=["accuracy"])

# %% [markdown]
# Now let's train it. Do not forget to scale the inputs to mean 0 and standard deviation 1:

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]
X_train, X_valid, X_test = X_train / 255, X_valid / 255, X_test / 255

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
pixel_means = X_train.mean(axis=0, keepdims=True)
pixel_stds = X_train.std(axis=0, keepdims=True)
X_train_scaled = (X_train - pixel_means) / pixel_stds
X_valid_scaled = (X_valid - pixel_means) / pixel_stds
X_test_scaled = (X_test - pixel_means) / pixel_stds

# %%
history = model.fit(X_train_scaled, y_train, epochs=5,
                    validation_data=(X_valid_scaled, y_valid))
# Out:
# Epoch 1/5
# 1719/1719 [==============================] - 14s 7ms/step - loss: 1.0840 - accuracy: 0.5864 - val_loss: 0.7516 - val_accuracy: 0.7300
# Epoch 2/5
# 1719/1719 [==============================] - 11s 7ms/step - loss: 0.6993 - accuracy: 0.7510 - val_loss: 0.6082 - val_accuracy: 0.7856
# Epoch 3/5
# 1719/1719 [==============================] - 11s 7ms/step - loss: 0.5837 - accuracy: 0.7956 - val_loss: 0.5306 - val_accuracy: 0.8120
# Epoch 4/5
# 1719/1719 [==============================] - 11s 7ms/step - loss: 0.5139 - accuracy: 0.8222 - val_loss: 0.4858 - val_accuracy: 0.8322
# Epoch 5/5
# 1719/1719 [==============================] - 11s 7ms/step - loss: 0.4804 - accuracy: 0.8336 - val_loss: 0.4651 - val_accuracy: 0.8340

# %% [markdown]
# The network managed to learn, despite how deep it is. Now look at what happens if we try to use the ReLU activation function instead:

# %%
tf.random.set_seed(42)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[28, 28]))
for layer in range(100):
    model.add(tf.keras.layers.Dense(100, activation="relu",
                                    kernel_initializer="he_normal"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              metrics=["accuracy"])

# %%
history = model.fit(X_train_scaled, y_train, epochs=5,
                    validation_data=(X_valid_scaled, y_valid))
# Out:
# Epoch 1/5
# 1719/1719 [==============================] - 12s 6ms/step - loss: 1.8935 - accuracy: 0.2494 - val_loss: 1.6118 - val_accuracy: 0.3546
# Epoch 2/5
# 1719/1719 [==============================] - 10s 6ms/step - loss: 1.3930 - accuracy: 0.4015 - val_loss: 1.2511 - val_accuracy: 0.4052
# Epoch 3/5
# 1719/1719 [==============================] - 10s 6ms/step - loss: 1.0269 - accuracy: 0.5724 - val_loss: 0.8353 - val_accuracy: 0.6696
# Epoch 4/5
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.8434 - accuracy: 0.6640 - val_loss: 0.9303 - val_accuracy: 0.6264
# Epoch 5/5
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.7782 - accuracy: 0.6889 - val_loss: 0.8578 - val_accuracy: 0.6352

# %% [markdown]
# Not great at all, we suffered from the vanishing/exploding gradients problem.

# %% [markdown]
# ### GELU, Swish and Mish

# %%
# extra code – this cell generates and saves Figure 11–4

def swish(z, beta=1):
    return z * sigmoid(beta * z)

def approx_gelu(z):
    return swish(z, beta=1.702)

def softplus(z):
    return np.log(1 + np.exp(z))

def mish(z):
    return z * np.tanh(softplus(z))

z = np.linspace(-4, 2, 200)

beta = 0.6
plt.plot(z, approx_gelu(z), "b-", linewidth=2,
         label=r"GELU$(z) = z\,\Phi(z)$")
plt.plot(z, swish(z), "r--", linewidth=2,
         label=r"Swish$(z) = z\,\sigma(z)$")
plt.plot(z, swish(z, beta), "r:", linewidth=2,
         label=fr"Swish$_{{\beta={beta}}}(z)=z\,\sigma({beta}\,z)$")
plt.plot(z, mish(z), "g:", linewidth=3,
         label=fr"Mish$(z) = z\,\tanh($softplus$(z))$")
plt.plot([-4, 2], [0, 0], 'k-')
plt.plot([0, 0], [-2.2, 3.2], 'k-')
plt.grid(True)
plt.axis([-4, 2, -1, 2])
plt.gca().set_aspect("equal")
plt.xlabel("$z$")
plt.legend(loc="upper left")

save_fig("gelu_swish_mish_plot")
plt.show()

# %% [markdown]
# # Batch Normalization

# %%
# extra code - clear the name counters and set the random seed
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(300, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  batch_normalization (BatchN  (None, 784)              3136
#  ormalization)
#
#  dense (Dense)               (None, 300)               235500
#
#  batch_normalization_1 (Batc  (None, 300)              1200
#  hNormalization)
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  batch_normalization_2 (Batc  (None, 100)              400
#  hNormalization)
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 271,346
# Trainable params: 268,978
# Non-trainable params: 2,368
# _________________________________________________________________

# %%
[(var.name, var.trainable) for var in model.layers[1].variables]
# Out:
# [('batch_normalization/gamma:0', True),
#  ('batch_normalization/beta:0', True),
#  ('batch_normalization/moving_mean:0', False),
#  ('batch_normalization/moving_variance:0', False)]

# %%
# extra code – just show that the model works! 😊
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd",
              metrics="accuracy")
model.fit(X_train, y_train, epochs=2, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/2
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.5468 - accuracy: 0.8104 - val_loss: 0.4013 - val_accuracy: 0.8552
# Epoch 2/2
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4042 - accuracy: 0.8557 - val_loss: 0.3673 - val_accuracy: 0.8652

# %% [markdown]
# Sometimes applying BN before the activation function works better (there's a debate on this topic). Moreover, the layer before a `BatchNormalization` layer does not need to have bias terms, since the `BatchNormalization` layer some as well, it would be a waste of parameters, so you can set `use_bias=False` when creating those layers:

# %%
# extra code - clear the name counters and set the random seed
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(300, kernel_initializer="he_normal", use_bias=False),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.Dense(100, kernel_initializer="he_normal", use_bias=False),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
# extra code – just show that the model works! 😊
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd",
              metrics="accuracy")
model.fit(X_train, y_train, epochs=2, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/2
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.6058 - accuracy: 0.7977 - val_loss: 0.4270 - val_accuracy: 0.8476
# Epoch 2/2
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4276 - accuracy: 0.8515 - val_loss: 0.3695 - val_accuracy: 0.8658

# %% [markdown]
# ## Gradient Clipping

# %% [markdown]
# All `tf.keras.optimizers` accept `clipnorm` or `clipvalue` arguments:

# %%
optimizer = tf.keras.optimizers.SGD(clipvalue=1.0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer)

# %%
optimizer = tf.keras.optimizers.SGD(clipnorm=1.0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer)

# %% [markdown]
# ## Reusing Pretrained Layers

# %% [markdown]
# ### Reusing a Keras model

# %% [markdown]
# Let's split the fashion MNIST training set in two:
# * `X_train_A`: all images of all items except for T-shirts/tops and pullovers (classes 0 and 2).
# * `X_train_B`: a much smaller training set of just the first 200 images of T-shirts/tops and pullovers.
#
# The validation set and the test set are also split this way, but without restricting the number of images.
#
# We will train a model on set A (classification task with 8 classes), and try to reuse it to tackle set B (binary classification). We hope to transfer a little bit of knowledge from task A to task B, since classes in set A (trousers, dresses, coats, sandals, shirts, sneakers, bags, and ankle boots) are somewhat similar to classes in set B (T-shirts/tops and pullovers). However, since we are using `Dense` layers, only patterns that occur at the same location can be reused (in contrast, convolutional layers will transfer much better, since learned patterns can be detected anywhere on the image, as we will see in the chapter 14).

# %%
# extra code – split Fashion MNIST into tasks A and B, then train and save
#              model A to "my_model_A".

pos_class_id = class_names.index("Pullover")
neg_class_id = class_names.index("T-shirt/top")

def split_dataset(X, y):
    y_for_B = (y == pos_class_id) | (y == neg_class_id)
    y_A = y[~y_for_B]
    y_B = (y[y_for_B] == pos_class_id).astype(np.float32)
    old_class_ids = list(set(range(10)) - set([neg_class_id, pos_class_id]))
    for old_class_id, new_class_id in zip(old_class_ids, range(8)):
        y_A[y_A == old_class_id] = new_class_id  # reorder class ids for A
    return ((X[~y_for_B], y_A), (X[y_for_B], y_B))

(X_train_A, y_train_A), (X_train_B, y_train_B) = split_dataset(X_train, y_train)
(X_valid_A, y_valid_A), (X_valid_B, y_valid_B) = split_dataset(X_valid, y_valid)
(X_test_A, y_test_A), (X_test_B, y_test_B) = split_dataset(X_test, y_test)
X_train_B = X_train_B[:200]
y_train_B = y_train_B[:200]

tf.random.set_seed(42)

model_A = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(8, activation="softmax")
])

model_A.compile(loss="sparse_categorical_crossentropy",
                optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
                metrics=["accuracy"])
history = model_A.fit(X_train_A, y_train_A, epochs=20,
                      validation_data=(X_valid_A, y_valid_A))
model_A.save("my_model_A")
# Out:
# Epoch 1/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 1.1887 - accuracy: 0.6127 - val_loss: 0.7237 - val_accuracy: 0.7781
# Epoch 2/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.6178 - accuracy: 0.8047 - val_loss: 0.5236 - val_accuracy: 0.8333
# Epoch 3/20
# 1376/1376 [==============================] - 2s 1ms/step - loss: 0.4918 - accuracy: 0.8405 - val_loss: 0.4477 - val_accuracy: 0.8536
# Epoch 4/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.4307 - accuracy: 0.8589 - val_loss: 0.4021 - val_accuracy: 0.8694
# Epoch 5/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.3926 - accuracy: 0.8698 - val_loss: 0.3732 - val_accuracy: 0.8749
# Epoch 6/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.3659 - accuracy: 0.8769 - val_loss: 0.3519 - val_accuracy: 0.8832
# Epoch 7/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.3461 - accuracy: 0.8829 - val_loss: 0.3371 - val_accuracy: 0.8842
# Epoch 8/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.3303 - accuracy: 0.8879 - val_loss: 0.3296 - val_accuracy: 0.8869
# Epoch 9/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.3181 - accuracy: 0.8920 - val_loss: 0.3158 - val_accuracy: 0.8904
# Epoch 10/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.3072 - accuracy: 0.8949 - val_loss: 0.3099 - val_accuracy: 0.8937
# Epoch 11/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.2980 - accuracy: 0.8987 - val_loss: 0.3045 - val_accuracy: 0.8952
# Epoch 12/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.2907 - accuracy: 0.9003 - val_loss: 0.3003 - val_accuracy: 0.8985
# Epoch 13/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.2847 - accuracy: 0.9026 - val_loss: 0.2916 - val_accuracy: 0.9000
# Epoch 14/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.2785 - accuracy: 0.9044 - val_loss: 0.2849 - val_accuracy: 0.9020
# Epoch 15/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.2734 - accuracy: 0.9060 - val_loss: 0.2818 - val_accuracy: 0.9042
# Epoch 16/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.2687 - accuracy: 0.9080 - val_loss: 0.2787 - val_accuracy: 0.9042
# Epoch 17/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.2643 - accuracy: 0.9091 - val_loss: 0.2756 - val_accuracy: 0.9055
# Epoch 18/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.2598 - accuracy: 0.9111 - val_loss: 0.2748 - val_accuracy: 0.9030
# Epoch 19/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.2562 - accuracy: 0.9124 - val_loss: 0.2712 - val_accuracy: 0.9070
# Epoch 20/20
# 1376/1376 [==============================] - 1s 1ms/step - loss: 0.2524 - accuracy: 0.9137 - val_loss: 0.2710 - val_accuracy: 0.9103
# INFO:tensorflow:Assets written to: my_model_A/assets

# %%
# extra code – train and evaluate model B, without reusing model A

tf.random.set_seed(42)
model_B = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

model_B.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
                metrics=["accuracy"])
history = model_B.fit(X_train_B, y_train_B, epochs=20,
                      validation_data=(X_valid_B, y_valid_B))
model_B.evaluate(X_test_B, y_test_B)
# Out:
# Epoch 1/20
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6877 - accuracy: 0.5050 - val_loss: 0.6656 - val_accuracy: 0.5895
# Epoch 2/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6695 - accuracy: 0.6100 - val_loss: 0.6495 - val_accuracy: 0.6775
# Epoch 3/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6517 - accuracy: 0.6950 - val_loss: 0.6337 - val_accuracy: 0.7527
# Epoch 4/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6332 - accuracy: 0.7650 - val_loss: 0.6194 - val_accuracy: 0.8091
# Epoch 5/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6173 - accuracy: 0.8050 - val_loss: 0.6050 - val_accuracy: 0.8309
# Epoch 6/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6016 - accuracy: 0.8200 - val_loss: 0.5913 - val_accuracy: 0.8566
# Epoch 7/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5865 - accuracy: 0.8550 - val_loss: 0.5786 - val_accuracy: 0.8724
# Epoch 8/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5736 - accuracy: 0.8700 - val_loss: 0.5663 - val_accuracy: 0.8912
# Epoch 9/20
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5602 - accuracy: 0.8900 - val_loss: 0.5547 - val_accuracy: 0.8991
# Epoch 10/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5478 - accuracy: 0.8950 - val_loss: 0.5433 - val_accuracy: 0.9050
# Epoch 11/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5355 - accuracy: 0.9000 - val_loss: 0.5324 - val_accuracy: 0.9110
# Epoch 12/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5235 - accuracy: 0.9000 - val_loss: 0.5216 - val_accuracy: 0.9139
# Epoch 13/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5117 - accuracy: 0.9050 - val_loss: 0.5118 - val_accuracy: 0.9189
# Epoch 14/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5011 - accuracy: 0.9150 - val_loss: 0.5022 - val_accuracy: 0.9179
# Epoch 15/20
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4910 - accuracy: 0.9150 - val_loss: 0.4930 - val_accuracy: 0.9219
# Epoch 16/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4812 - accuracy: 0.9300 - val_loss: 0.4841 - val_accuracy: 0.9209
# Epoch 17/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4715 - accuracy: 0.9350 - val_loss: 0.4752 - val_accuracy: 0.9219
# Epoch 18/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4621 - accuracy: 0.9400 - val_loss: 0.4660 - val_accuracy: 0.9278
# Epoch 19/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4526 - accuracy: 0.9300 - val_loss: 0.4577 - val_accuracy: 0.9278
# Epoch 20/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4439 - accuracy: 0.9350 - val_loss: 0.4496 - val_accuracy: 0.9327
# 63/63 [==============================] - 0s 860us/step - loss: 0.4585 - accuracy: 0.9160
# [0.4584946632385254, 0.9160000085830688]

# %% [markdown]
# Model B reaches 91.85% accuracy on the test set. Now let's try reusing the pretrained model A.

# %%
model_A = tf.keras.models.load_model("my_model_A")
model_B_on_A = tf.keras.Sequential(model_A.layers[:-1])
model_B_on_A.add(tf.keras.layers.Dense(1, activation="sigmoid"))

# %% [markdown]
# Note that `model_B_on_A` and `model_A` actually share layers now, so when we train one, it will update both models. If we want to avoid that, we need to build `model_B_on_A` on top of a *clone* of `model_A`:

# %%
tf.random.set_seed(42)  # extra code – ensure reproducibility

# %%
model_A_clone = tf.keras.models.clone_model(model_A)
model_A_clone.set_weights(model_A.get_weights())

# %%
# extra code – creating model_B_on_A just like in the previous cell
model_B_on_A = tf.keras.Sequential(model_A_clone.layers[:-1])
model_B_on_A.add(tf.keras.layers.Dense(1, activation="sigmoid"))

# %%
for layer in model_B_on_A.layers[:-1]:
    layer.trainable = False

optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model_B_on_A.compile(loss="binary_crossentropy", optimizer=optimizer,
                     metrics=["accuracy"])

# %%
history = model_B_on_A.fit(X_train_B, y_train_B, epochs=4,
                           validation_data=(X_valid_B, y_valid_B))

for layer in model_B_on_A.layers[:-1]:
    layer.trainable = True

optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model_B_on_A.compile(loss="binary_crossentropy", optimizer=optimizer,
                     metrics=["accuracy"])
history = model_B_on_A.fit(X_train_B, y_train_B, epochs=16,
                           validation_data=(X_valid_B, y_valid_B))
# Out:
# Epoch 1/4
# 7/7 [==============================] - 0s 22ms/step - loss: 1.1515 - accuracy: 0.4300 - val_loss: 0.9179 - val_accuracy: 0.4392
# Epoch 2/4
# 7/7 [==============================] - 0s 7ms/step - loss: 0.9459 - accuracy: 0.3350 - val_loss: 0.8500 - val_accuracy: 0.3937
# Epoch 3/4
# 7/7 [==============================] - 0s 8ms/step - loss: 0.8863 - accuracy: 0.3400 - val_loss: 0.8354 - val_accuracy: 0.4184
# Epoch 4/4
# 7/7 [==============================] - 0s 8ms/step - loss: 0.8543 - accuracy: 0.3500 - val_loss: 0.8178 - val_accuracy: 0.4303
# Epoch 1/16
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7835 - accuracy: 0.4550 - val_loss: 0.6815 - val_accuracy: 0.5519
# Epoch 2/16
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6556 - accuracy: 0.6350 - val_loss: 0.5865 - val_accuracy: 0.6904
# Epoch 3/16
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5640 - accuracy: 0.7350 - val_loss: 0.5409 - val_accuracy: 0.7359
# Epoch 4/16
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4954 - accuracy: 0.8050 - val_loss: 0.4755 - val_accuracy: 0.8081
# Epoch 5/16
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4490 - accuracy: 0.8250 - val_loss: 0.4352 - val_accuracy: 0.8398
# Epoch 6/16
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4115 - accuracy: 0.8550 - val_loss: 0.4058 - val_accuracy: 0.8586
# Epoch 7/16
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3812 - accuracy: 0.8600 - val_loss: 0.3883 - val_accuracy: 0.8635
# Epoch 8/16
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3675 - accuracy: 0.8700 - val_loss: 0.3639 - val_accuracy: 0.8803
# Epoch 9/16
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3396 - accuracy: 0.8800 - val_loss: 0.3478 - val_accuracy: 0.8823
# Epoch 10/16
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3246 - accuracy: 0.9050 - val_loss: 0.3369 - val_accuracy: 0.8833
# Epoch 11/16
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3118 - accuracy: 0.8950 - val_loss: 0.3225 - val_accuracy: 0.8872
# Epoch 12/16
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2991 - accuracy: 0.9050 - val_loss: 0.3123 - val_accuracy: 0.8912
# Epoch 13/16
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2884 - accuracy: 0.9150 - val_loss: 0.3053 - val_accuracy: 0.8942
# Epoch 14/16
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2804 - accuracy: 0.9150 - val_loss: 0.2969 - val_accuracy: 0.8961
# Epoch 15/16
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2721 - accuracy: 0.9250 - val_loss: 0.2882 - val_accuracy: 0.8991
# Epoch 16/16
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2643 - accuracy: 0.9150 - val_loss: 0.2821 - val_accuracy: 0.8991

# %% [markdown]
# So, what's the final verdict?

# %%
model_B_on_A.evaluate(X_test_B, y_test_B)
# Out:
# 63/63 [==============================] - 0s 847us/step - loss: 0.2893 - accuracy: 0.9130
# [0.289315402507782, 0.9129999876022339]

# %% [markdown]
# Great! We got a bit of transfer: the model's accuracy went up 2 percentage points, from 91.85% to 93.85%. This means the error rate dropped by almost 25%:

# %%
1 - (100 - 93.85) / (100 - 91.85)
# Out:
# 0.24539877300613477

# %% [markdown]
# # Faster Optimizers

# %%
# extra code – a little function to test an optimizer on Fashion MNIST

def build_model(seed=42):
    tf.random.set_seed(seed)
    return tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=[28, 28]),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(10, activation="softmax")
    ])

def build_and_train_model(optimizer):
    model = build_model()
    model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
                  metrics=["accuracy"])
    return model.fit(X_train, y_train, epochs=10,
                     validation_data=(X_valid, y_valid))

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)

# %%
history_sgd = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.6954 - accuracy: 0.7614 - val_loss: 0.5025 - val_accuracy: 0.8166
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4666 - accuracy: 0.8357 - val_loss: 0.4545 - val_accuracy: 0.8308
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4203 - accuracy: 0.8510 - val_loss: 0.3992 - val_accuracy: 0.8580
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3909 - accuracy: 0.8611 - val_loss: 0.3790 - val_accuracy: 0.8608
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3700 - accuracy: 0.8679 - val_loss: 0.3620 - val_accuracy: 0.8672
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3562 - accuracy: 0.8728 - val_loss: 0.3723 - val_accuracy: 0.8668
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3404 - accuracy: 0.8778 - val_loss: 0.3610 - val_accuracy: 0.8672
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3309 - accuracy: 0.8798 - val_loss: 0.3512 - val_accuracy: 0.8728
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3224 - accuracy: 0.8835 - val_loss: 0.3668 - val_accuracy: 0.8692
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3117 - accuracy: 0.8873 - val_loss: 0.3558 - val_accuracy: 0.8728

# %% [markdown]
# ## Momentum optimization

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)

# %%
history_momentum = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.7089 - accuracy: 0.7586 - val_loss: 0.5204 - val_accuracy: 0.8106
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4687 - accuracy: 0.8344 - val_loss: 0.4399 - val_accuracy: 0.8404
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4213 - accuracy: 0.8518 - val_loss: 0.4056 - val_accuracy: 0.8592
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3939 - accuracy: 0.8600 - val_loss: 0.3810 - val_accuracy: 0.8628
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3720 - accuracy: 0.8673 - val_loss: 0.3682 - val_accuracy: 0.8624
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3589 - accuracy: 0.8714 - val_loss: 0.3653 - val_accuracy: 0.8654
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3423 - accuracy: 0.8768 - val_loss: 0.3603 - val_accuracy: 0.8686
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3330 - accuracy: 0.8790 - val_loss: 0.3502 - val_accuracy: 0.8720
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3232 - accuracy: 0.8834 - val_loss: 0.3652 - val_accuracy: 0.8662
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3128 - accuracy: 0.8858 - val_loss: 0.3641 - val_accuracy: 0.8680

# %% [markdown]
# ## Nesterov Accelerated Gradient

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9,
                                    nesterov=True)

# %%
history_nesterov = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.6710 - accuracy: 0.7739 - val_loss: 0.4806 - val_accuracy: 0.8272
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4581 - accuracy: 0.8401 - val_loss: 0.4413 - val_accuracy: 0.8398
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4155 - accuracy: 0.8547 - val_loss: 0.4011 - val_accuracy: 0.8568
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3900 - accuracy: 0.8637 - val_loss: 0.3884 - val_accuracy: 0.8598
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3690 - accuracy: 0.8694 - val_loss: 0.3664 - val_accuracy: 0.8666
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3546 - accuracy: 0.8746 - val_loss: 0.3882 - val_accuracy: 0.8618
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3402 - accuracy: 0.8788 - val_loss: 0.3669 - val_accuracy: 0.8642
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3293 - accuracy: 0.8816 - val_loss: 0.3570 - val_accuracy: 0.8694
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3199 - accuracy: 0.8865 - val_loss: 0.3583 - val_accuracy: 0.8668
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3085 - accuracy: 0.8893 - val_loss: 0.3737 - val_accuracy: 0.8644

# %% [markdown]
# ## AdaGrad

# %%
optimizer = tf.keras.optimizers.Adagrad(learning_rate=0.001)

# %%
history_adagrad = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.9934 - accuracy: 0.6732 - val_loss: 0.7020 - val_accuracy: 0.7688
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.6525 - accuracy: 0.7835 - val_loss: 0.5967 - val_accuracy: 0.8028
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.5768 - accuracy: 0.8096 - val_loss: 0.5476 - val_accuracy: 0.8146
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.5370 - accuracy: 0.8205 - val_loss: 0.5210 - val_accuracy: 0.8232
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.5118 - accuracy: 0.8272 - val_loss: 0.5019 - val_accuracy: 0.8264
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4935 - accuracy: 0.8328 - val_loss: 0.4895 - val_accuracy: 0.8278
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4799 - accuracy: 0.8363 - val_loss: 0.4773 - val_accuracy: 0.8302
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4693 - accuracy: 0.8393 - val_loss: 0.4690 - val_accuracy: 0.8310
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4603 - accuracy: 0.8428 - val_loss: 0.4623 - val_accuracy: 0.8360
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4525 - accuracy: 0.8446 - val_loss: 0.4551 - val_accuracy: 0.8370

# %% [markdown]
# ## RMSProp

# %%
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9)

# %%
history_rmsprop = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.5160 - accuracy: 0.8125 - val_loss: 0.4345 - val_accuracy: 0.8418
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3947 - accuracy: 0.8579 - val_loss: 0.4298 - val_accuracy: 0.8438
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3680 - accuracy: 0.8683 - val_loss: 0.4171 - val_accuracy: 0.8650
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3645 - accuracy: 0.8757 - val_loss: 0.4192 - val_accuracy: 0.8674
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3616 - accuracy: 0.8770 - val_loss: 0.3809 - val_accuracy: 0.8738
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3577 - accuracy: 0.8780 - val_loss: 0.4698 - val_accuracy: 0.8622
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3620 - accuracy: 0.8785 - val_loss: 0.4455 - val_accuracy: 0.8738
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3613 - accuracy: 0.8800 - val_loss: 0.4594 - val_accuracy: 0.8638
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3538 - accuracy: 0.8808 - val_loss: 0.5205 - val_accuracy: 0.8746
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3550 - accuracy: 0.8815 - val_loss: 0.5046 - val_accuracy: 0.8588

# %% [markdown]
# ## Adam Optimization

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9,
                                     beta_2=0.999)

# %%
history_adam = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.5003 - accuracy: 0.8210 - val_loss: 0.3966 - val_accuracy: 0.8480
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3761 - accuracy: 0.8636 - val_loss: 0.3851 - val_accuracy: 0.8568
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3430 - accuracy: 0.8746 - val_loss: 0.3760 - val_accuracy: 0.8668
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3197 - accuracy: 0.8826 - val_loss: 0.3358 - val_accuracy: 0.8714
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2972 - accuracy: 0.8896 - val_loss: 0.3229 - val_accuracy: 0.8818
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2851 - accuracy: 0.8938 - val_loss: 0.3319 - val_accuracy: 0.8804
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2713 - accuracy: 0.8970 - val_loss: 0.3453 - val_accuracy: 0.8778
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2615 - accuracy: 0.9007 - val_loss: 0.3200 - val_accuracy: 0.8872
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2515 - accuracy: 0.9046 - val_loss: 0.3340 - val_accuracy: 0.8834
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2431 - accuracy: 0.9083 - val_loss: 0.3900 - val_accuracy: 0.8720

# %% [markdown]
# **Adamax Optimization**

# %%
optimizer = tf.keras.optimizers.Adamax(learning_rate=0.001, beta_1=0.9,
                                       beta_2=0.999)

# %%
history_adamax = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.5373 - accuracy: 0.8116 - val_loss: 0.4476 - val_accuracy: 0.8356
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3979 - accuracy: 0.8578 - val_loss: 0.3940 - val_accuracy: 0.8506
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3608 - accuracy: 0.8706 - val_loss: 0.3540 - val_accuracy: 0.8698
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3357 - accuracy: 0.8785 - val_loss: 0.3353 - val_accuracy: 0.8768
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3152 - accuracy: 0.8859 - val_loss: 0.3265 - val_accuracy: 0.8788
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3015 - accuracy: 0.8900 - val_loss: 0.3349 - val_accuracy: 0.8746
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2877 - accuracy: 0.8946 - val_loss: 0.3334 - val_accuracy: 0.8788
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2785 - accuracy: 0.8970 - val_loss: 0.3155 - val_accuracy: 0.8836
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2685 - accuracy: 0.9012 - val_loss: 0.3370 - val_accuracy: 0.8810
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2561 - accuracy: 0.9051 - val_loss: 0.3455 - val_accuracy: 0.8758

# %% [markdown]
# **Nadam Optimization**

# %%
optimizer = tf.keras.optimizers.Nadam(learning_rate=0.001, beta_1=0.9,
                                      beta_2=0.999)

# %%
history_nadam = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4894 - accuracy: 0.8230 - val_loss: 0.3978 - val_accuracy: 0.8514
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3646 - accuracy: 0.8665 - val_loss: 0.3961 - val_accuracy: 0.8518
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3288 - accuracy: 0.8796 - val_loss: 0.3683 - val_accuracy: 0.8672
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3055 - accuracy: 0.8884 - val_loss: 0.3275 - val_accuracy: 0.8796
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2897 - accuracy: 0.8920 - val_loss: 0.3268 - val_accuracy: 0.8760
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2736 - accuracy: 0.8977 - val_loss: 0.3377 - val_accuracy: 0.8802
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2649 - accuracy: 0.8994 - val_loss: 0.3755 - val_accuracy: 0.8728
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2539 - accuracy: 0.9045 - val_loss: 0.3176 - val_accuracy: 0.8856
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2457 - accuracy: 0.9087 - val_loss: 0.3670 - val_accuracy: 0.8758
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2382 - accuracy: 0.9097 - val_loss: 0.3746 - val_accuracy: 0.8734

# %% [markdown]
# **AdamW Optimization**

# %% [markdown]
# On Colab or Kaggle, we need to install the TensorFlow-Addons library:

# %%
if "google.colab" in sys.modules:
    # %pip install -q -U tensorflow-addons

# %%
import tensorflow_addons as tfa

optimizer = tfa.optimizers.AdamW(weight_decay=1e-5, learning_rate=0.001,
                                 beta_1=0.9, beta_2=0.999)

# %%
history_adamw = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4933 - accuracy: 0.8227 - val_loss: 0.4211 - val_accuracy: 0.8320
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3754 - accuracy: 0.8629 - val_loss: 0.3921 - val_accuracy: 0.8462
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3423 - accuracy: 0.8744 - val_loss: 0.3689 - val_accuracy: 0.8700
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3183 - accuracy: 0.8829 - val_loss: 0.3538 - val_accuracy: 0.8686
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3017 - accuracy: 0.8878 - val_loss: 0.3310 - val_accuracy: 0.8742
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2876 - accuracy: 0.8942 - val_loss: 0.3504 - val_accuracy: 0.8798
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2741 - accuracy: 0.8963 - val_loss: 0.3488 - val_accuracy: 0.8770
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2661 - accuracy: 0.8991 - val_loss: 0.3362 - val_accuracy: 0.8812
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2574 - accuracy: 0.9051 - val_loss: 0.3670 - val_accuracy: 0.8716
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2477 - accuracy: 0.9056 - val_loss: 0.3687 - val_accuracy: 0.8718

# %%
# extra code – visualize the learning curves of all the optimizers

for loss in ("loss", "val_loss"):
    plt.figure(figsize=(12, 8))
    opt_names = "SGD Momentum Nesterov AdaGrad RMSProp Adam Adamax Nadam AdamW"
    for history, opt_name in zip((history_sgd, history_momentum, history_nesterov,
                                  history_adagrad, history_rmsprop, history_adam,
                                  history_adamax, history_nadam, history_adamw),
                                 opt_names.split()):
        plt.plot(history.history[loss], label=f"{opt_name}", linewidth=3)

    plt.grid()
    plt.xlabel("Epochs")
    plt.ylabel({"loss": "Training loss", "val_loss": "Validation loss"}[loss])
    plt.legend(loc="upper left")
    plt.axis([0, 9, 0.1, 0.7])
    plt.show()

# %% [markdown]
# ## Learning Rate Scheduling

# %% [markdown]
# ### Power Scheduling

# %% [markdown]
# ```lr = lr0 / (1 + steps / s)**c```
# * Keras uses `c=1` and `s = 1 / decay`

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, decay=1e-4)

# %%
history_power_scheduling = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.6811 - accuracy: 0.7649 - val_loss: 0.4837 - val_accuracy: 0.8294
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4742 - accuracy: 0.8320 - val_loss: 0.4590 - val_accuracy: 0.8370
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4270 - accuracy: 0.8469 - val_loss: 0.4206 - val_accuracy: 0.8500
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4037 - accuracy: 0.8570 - val_loss: 0.3957 - val_accuracy: 0.8578
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3849 - accuracy: 0.8625 - val_loss: 0.3860 - val_accuracy: 0.8608
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3705 - accuracy: 0.8677 - val_loss: 0.3937 - val_accuracy: 0.8564
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3607 - accuracy: 0.8705 - val_loss: 0.3692 - val_accuracy: 0.8654
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3515 - accuracy: 0.8744 - val_loss: 0.3704 - val_accuracy: 0.8632
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3431 - accuracy: 0.8767 - val_loss: 0.3566 - val_accuracy: 0.8694
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3360 - accuracy: 0.8797 - val_loss: 0.3555 - val_accuracy: 0.8714

# %%
# extra code – this cell plots power scheduling

import math

learning_rate = 0.01
decay = 1e-4
batch_size = 32
n_steps_per_epoch = math.ceil(len(X_train) / batch_size)
n_epochs = 25

epochs = np.arange(n_epochs)
lrs = learning_rate / (1 + decay * epochs * n_steps_per_epoch)

plt.plot(epochs, lrs,  "o-")
plt.axis([0, n_epochs - 1, 0, 0.01])
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.title("Power Scheduling", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exponential Scheduling

# %% [markdown]
# ```lr = lr0 * 0.1 ** (epoch / s)```

# %%
def exponential_decay_fn(epoch):
    return 0.01 * 0.1 ** (epoch / 20)

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 ** (epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(lr0=0.01, s=20)

# %%
# extra code – build and compile a model for Fashion MNIST

tf.random.set_seed(42)
model = build_model()
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])

# %%
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler])
# Out:
# Epoch 1/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.6813 - accuracy: 0.7667 - val_loss: 0.4802 - val_accuracy: 0.8278 - lr: 0.0100
# Epoch 2/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4616 - accuracy: 0.8367 - val_loss: 0.4390 - val_accuracy: 0.8422 - lr: 0.0089
# Epoch 3/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4164 - accuracy: 0.8514 - val_loss: 0.4146 - val_accuracy: 0.8546 - lr: 0.0079
# Epoch 4/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3924 - accuracy: 0.8615 - val_loss: 0.3851 - val_accuracy: 0.8630 - lr: 0.0071
# Epoch 5/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3734 - accuracy: 0.8679 - val_loss: 0.3749 - val_accuracy: 0.8662 - lr: 0.0063
# Epoch 6/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3591 - accuracy: 0.8723 - val_loss: 0.3860 - val_accuracy: 0.8664 - lr: 0.0056
# Epoch 7/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3487 - accuracy: 0.8752 - val_loss: 0.3608 - val_accuracy: 0.8720 - lr: 0.0050
# Epoch 8/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3393 - accuracy: 0.8787 - val_loss: 0.3669 - val_accuracy: 0.8664 - lr: 0.0045
# Epoch 9/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3316 - accuracy: 0.8815 - val_loss: 0.3499 - val_accuracy: 0.8754 - lr: 0.0040
# Epoch 10/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3245 - accuracy: 0.8837 - val_loss: 0.3492 - val_accuracy: 0.8770 - lr: 0.0035
# Epoch 11/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3191 - accuracy: 0.8858 - val_loss: 0.3457 - val_accuracy: 0.8786 - lr: 0.0032
# Epoch 12/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3141 - accuracy: 0.8877 - val_loss: 0.3454 - val_accuracy: 0.8756 - lr: 0.0028
# Epoch 13/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3098 - accuracy: 0.8891 - val_loss: 0.3350 - val_accuracy: 0.8794 - lr: 0.0025
# Epoch 14/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3059 - accuracy: 0.8909 - val_loss: 0.3374 - val_accuracy: 0.8812 - lr: 0.0022
# Epoch 15/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3027 - accuracy: 0.8908 - val_loss: 0.3411 - val_accuracy: 0.8808 - lr: 0.0020
# Epoch 16/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2993 - accuracy: 0.8923 - val_loss: 0.3321 - val_accuracy: 0.8792 - lr: 0.0018
# Epoch 17/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2967 - accuracy: 0.8930 - val_loss: 0.3353 - val_accuracy: 0.8782 - lr: 0.0016
# Epoch 18/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2946 - accuracy: 0.8941 - val_loss: 0.3333 - val_accuracy: 0.8810 - lr: 0.0014
# Epoch 19/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2927 - accuracy: 0.8951 - val_loss: 0.3302 - val_accuracy: 0.8800 - lr: 0.0013
# Epoch 20/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2906 - accuracy: 0.8954 - val_loss: 0.3293 - val_accuracy: 0.8816 - lr: 0.0011
# Epoch 21/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2890 - accuracy: 0.8963 - val_loss: 0.3273 - val_accuracy: 0.8800 - lr: 0.0010
# Epoch 22/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2876 - accuracy: 0.8970 - val_loss: 0.3297 - val_accuracy: 0.8794 - lr: 8.9125e-04
# Epoch 23/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2863 - accuracy: 0.8969 - val_loss: 0.3288 - val_accuracy: 0.8802 - lr: 7.9433e-04
# Epoch 24/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2850 - accuracy: 0.8975 - val_loss: 0.3299 - val_accuracy: 0.8804 - lr: 7.0795e-04
# Epoch 25/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2841 - accuracy: 0.8984 - val_loss: 0.3279 - val_accuracy: 0.8814 - lr: 6.3096e-04

# %%
# extra code – this cell plots exponential scheduling

plt.plot(history.epoch, history.history["lr"], "o-")
plt.axis([0, n_epochs - 1, 0, 0.011])
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.title("Exponential Scheduling", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# The schedule function can take the current learning rate as a second argument:

# %%
def exponential_decay_fn(epoch, lr):
    return lr * 0.1 ** (1 / 20)

# %% [markdown]
# **Extra material**: if you want to update the learning rate at each iteration rather than at each epoch, you can write your own callback class:

# %%
K = tf.keras.backend

class ExponentialDecay(tf.keras.callbacks.Callback):
    def __init__(self, n_steps=40_000):
        super().__init__()
        self.n_steps = n_steps

    def on_batch_begin(self, batch, logs=None):
        # Note: the `batch` argument is reset at each epoch
        lr = K.get_value(self.model.optimizer.learning_rate)
        new_learning_rate = lr * 0.1 ** (1 / self.n_steps)
        K.set_value(self.model.optimizer.learning_rate, new_learning_rate)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = K.get_value(self.model.optimizer.learning_rate)

# %%
lr0 = 0.01
model = build_model()
optimizer = tf.keras.optimizers.SGD(learning_rate=lr0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])

# %%
n_epochs = 25
batch_size = 32
n_steps = n_epochs * math.ceil(len(X_train) / batch_size)
exp_decay = ExponentialDecay(n_steps)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[exp_decay])
# Out:
# Epoch 1/25
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.6877 - accuracy: 0.7665 - val_loss: 0.4969 - val_accuracy: 0.8192 - lr: 0.0091
# Epoch 2/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4699 - accuracy: 0.8349 - val_loss: 0.4707 - val_accuracy: 0.8256 - lr: 0.0083
# Epoch 3/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4241 - accuracy: 0.8490 - val_loss: 0.4235 - val_accuracy: 0.8486 - lr: 0.0076
# Epoch 4/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4012 - accuracy: 0.8584 - val_loss: 0.3926 - val_accuracy: 0.8564 - lr: 0.0069
# Epoch 5/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3827 - accuracy: 0.8642 - val_loss: 0.3872 - val_accuracy: 0.8614 - lr: 0.0063
# Epoch 6/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3680 - accuracy: 0.8695 - val_loss: 0.3866 - val_accuracy: 0.8616 - lr: 0.0058
# Epoch 7/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3576 - accuracy: 0.8715 - val_loss: 0.3732 - val_accuracy: 0.8664 - lr: 0.0052
# Epoch 8/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3482 - accuracy: 0.8760 - val_loss: 0.3781 - val_accuracy: 0.8622 - lr: 0.0048
# Epoch 9/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3395 - accuracy: 0.8790 - val_loss: 0.3599 - val_accuracy: 0.8686 - lr: 0.0044
# Epoch 10/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3320 - accuracy: 0.8818 - val_loss: 0.3621 - val_accuracy: 0.8672 - lr: 0.0040
# Epoch 11/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3261 - accuracy: 0.8833 - val_loss: 0.3543 - val_accuracy: 0.8690 - lr: 0.0036
# Epoch 12/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3202 - accuracy: 0.8861 - val_loss: 0.3552 - val_accuracy: 0.8708 - lr: 0.0033
# Epoch 13/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3152 - accuracy: 0.8880 - val_loss: 0.3430 - val_accuracy: 0.8756 - lr: 0.0030
# Epoch 14/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3111 - accuracy: 0.8896 - val_loss: 0.3494 - val_accuracy: 0.8728 - lr: 0.0028
# Epoch 15/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3069 - accuracy: 0.8910 - val_loss: 0.3475 - val_accuracy: 0.8760 - lr: 0.0025
# Epoch 16/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3028 - accuracy: 0.8917 - val_loss: 0.3389 - val_accuracy: 0.8762 - lr: 0.0023
# Epoch 17/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2998 - accuracy: 0.8932 - val_loss: 0.3406 - val_accuracy: 0.8748 - lr: 0.0021
# Epoch 18/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2969 - accuracy: 0.8947 - val_loss: 0.3427 - val_accuracy: 0.8748 - lr: 0.0019
# Epoch 19/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2944 - accuracy: 0.8950 - val_loss: 0.3370 - val_accuracy: 0.8744 - lr: 0.0017
# Epoch 20/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2918 - accuracy: 0.8965 - val_loss: 0.3355 - val_accuracy: 0.8756 - lr: 0.0016
# Epoch 21/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2896 - accuracy: 0.8973 - val_loss: 0.3341 - val_accuracy: 0.8780 - lr: 0.0014
# Epoch 22/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2875 - accuracy: 0.8982 - val_loss: 0.3356 - val_accuracy: 0.8742 - lr: 0.0013
# Epoch 23/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2858 - accuracy: 0.8985 - val_loss: 0.3349 - val_accuracy: 0.8772 - lr: 0.0012
# Epoch 24/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2840 - accuracy: 0.8993 - val_loss: 0.3353 - val_accuracy: 0.8778 - lr: 0.0011
# Epoch 25/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2826 - accuracy: 0.9000 - val_loss: 0.3343 - val_accuracy: 0.8780 - lr: 1.0000e-03

# %%
n_steps = n_epochs * math.ceil(len(X_train) / batch_size)
steps = np.arange(n_steps)
decay_rate = 0.1
lrs = lr0 * decay_rate ** (steps / n_steps)

plt.plot(steps, lrs, "-", linewidth=2)
plt.axis([0, n_steps - 1, 0, lr0 * 1.1])
plt.xlabel("Batch")
plt.ylabel("Learning Rate")
plt.title("Exponential Scheduling (per batch)", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Piecewise Constant Scheduling

# %%
def piecewise_constant_fn(epoch):
    if epoch < 5:
        return 0.01
    elif epoch < 15:
        return 0.005
    else:
        return 0.001

# %%
# extra code – this cell demonstrates a more general way to define
#              piecewise constant scheduling.

def piecewise_constant(boundaries, values):
    boundaries = np.array([0] + boundaries)
    values = np.array(values)
    def piecewise_constant_fn(epoch):
        return values[(boundaries > epoch).argmax() - 1]
    return piecewise_constant_fn

piecewise_constant_fn = piecewise_constant([5, 15], [0.01, 0.005, 0.001])

# %%
# extra code – use a tf.keras.callbacks.LearningRateScheduler like earlier

n_epochs = 25

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(piecewise_constant_fn)

model = build_model()
optimizer = tf.keras.optimizers.Nadam(learning_rate=lr0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler])
# Out:
# Epoch 1/25
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.5713 - accuracy: 0.7920 - val_loss: 0.5343 - val_accuracy: 0.8024 - lr: 0.0100
# Epoch 2/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4516 - accuracy: 0.8392 - val_loss: 0.4505 - val_accuracy: 0.8390 - lr: 0.0100
# Epoch 3/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4248 - accuracy: 0.8484 - val_loss: 0.4803 - val_accuracy: 0.8364 - lr: 0.0100
# Epoch 4/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4174 - accuracy: 0.8531 - val_loss: 0.4168 - val_accuracy: 0.8540 - lr: 0.0100
# Epoch 5/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4210 - accuracy: 0.8546 - val_loss: 0.4010 - val_accuracy: 0.8556 - lr: 0.0100
# Epoch 6/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3531 - accuracy: 0.8721 - val_loss: 0.3824 - val_accuracy: 0.8606 - lr: 0.0050
# Epoch 7/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3451 - accuracy: 0.8741 - val_loss: 0.4030 - val_accuracy: 0.8620 - lr: 0.0050
# Epoch 8/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3388 - accuracy: 0.8762 - val_loss: 0.3893 - val_accuracy: 0.8668 - lr: 0.0050
# Epoch 9/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3390 - accuracy: 0.8760 - val_loss: 0.3718 - val_accuracy: 0.8660 - lr: 0.0050
# Epoch 10/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3319 - accuracy: 0.8785 - val_loss: 0.4160 - val_accuracy: 0.8616 - lr: 0.0050
# Epoch 11/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3333 - accuracy: 0.8793 - val_loss: 0.3760 - val_accuracy: 0.8654 - lr: 0.0050
# Epoch 12/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3282 - accuracy: 0.8801 - val_loss: 0.3888 - val_accuracy: 0.8710 - lr: 0.0050
# Epoch 13/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3286 - accuracy: 0.8808 - val_loss: 0.3997 - val_accuracy: 0.8722 - lr: 0.0050
# Epoch 14/25
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.3308 - accuracy: 0.8797 - val_loss: 0.3875 - val_accuracy: 0.8674 - lr: 0.0050
# Epoch 15/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3198 - accuracy: 0.8840 - val_loss: 0.4132 - val_accuracy: 0.8654 - lr: 0.0050
# Epoch 16/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2836 - accuracy: 0.8949 - val_loss: 0.4059 - val_accuracy: 0.8760 - lr: 0.0010
# Epoch 17/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2770 - accuracy: 0.8960 - val_loss: 0.3972 - val_accuracy: 0.8742 - lr: 0.0010
# Epoch 18/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2738 - accuracy: 0.8968 - val_loss: 0.4242 - val_accuracy: 0.8802 - lr: 0.0010
# Epoch 19/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2712 - accuracy: 0.8981 - val_loss: 0.4199 - val_accuracy: 0.8762 - lr: 0.0010
# Epoch 20/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2701 - accuracy: 0.8986 - val_loss: 0.4327 - val_accuracy: 0.8764 - lr: 0.0010
# Epoch 21/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2677 - accuracy: 0.8990 - val_loss: 0.4572 - val_accuracy: 0.8758 - lr: 0.0010
# Epoch 22/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2655 - accuracy: 0.8992 - val_loss: 0.4728 - val_accuracy: 0.8788 - lr: 0.0010
# Epoch 23/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2645 - accuracy: 0.8998 - val_loss: 0.5081 - val_accuracy: 0.8770 - lr: 0.0010
# Epoch 24/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2639 - accuracy: 0.9003 - val_loss: 0.4858 - val_accuracy: 0.8782 - lr: 0.0010
# Epoch 25/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2611 - accuracy: 0.9001 - val_loss: 0.5270 - val_accuracy: 0.8782 - lr: 0.0010

# %%
# extra code – this cell plots piecewise constant scheduling

plt.plot(history.epoch, history.history["lr"], "o-")
plt.axis([0, n_epochs - 1, 0, 0.011])
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.title("Piecewise Constant Scheduling", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Performance Scheduling

# %%
# extra code – build and compile the model

model = build_model()
optimizer = tf.keras.optimizers.SGD(learning_rate=lr0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler])
# Out:
# Epoch 1/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.6977 - accuracy: 0.7628 - val_loss: 0.4892 - val_accuracy: 0.8310 - lr: 0.0100
# Epoch 2/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4676 - accuracy: 0.8355 - val_loss: 0.4596 - val_accuracy: 0.8332 - lr: 0.0100
# Epoch 3/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4200 - accuracy: 0.8504 - val_loss: 0.4099 - val_accuracy: 0.8556 - lr: 0.0100
# Epoch 4/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3953 - accuracy: 0.8590 - val_loss: 0.3799 - val_accuracy: 0.8632 - lr: 0.0100
# Epoch 5/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3747 - accuracy: 0.8657 - val_loss: 0.3730 - val_accuracy: 0.8668 - lr: 0.0100
# Epoch 6/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3588 - accuracy: 0.8710 - val_loss: 0.3711 - val_accuracy: 0.8666 - lr: 0.0100
# Epoch 7/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3469 - accuracy: 0.8736 - val_loss: 0.3574 - val_accuracy: 0.8744 - lr: 0.0100
# Epoch 8/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3347 - accuracy: 0.8780 - val_loss: 0.3557 - val_accuracy: 0.8686 - lr: 0.0100
# Epoch 9/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3247 - accuracy: 0.8832 - val_loss: 0.3430 - val_accuracy: 0.8724 - lr: 0.0100
# Epoch 10/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3152 - accuracy: 0.8857 - val_loss: 0.3422 - val_accuracy: 0.8754 - lr: 0.0100
# Epoch 11/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3073 - accuracy: 0.8887 - val_loss: 0.3624 - val_accuracy: 0.8632 - lr: 0.0100
# Epoch 12/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2999 - accuracy: 0.8902 - val_loss: 0.3362 - val_accuracy: 0.8784 - lr: 0.0100
# Epoch 13/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2941 - accuracy: 0.8930 - val_loss: 0.3193 - val_accuracy: 0.8816 - lr: 0.0100
# Epoch 14/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2865 - accuracy: 0.8946 - val_loss: 0.3404 - val_accuracy: 0.8790 - lr: 0.0100
# Epoch 15/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2809 - accuracy: 0.8982 - val_loss: 0.3372 - val_accuracy: 0.8812 - lr: 0.0100
# Epoch 16/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2748 - accuracy: 0.8991 - val_loss: 0.3360 - val_accuracy: 0.8786 - lr: 0.0100
# Epoch 17/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2697 - accuracy: 0.9004 - val_loss: 0.3215 - val_accuracy: 0.8792 - lr: 0.0100
# Epoch 18/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2644 - accuracy: 0.9037 - val_loss: 0.3243 - val_accuracy: 0.8822 - lr: 0.0100
# Epoch 19/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2471 - accuracy: 0.9096 - val_loss: 0.3187 - val_accuracy: 0.8834 - lr: 0.0050
# Epoch 20/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2433 - accuracy: 0.9114 - val_loss: 0.3118 - val_accuracy: 0.8868 - lr: 0.0050
# Epoch 21/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2409 - accuracy: 0.9119 - val_loss: 0.3087 - val_accuracy: 0.8876 - lr: 0.0050
# Epoch 22/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2381 - accuracy: 0.9123 - val_loss: 0.3133 - val_accuracy: 0.8830 - lr: 0.0050
# Epoch 23/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2358 - accuracy: 0.9143 - val_loss: 0.3196 - val_accuracy: 0.8826 - lr: 0.0050
# Epoch 24/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2325 - accuracy: 0.9155 - val_loss: 0.3188 - val_accuracy: 0.8826 - lr: 0.0050
# Epoch 25/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2308 - accuracy: 0.9153 - val_loss: 0.3177 - val_accuracy: 0.8874 - lr: 0.0050

# %%
# extra code – this cell plots performance scheduling

plt.plot(history.epoch, history.history["lr"], "bo-")
plt.xlabel("Epoch")
plt.ylabel("Learning Rate", color='b')
plt.tick_params('y', colors='b')
plt.gca().set_xlim(0, n_epochs - 1)
plt.grid(True)

ax2 = plt.gca().twinx()
ax2.plot(history.epoch, history.history["val_loss"], "r^-")
ax2.set_ylabel('Validation Loss', color='r')
ax2.tick_params('y', colors='r')

plt.title("Reduce LR on Plateau", fontsize=14)
plt.show()

# %% [markdown]
# ### tf.keras schedulers

# %%
import math

batch_size = 32
n_epochs = 25
n_steps = n_epochs * math.ceil(len(X_train) / batch_size)
scheduled_learning_rate = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01, decay_steps=n_steps, decay_rate=0.1)
optimizer = tf.keras.optimizers.SGD(learning_rate=scheduled_learning_rate)

# %%
# extra code – build and train the model
model = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.7112 - accuracy: 0.7600 - val_loss: 0.5062 - val_accuracy: 0.8178
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4759 - accuracy: 0.8327 - val_loss: 0.4627 - val_accuracy: 0.8312
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4287 - accuracy: 0.8482 - val_loss: 0.4173 - val_accuracy: 0.8532
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4052 - accuracy: 0.8584 - val_loss: 0.3981 - val_accuracy: 0.8576
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3855 - accuracy: 0.8641 - val_loss: 0.3907 - val_accuracy: 0.8590
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3709 - accuracy: 0.8684 - val_loss: 0.3972 - val_accuracy: 0.8572
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3602 - accuracy: 0.8721 - val_loss: 0.3722 - val_accuracy: 0.8650
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3506 - accuracy: 0.8756 - val_loss: 0.3755 - val_accuracy: 0.8616
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3424 - accuracy: 0.8785 - val_loss: 0.3609 - val_accuracy: 0.8692
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3351 - accuracy: 0.8808 - val_loss: 0.3612 - val_accuracy: 0.8698

# %% [markdown]
# For piecewise constant scheduling, try this:

# %%
# extra code – shows how to use PiecewiseConstantDecay
scheduled_learning_rate = tf.keras.optimizers.schedules.PiecewiseConstantDecay(
    boundaries=[5. * n_steps_per_epoch, 15. * n_steps_per_epoch],
    values=[0.01, 0.005, 0.001])

# %% [markdown]
# ### 1Cycle scheduling

# %% [markdown]
# The `ExponentialLearningRate` custom callback updates the learning rate during training, at the end of each batch. It multiplies it by a constant `factor`. It also saves the learning rate and loss at each batch. Since `logs["loss"]` is actually the mean loss since the start of the epoch, and we want to save the batch loss instead, we must compute the mean times the number of batches since the beginning of the epoch to get the total loss so far, then we subtract the total loss at the previous batch to get the current batch's loss.

# %%
K = tf.keras.backend

class ExponentialLearningRate(tf.keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []

    def on_epoch_begin(self, epoch, logs=None):
        self.sum_of_epoch_losses = 0

    def on_batch_end(self, batch, logs=None):
        mean_epoch_loss = logs["loss"]  # the epoch's mean loss so far 
        new_sum_of_epoch_losses = mean_epoch_loss * (batch + 1)
        batch_loss = new_sum_of_epoch_losses - self.sum_of_epoch_losses
        self.sum_of_epoch_losses = new_sum_of_epoch_losses
        self.rates.append(K.get_value(self.model.optimizer.learning_rate))
        self.losses.append(batch_loss)
        K.set_value(self.model.optimizer.learning_rate,
                    self.model.optimizer.learning_rate * self.factor)

# %% [markdown]
# The `find_learning_rate()` function trains the model using the `ExponentialLearningRate` callback, and it returns the learning rates and corresponding batch losses. At the end, it restores the model and its optimizer to their initial state.

# %%
def find_learning_rate(model, X, y, epochs=1, batch_size=32, min_rate=1e-4,
                       max_rate=1):
    init_weights = model.get_weights()
    iterations = math.ceil(len(X) / batch_size) * epochs
    factor = (max_rate / min_rate) ** (1 / iterations)
    init_lr = K.get_value(model.optimizer.learning_rate)
    K.set_value(model.optimizer.learning_rate, min_rate)
    exp_lr = ExponentialLearningRate(factor)
    history = model.fit(X, y, epochs=epochs, batch_size=batch_size,
                        callbacks=[exp_lr])
    K.set_value(model.optimizer.learning_rate, init_lr)
    model.set_weights(init_weights)
    return exp_lr.rates, exp_lr.losses

# %% [markdown]
# The `plot_lr_vs_loss()` function plots the learning rates vs the losses. The optimal learning rate to use as the maximum learning rate in 1cycle is near the bottom of the curve.

# %%
def plot_lr_vs_loss(rates, losses):
    plt.plot(rates, losses, "b")
    plt.gca().set_xscale('log')
    max_loss = losses[0] + min(losses)
    plt.hlines(min(losses), min(rates), max(rates), color="k")
    plt.axis([min(rates), max(rates), 0, max_loss])
    plt.xlabel("Learning rate")
    plt.ylabel("Loss")
    plt.grid()

# %% [markdown]
# Let's build a simple Fashion MNIST model and compile it:

# %%
model = build_model()
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              metrics=["accuracy"])

# %% [markdown]
# Now let's find the optimal max learning rate for 1cycle:

# %%
batch_size = 128
rates, losses = find_learning_rate(model, X_train, y_train, epochs=1,
                                   batch_size=batch_size)
plot_lr_vs_loss(rates, losses)
# Out:
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8643 - accuracy: 0.4045

# %% [markdown]
# Looks like the max learning rate to use for 1cycle is around 10<sup>–1</sup>.

# %% [markdown]
# The `OneCycleScheduler` custom callback updates the learning rate at the beginning of each batch. It applies the logic described in the book: increase the learning rate linearly during about half of training, then reduce it linearly back to the initial learning rate, and lastly reduce it down to close to zero linearly for the very last part of training.

# %%
class OneCycleScheduler(tf.keras.callbacks.Callback):
    def __init__(self, iterations, max_lr=1e-3, start_lr=None,
                 last_iterations=None, last_lr=None):
        self.iterations = iterations
        self.max_lr = max_lr
        self.start_lr = start_lr or max_lr / 10
        self.last_iterations = last_iterations or iterations // 10 + 1
        self.half_iteration = (iterations - self.last_iterations) // 2
        self.last_lr = last_lr or self.start_lr / 1000
        self.iteration = 0

    def _interpolate(self, iter1, iter2, lr1, lr2):
        return (lr2 - lr1) * (self.iteration - iter1) / (iter2 - iter1) + lr1

    def on_batch_begin(self, batch, logs):
        if self.iteration < self.half_iteration:
            lr = self._interpolate(0, self.half_iteration, self.start_lr,
                                   self.max_lr)
        elif self.iteration < 2 * self.half_iteration:
            lr = self._interpolate(self.half_iteration, 2 * self.half_iteration,
                                   self.max_lr, self.start_lr)
        else:
            lr = self._interpolate(2 * self.half_iteration, self.iterations,
                                   self.start_lr, self.last_lr)
        self.iteration += 1
        K.set_value(self.model.optimizer.learning_rate, lr)

# %% [markdown]
# Let's build and compile a simple Fashion MNIST model, then train it using the `OneCycleScheduler` callback:

# %%
model = build_model()
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["accuracy"])
n_epochs = 25
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * n_epochs,
                             max_lr=0.1)
history = model.fit(X_train, y_train, epochs=n_epochs, batch_size=batch_size,
                    validation_data=(X_valid, y_valid),
                    callbacks=[onecycle])
# Out:
# Epoch 1/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.9317 - accuracy: 0.6942 - val_loss: 0.5876 - val_accuracy: 0.8016
# Epoch 2/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.5631 - accuracy: 0.8044 - val_loss: 0.4849 - val_accuracy: 0.8276
# Epoch 3/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.4905 - accuracy: 0.8266 - val_loss: 0.4539 - val_accuracy: 0.8392
# Epoch 4/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.4460 - accuracy: 0.8415 - val_loss: 0.4185 - val_accuracy: 0.8476
# Epoch 5/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.4185 - accuracy: 0.8507 - val_loss: 0.4209 - val_accuracy: 0.8452
# Epoch 6/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3942 - accuracy: 0.8580 - val_loss: 0.4746 - val_accuracy: 0.8262
# Epoch 7/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3807 - accuracy: 0.8628 - val_loss: 0.3854 - val_accuracy: 0.8618
# Epoch 8/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3648 - accuracy: 0.8667 - val_loss: 0.4448 - val_accuracy: 0.8354
# Epoch 9/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3520 - accuracy: 0.8711 - val_loss: 0.3896 - val_accuracy: 0.8642
# Epoch 10/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3400 - accuracy: 0.8749 - val_loss: 0.4961 - val_accuracy: 0.8370
# Epoch 11/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3286 - accuracy: 0.8793 - val_loss: 0.3882 - val_accuracy: 0.8528
# Epoch 12/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.3190 - accuracy: 0.8809 - val_loss: 0.3400 - val_accuracy: 0.8746
# Epoch 13/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2992 - accuracy: 0.8902 - val_loss: 0.3394 - val_accuracy: 0.8738
# Epoch 14/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2836 - accuracy: 0.8951 - val_loss: 0.3491 - val_accuracy: 0.8754
# Epoch 15/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2700 - accuracy: 0.8983 - val_loss: 0.3300 - val_accuracy: 0.8816
# Epoch 16/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2583 - accuracy: 0.9038 - val_loss: 0.3286 - val_accuracy: 0.8828
# Epoch 17/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2498 - accuracy: 0.9064 - val_loss: 0.3181 - val_accuracy: 0.8846
# Epoch 18/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2384 - accuracy: 0.9117 - val_loss: 0.3232 - val_accuracy: 0.8844
# Epoch 19/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2303 - accuracy: 0.9139 - val_loss: 0.3151 - val_accuracy: 0.8842
# Epoch 20/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2221 - accuracy: 0.9175 - val_loss: 0.3170 - val_accuracy: 0.8842
# Epoch 21/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2150 - accuracy: 0.9211 - val_loss: 0.3075 - val_accuracy: 0.8876
# Epoch 22/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2082 - accuracy: 0.9240 - val_loss: 0.3114 - val_accuracy: 0.8872
# Epoch 23/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.2030 - accuracy: 0.9256 - val_loss: 0.3079 - val_accuracy: 0.8888
# Epoch 24/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.1997 - accuracy: 0.9278 - val_loss: 0.3106 - val_accuracy: 0.8890
# Epoch 25/25
# 430/430 [==============================] - 1s 2ms/step - loss: 0.1974 - accuracy: 0.9283 - val_loss: 0.3094 - val_accuracy: 0.8896

# %% [markdown]
# # Avoiding Overfitting Through Regularization

# %% [markdown]
# ## $\ell_1$ and $\ell_2$ regularization

# %%
layer = tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal",
                              kernel_regularizer=tf.keras.regularizers.l2(0.01))

# %% [markdown]
# Or use `l1(0.1)` for ℓ<sub>1</sub> regularization with a factor of 0.1, or `l1_l2(0.1, 0.01)` for both ℓ<sub>1</sub> and ℓ<sub>2</sub> regularization, with factors 0.1 and 0.01 respectively.

# %%
tf.random.set_seed(42)  # extra code – for reproducibility

# %%
from functools import partial

RegularizedDense = partial(tf.keras.layers.Dense,
                           activation="relu",
                           kernel_initializer="he_normal",
                           kernel_regularizer=tf.keras.regularizers.l2(0.01))

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    RegularizedDense(100),
    RegularizedDense(100),
    RegularizedDense(10, activation="softmax")
])

# %%
# extra code – compile and train the model
optimizer = tf.keras.optimizers.SGD(learning_rate=0.02)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=2,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/2
# 1719/1719 [==============================] - 2s 1ms/step - loss: 3.1349 - accuracy: 0.7717 - val_loss: 1.8641 - val_accuracy: 0.8242
# Epoch 2/2
# 1719/1719 [==============================] - 2s 1ms/step - loss: 1.4295 - accuracy: 0.8140 - val_loss: 1.1298 - val_accuracy: 0.8192

# %% [markdown]
# ## Dropout

# %%
tf.random.set_seed(42)  # extra code – for reproducibility

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
# extra code – compile and train the model
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.6773 - accuracy: 0.7523 - val_loss: 0.4750 - val_accuracy: 0.8240
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.5158 - accuracy: 0.8117 - val_loss: 0.4252 - val_accuracy: 0.8332
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4775 - accuracy: 0.8239 - val_loss: 0.4107 - val_accuracy: 0.8492
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4522 - accuracy: 0.8346 - val_loss: 0.3846 - val_accuracy: 0.8562
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4378 - accuracy: 0.8373 - val_loss: 0.3602 - val_accuracy: 0.8600
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4264 - accuracy: 0.8429 - val_loss: 0.3684 - val_accuracy: 0.8626
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4168 - accuracy: 0.8484 - val_loss: 0.3588 - val_accuracy: 0.8656
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4117 - accuracy: 0.8470 - val_loss: 0.3438 - val_accuracy: 0.8738
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4046 - accuracy: 0.8519 - val_loss: 0.3432 - val_accuracy: 0.8718
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3927 - accuracy: 0.8553 - val_loss: 0.3482 - val_accuracy: 0.8682

# %% [markdown]
# The training accuracy looks like it's lower than the validation accuracy, but that's just because dropout is only active during training. If we evaluate the model on the training set after training (i.e., with dropout turned off), we get the "real" training accuracy, which is very slightly higher than the validation accuracy and the test accuracy:

# %%
model.evaluate(X_train, y_train)
# Out:
# 1719/1719 [==============================] - 1s 787us/step - loss: 0.3163 - accuracy: 0.8812
# [0.3162756860256195, 0.8812181949615479]

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 809us/step - loss: 0.3682 - accuracy: 0.8642
# [0.36819222569465637, 0.8641999959945679]

# %% [markdown]
# **Note**: make sure to use `AlphaDropout` instead of `Dropout` if you want to build a self-normalizing neural net using SELU.

# %% [markdown]
# ## MC Dropout

# %%
tf.random.set_seed(42)  # extra code – for reproducibility

# %%
y_probas = np.stack([model(X_test, training=True)
                     for sample in range(100)])
y_proba = y_probas.mean(axis=0)

# %%
model.predict(X_test[:1]).round(3)
# Out:
# 1/1 [==============================] - 0s 62ms/step
# array([[0.   , 0.   , 0.   , 0.   , 0.   , 0.034, 0.   , 0.226, 0.   ,
#         0.739]], dtype=float32)

# %%
y_proba[0].round(3)
# Out:
# array([0.   , 0.   , 0.   , 0.   , 0.   , 0.086, 0.   , 0.289, 0.003,
#        0.62 ], dtype=float32)

# %%
y_std = y_probas.std(axis=0)
y_std[0].round(3)
# Out:
# array([0.001, 0.001, 0.001, 0.002, 0.001, 0.111, 0.001, 0.232, 0.02 ,
#        0.252], dtype=float32)

# %%
y_pred = y_proba.argmax(axis=1)
accuracy = (y_pred == y_test).sum() / len(y_test)
accuracy
# Out:
# 0.8685

# %%
class MCDropout(tf.keras.layers.Dropout):
    def call(self, inputs, training=None):
        return super().call(inputs, training=True)

# %%
# extra code – shows how to convert Dropout to MCDropout in a Sequential model
Dropout = tf.keras.layers.Dropout
mc_model = tf.keras.Sequential([
    MCDropout(layer.rate) if isinstance(layer, Dropout) else layer
    for layer in model.layers
])
mc_model.set_weights(model.get_weights())

# %%
mc_model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_21 (Flatten)        (None, 784)               0
#
#  mc_dropout (MCDropout)      (None, 784)               0
#
#  dense_85 (Dense)            (None, 100)               78500
#
#  mc_dropout_1 (MCDropout)    (None, 100)               0
#
#  dense_86 (Dense)            (None, 100)               10100
#
#  mc_dropout_2 (MCDropout)    (None, 100)               0
#
#  dense_87 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 89,610
# Trainable params: 89,610
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now we can use the model with MC Dropout:

# %%
# extra code – shows that the model works without retraining
tf.random.set_seed(42)
np.mean([mc_model.predict(X_test[:1])
         for sample in range(100)], axis=0).round(2)
# Out:
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# array([[0.  , 0.  , 0.  , 0.  , 0.  , 0.08, 0.  , 0.29, 0.  , 0.63]],
#       dtype=float32)

# %% [markdown]
# ## Max norm

# %%
dense = tf.keras.layers.Dense(
    100, activation="relu", kernel_initializer="he_normal",
    kernel_constraint=tf.keras.constraints.max_norm(1.))

# %%
# extra code – shows how to apply max norm to every hidden layer in a model

MaxNormDense = partial(tf.keras.layers.Dense,
                       activation="relu", kernel_initializer="he_normal",
                       kernel_constraint=tf.keras.constraints.max_norm(1.))

tf.random.set_seed(42)
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    MaxNormDense(100),
    MaxNormDense(100),
    tf.keras.layers.Dense(10, activation="softmax")
])
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.5464 - accuracy: 0.8056 - val_loss: 0.4539 - val_accuracy: 0.8240
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4135 - accuracy: 0.8493 - val_loss: 0.4104 - val_accuracy: 0.8452
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3813 - accuracy: 0.8591 - val_loss: 0.3669 - val_accuracy: 0.8676
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3617 - accuracy: 0.8673 - val_loss: 0.3603 - val_accuracy: 0.8694
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3475 - accuracy: 0.8713 - val_loss: 0.3572 - val_accuracy: 0.8652
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3391 - accuracy: 0.8748 - val_loss: 0.3858 - val_accuracy: 0.8600
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3314 - accuracy: 0.8762 - val_loss: 0.3963 - val_accuracy: 0.8544
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3282 - accuracy: 0.8779 - val_loss: 0.3575 - val_accuracy: 0.8656
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3296 - accuracy: 0.8778 - val_loss: 0.3653 - val_accuracy: 0.8620
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3198 - accuracy: 0.8804 - val_loss: 0.3982 - val_accuracy: 0.8560

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1. to 7.

# %% [markdown]
# 1. Glorot initialization and He initialization were designed to make the output standard deviation as close as possible to the input standard deviation, at least at the beginning of training. This reduces the vanishing/exploding gradients problem.
# 2. No, all weights should be sampled independently; they should not all have the same initial value. One important goal of sampling weights randomly is to break symmetry: if all the weights have the same initial value, even if that value is not zero, then symmetry is not broken (i.e., all neurons in a given layer are equivalent), and backpropagation will be unable to break it. Concretely, this means that all the neurons in any given layer will always have the same weights. It's like having just one neuron per layer, and much slower. It is virtually impossible for such a configuration to converge to a good solution.
# 3. It is perfectly fine to initialize the bias terms to zero. Some people like to initialize them just like weights, and that's OK too; it does not make much difference.
# 4. ReLU is usually a good default for the hidden layers, as it is fast and yields good results. Its ability to output precisely zero can also be useful in some cases (e.g., see Chapter 17). Moreover, it can sometimes benefit from optimized implementations as well as from hardware acceleration. The leaky ReLU variants of ReLU can improve the model's quality without hindering its speed too much compared to ReLU. For large neural nets and more complex problems, GLU, Swish and Mish can give you a slightly higher quality model, but they have a computational cost. The hyperbolic tangent (tanh) can be useful in the output layer if you need to output a number in a fixed range (by default between –1 and 1), but nowadays it is not used much in hidden layers, except in recurrent nets. The sigmoid activation function is also useful in the output layer when you need to estimate a probability (e.g., for binary classification), but it is rarely used in hidden layers (there are exceptions—for example, for the coding layer of variational autoencoders; see Chapter 17). The softplus activation function is useful in the output layer when you need to ensure that the output will always be positive. The softmax activation function is useful in the output layer to estimate probabilities for mutually exclusive classes, but it is rarely (if ever) used in hidden layers.
# 5. If you set the `momentum` hyperparameter too close to 1 (e.g., 0.99999) when using an `SGD` optimizer, then the algorithm will likely pick up a lot of speed, hopefully moving roughly toward the global minimum, but its momentum will carry it right past the minimum. Then it will slow down and come back, accelerate again, overshoot again, and so on. It may oscillate this way many times before converging, so overall it will take much longer to converge than with a smaller `momentum` value.
# 6. One way to produce a sparse model (i.e., with most weights equal to zero) is to train the model normally, then zero out tiny weights. For more sparsity, you can apply ℓ<sub>1</sub> regularization during training, which pushes the optimizer toward sparsity. A third option is to use the TensorFlow Model Optimization Toolkit.
# 7. Yes, dropout does slow down training, in general roughly by a factor of two. However, it has no impact on inference speed since it is only turned on during training. MC Dropout is exactly like dropout during training, but it is still active during inference, so each inference is slowed down slightly. More importantly, when using MC Dropout you generally want to run inference 10 times or more to get better predictions. This means that making predictions is slowed down by a factor of 10 or more.

# %% [markdown]
# ## 8. Deep Learning on CIFAR10

# %% [markdown]
# ### a.
# *Exercise: Build a DNN with 20 hidden layers of 100 neurons each (that's too many, but it's the point of this exercise). Use He initialization and the Swish activation function.*

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                    activation="swish",
                                    kernel_initializer="he_normal"))

# %% [markdown]
# ### b.
# *Exercise: Using Nadam optimization and early stopping, train the network on the CIFAR10 dataset. You can load it with `tf.keras.datasets.cifar10.load_data()`. The dataset is composed of 60,000 32 × 32–pixel color images (50,000 for training, 10,000 for testing) with 10 classes, so you'll need a softmax output layer with 10 neurons. Remember to search for the right learning rate each time you change the model's architecture or hyperparameters.*

# %% [markdown]
# Let's add the output layer to the model:

# %%
model.add(tf.keras.layers.Dense(10, activation="softmax"))

# %% [markdown]
# Let's use a Nadam optimizer with a learning rate of 5e-5. I tried learning rates 1e-5, 3e-5, 1e-4, 3e-4, 1e-3, 3e-3 and 1e-2, and I compared their learning curves for 10 epochs each (using the TensorBoard callback, below). The learning rates 3e-5 and 1e-4 were pretty good, so I tried 5e-5, which turned out to be slightly better.

# %%
optimizer = tf.keras.optimizers.Nadam(learning_rate=5e-5)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

# %% [markdown]
# Let's load the CIFAR10 dataset. We also want to use early stopping, so we need a validation set. Let's use the first 5,000 images of the original training set as the validation set:

# %%
cifar10 = tf.keras.datasets.cifar10.load_data()
(X_train_full, y_train_full), (X_test, y_test) = cifar10

X_train = X_train_full[5000:]
y_train = y_train_full[5000:]
X_valid = X_train_full[:5000]
y_valid = y_train_full[:5000]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 138s 1us/step

# %% [markdown]
# Now we can create the callbacks we need and train the model:

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=20,
                                                     restore_best_weights=True)
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("my_cifar10_model",
                                                         save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = Path() / "my_cifar10_logs" / f"run_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./my_cifar10_logs
# Out:
#       <iframe id="tensorboard-frame-366a6040fb904c42" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-366a6040fb904c42");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model.fit(X_train, y_train, epochs=100,
          validation_data=(X_valid, y_valid),
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 3.5255 - accuracy: 0.1663INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 13s 7ms/step - loss: 3.5162 - accuracy: 0.1666 - val_loss: 2.1528 - val_accuracy: 0.2176
# Epoch 2/100
# 1400/1407 [============================>.] - ETA: 0s - loss: 2.0461 - accuracy: 0.2454INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 9s 7ms/step - loss: 2.0458 - accuracy: 0.2454 - val_loss: 2.0778 - val_accuracy: 0.2194
# Epoch 3/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 1.9426 - accuracy: 0.2820INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.9424 - accuracy: 0.2821 - val_loss: 1.9471 - val_accuracy: 0.2828
# Epoch 4/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 1.8721 - accuracy: 0.3146INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.8721 - accuracy: 0.3146 - val_loss: 1.9401 - val_accuracy: 0.3030
# Epoch 5/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.8148 - accuracy: 0.3376INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.8147 - accuracy: 0.3378 - val_loss: 1.7961 - val_accuracy: 0.3376
# Epoch 6/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 1.7604 - accuracy: 0.3616INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.7605 - accuracy: 0.3616 - val_loss: 1.7641 - val_accuracy: 0.3608
# Epoch 7/100
# 1398/1407 [============================>.] - ETA: 0s - loss: 1.7140 - accuracy: 0.3786INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.7139 - accuracy: 0.3787 - val_loss: 1.7049 - val_accuracy: 0.3726
# Epoch 8/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 1.6781 - accuracy: 0.3936INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.6781 - accuracy: 0.3936 - val_loss: 1.6647 - val_accuracy: 0.3960
# Epoch 9/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.6461 - accuracy: 0.4080 - val_loss: 1.7108 - val_accuracy: 0.3788
# Epoch 10/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.6246 - accuracy: 0.4143 - val_loss: 1.6914 - val_accuracy: 0.3850
# Epoch 11/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.5989 - accuracy: 0.4224 - val_loss: 1.6992 - val_accuracy: 0.3790
# Epoch 12/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 1.5791 - accuracy: 0.4334INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5789 - accuracy: 0.4335 - val_loss: 1.6370 - val_accuracy: 0.4072
# Epoch 13/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.5563 - accuracy: 0.4387INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5561 - accuracy: 0.4387 - val_loss: 1.6362 - val_accuracy: 0.4114
# Epoch 14/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 1.5414 - accuracy: 0.4468INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 11s 7ms/step - loss: 1.5416 - accuracy: 0.4468 - val_loss: 1.6042 - val_accuracy: 0.4204
# Epoch 15/100
# 1398/1407 [============================>.] - ETA: 0s - loss: 1.5235 - accuracy: 0.4541INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5237 - accuracy: 0.4541 - val_loss: 1.5848 - val_accuracy: 0.4260
# Epoch 16/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 1.5066 - accuracy: 0.4578INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5067 - accuracy: 0.4578 - val_loss: 1.5623 - val_accuracy: 0.4412
# Epoch 17/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4917 - accuracy: 0.4648 - val_loss: 1.5729 - val_accuracy: 0.4352
# Epoch 18/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 1.4800 - accuracy: 0.4700INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4800 - accuracy: 0.4699 - val_loss: 1.5566 - val_accuracy: 0.4400
# Epoch 19/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4670 - accuracy: 0.4747 - val_loss: 1.6052 - val_accuracy: 0.4304
# Epoch 20/100
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.4523 - accuracy: 0.4784 - val_loss: 1.6251 - val_accuracy: 0.4236
# Epoch 21/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4423 - accuracy: 0.4816 - val_loss: 1.5606 - val_accuracy: 0.4418
# Epoch 22/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 1.4329 - accuracy: 0.4847INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.4334 - accuracy: 0.4846 - val_loss: 1.5459 - val_accuracy: 0.4484
# Epoch 23/100
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.4175 - accuracy: 0.4932 - val_loss: 1.5781 - val_accuracy: 0.4334
# Epoch 24/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4074 - accuracy: 0.4955 - val_loss: 1.5757 - val_accuracy: 0.4410
# Epoch 25/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.3970 - accuracy: 0.4959INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3967 - accuracy: 0.4961 - val_loss: 1.5314 - val_accuracy: 0.4596
# Epoch 26/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3861 - accuracy: 0.5027 - val_loss: 1.6023 - val_accuracy: 0.4286
# Epoch 27/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 1.3775 - accuracy: 0.5047INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.3769 - accuracy: 0.5049 - val_loss: 1.5213 - val_accuracy: 0.4576
# Epoch 28/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3674 - accuracy: 0.5086 - val_loss: 1.5354 - val_accuracy: 0.4538
# Epoch 29/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3595 - accuracy: 0.5104 - val_loss: 1.5399 - val_accuracy: 0.4598
# Epoch 30/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3501 - accuracy: 0.5148 - val_loss: 1.5836 - val_accuracy: 0.4522
# Epoch 31/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3404 - accuracy: 0.5185 - val_loss: 1.5605 - val_accuracy: 0.4490
# Epoch 32/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3319 - accuracy: 0.5234 - val_loss: 1.5379 - val_accuracy: 0.4568
# Epoch 33/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3213 - accuracy: 0.5257 - val_loss: 1.5414 - val_accuracy: 0.4584
# Epoch 34/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3174 - accuracy: 0.5283 - val_loss: 1.5358 - val_accuracy: 0.4654
# Epoch 35/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.3079 - accuracy: 0.5306INFO:tensorflow:Assets written to: my_cifar10_model/assets
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3078 - accuracy: 0.5306 - val_loss: 1.5039 - val_accuracy: 0.4742
# Epoch 36/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2995 - accuracy: 0.5346 - val_loss: 1.5507 - val_accuracy: 0.4572
# Epoch 37/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2905 - accuracy: 0.5384 - val_loss: 1.5209 - val_accuracy: 0.4702
# Epoch 38/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2853 - accuracy: 0.5380 - val_loss: 1.5343 - val_accuracy: 0.4690
# Epoch 39/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2764 - accuracy: 0.5423 - val_loss: 1.5594 - val_accuracy: 0.4566
# Epoch 40/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2684 - accuracy: 0.5435 - val_loss: 1.5347 - val_accuracy: 0.4616
# Epoch 41/100
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.2636 - accuracy: 0.5473 - val_loss: 1.5560 - val_accuracy: 0.4616
# Epoch 42/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2542 - accuracy: 0.5498 - val_loss: 1.5441 - val_accuracy: 0.4664
# Epoch 43/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2470 - accuracy: 0.5508 - val_loss: 1.5754 - val_accuracy: 0.4514
# Epoch 44/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2406 - accuracy: 0.5559 - val_loss: 1.5691 - val_accuracy: 0.4632
# Epoch 45/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2309 - accuracy: 0.5605 - val_loss: 1.5216 - val_accuracy: 0.4686
# Epoch 46/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2245 - accuracy: 0.5593 - val_loss: 1.5252 - val_accuracy: 0.4802
# Epoch 47/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2177 - accuracy: 0.5625 - val_loss: 1.5230 - val_accuracy: 0.4728
# Epoch 48/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2157 - accuracy: 0.5661 - val_loss: 1.5394 - val_accuracy: 0.4668
# Epoch 49/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2028 - accuracy: 0.5670 - val_loss: 1.5498 - val_accuracy: 0.4670
# Epoch 50/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1988 - accuracy: 0.5701 - val_loss: 1.5345 - val_accuracy: 0.4692
# Epoch 51/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1901 - accuracy: 0.5722 - val_loss: 1.6011 - val_accuracy: 0.4624
# Epoch 52/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1825 - accuracy: 0.5785 - val_loss: 1.5637 - val_accuracy: 0.4726
# Epoch 53/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1763 - accuracy: 0.5777 - val_loss: 1.5415 - val_accuracy: 0.4760
# Epoch 54/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1684 - accuracy: 0.5819 - val_loss: 1.5624 - val_accuracy: 0.4674
# Epoch 55/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1644 - accuracy: 0.5822 - val_loss: 1.5840 - val_accuracy: 0.4682

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 157/157 [==============================] - 0s 2ms/step - loss: 1.5039 - accuracy: 0.4742
# [1.5038809776306152, 0.4742000102996826]

# %% [markdown]
# The model with the lowest validation loss gets about 46.8% accuracy on the validation set. It took 29 epochs to reach the lowest validation loss, with roughly 10 seconds per epoch on my laptop (without a GPU). Let's see if we can improve the model using Batch Normalization.

# %% [markdown]
# ### c.
# *Exercise: Now try adding Batch Normalization and compare the learning curves: Is it converging faster than before? Does it produce a better model? How does it affect training speed?*

# %% [markdown]
# The code below is very similar to the code above, with a few changes:
#
# * I added a BN layer after every Dense layer (before the activation function), except for the output layer.
# * I changed the learning rate to 5e-4. I experimented with 1e-5, 3e-5, 5e-5, 1e-4, 3e-4, 5e-4, 1e-3 and 3e-3, and I chose the one with the best validation performance after 20 epochs.
# * I renamed the run directories to run_bn_* and the model file name to `my_cifar10_bn_model`.

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100, kernel_initializer="he_normal"))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation("swish"))

model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.Nadam(learning_rate=5e-4)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=20,
                                                     restore_best_weights=True)
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("my_cifar10_bn_model",
                                                         save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = Path() / "my_cifar10_logs" / f"run_bn_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

model.fit(X_train, y_train, epochs=100,
          validation_data=(X_valid, y_valid),
          callbacks=callbacks)

model.evaluate(X_valid, y_valid)
# Out:
# Epoch 1/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 2.0556 - accuracy: 0.2443INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 24s 12ms/step - loss: 2.0556 - accuracy: 0.2443 - val_loss: 1.9155 - val_accuracy: 0.3032
# Epoch 2/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.7914 - accuracy: 0.3537 - val_loss: 2.0414 - val_accuracy: 0.2788
# Epoch 3/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.6882 - accuracy: 0.3978INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.6882 - accuracy: 0.3978 - val_loss: 1.8791 - val_accuracy: 0.3148
# Epoch 4/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.6200 - accuracy: 0.4223INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.6203 - accuracy: 0.4224 - val_loss: 1.7319 - val_accuracy: 0.3880
# Epoch 5/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5579 - accuracy: 0.4482 - val_loss: 1.9397 - val_accuracy: 0.3348
# Epoch 6/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 1.5121 - accuracy: 0.4631INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.5123 - accuracy: 0.4630 - val_loss: 1.6438 - val_accuracy: 0.4134
# Epoch 7/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4642 - accuracy: 0.4803 - val_loss: 1.6869 - val_accuracy: 0.4028
# Epoch 8/100
# 1407/1407 [==============================] - ETA: 0s - loss: 1.4231 - accuracy: 0.4967INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.4231 - accuracy: 0.4967 - val_loss: 1.5685 - val_accuracy: 0.4526
# Epoch 9/100
# 1407/1407 [==============================] - ETA: 0s - loss: 1.3948 - accuracy: 0.5087INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.3948 - accuracy: 0.5087 - val_loss: 1.5336 - val_accuracy: 0.4608
# Epoch 10/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 1.3594 - accuracy: 0.5187INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.3593 - accuracy: 0.5188 - val_loss: 1.5021 - val_accuracy: 0.4602
# Epoch 11/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.3320 - accuracy: 0.5294INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.3320 - accuracy: 0.5294 - val_loss: 1.4677 - val_accuracy: 0.4900
# Epoch 12/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.2997 - accuracy: 0.5438 - val_loss: 1.6915 - val_accuracy: 0.4150
# Epoch 13/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.2733 - accuracy: 0.5526 - val_loss: 1.5244 - val_accuracy: 0.4742
# Epoch 14/100
# 1407/1407 [==============================] - ETA: 0s - loss: 1.2492 - accuracy: 0.5588INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.2492 - accuracy: 0.5588 - val_loss: 1.4612 - val_accuracy: 0.4942
# Epoch 15/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.2235 - accuracy: 0.5709 - val_loss: 1.6263 - val_accuracy: 0.4710
# Epoch 16/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.2105 - accuracy: 0.5744 - val_loss: 1.4914 - val_accuracy: 0.4872
# Epoch 17/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 1.1905 - accuracy: 0.5829INFO:tensorflow:Assets written to: my_cifar10_bn_model/assets
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.1906 - accuracy: 0.5828 - val_loss: 1.3981 - val_accuracy: 0.5126
# Epoch 18/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.1698 - accuracy: 0.5887 - val_loss: 1.6549 - val_accuracy: 0.4438
# Epoch 19/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.1548 - accuracy: 0.5991 - val_loss: 1.5356 - val_accuracy: 0.4852
# Epoch 20/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.1342 - accuracy: 0.6036 - val_loss: 1.4682 - val_accuracy: 0.4996
# Epoch 21/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.1214 - accuracy: 0.6065 - val_loss: 1.6138 - val_accuracy: 0.4594
# Epoch 22/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.1014 - accuracy: 0.6133 - val_loss: 1.4138 - val_accuracy: 0.5108
# Epoch 23/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.0868 - accuracy: 0.6211 - val_loss: 1.4642 - val_accuracy: 0.5066
# Epoch 24/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.0710 - accuracy: 0.6258 - val_loss: 1.5450 - val_accuracy: 0.4896
# Epoch 25/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.0607 - accuracy: 0.6303 - val_loss: 1.6419 - val_accuracy: 0.4568
# Epoch 26/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.0454 - accuracy: 0.6334 - val_loss: 1.4746 - val_accuracy: 0.5058
# Epoch 27/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.0287 - accuracy: 0.6393 - val_loss: 1.4720 - val_accuracy: 0.4990
# Epoch 28/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.0255 - accuracy: 0.6412 - val_loss: 1.6544 - val_accuracy: 0.4634
# Epoch 29/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.0119 - accuracy: 0.6440 - val_loss: 1.4520 - val_accuracy: 0.5200
# Epoch 30/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.0015 - accuracy: 0.6504 - val_loss: 1.6201 - val_accuracy: 0.4858
# Epoch 31/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.9799 - accuracy: 0.6567 - val_loss: 1.5282 - val_accuracy: 0.4966
# Epoch 32/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.9744 - accuracy: 0.6580 - val_loss: 1.7133 - val_accuracy: 0.4528
# Epoch 33/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.9596 - accuracy: 0.6661 - val_loss: 1.5422 - val_accuracy: 0.4960
# Epoch 34/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.9525 - accuracy: 0.6667 - val_loss: 1.6465 - val_accuracy: 0.4812
# Epoch 35/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.9392 - accuracy: 0.6701 - val_loss: 1.5699 - val_accuracy: 0.4934
# Epoch 36/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.9390 - accuracy: 0.6732 - val_loss: 1.6308 - val_accuracy: 0.4978
# Epoch 37/100
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.9161 - accuracy: 0.6785 - val_loss: 1.7920 - val_accuracy: 0.4482
# 157/157 [==============================] - 0s 2ms/step - loss: 1.3981 - accuracy: 0.5126
# [1.3980835676193237, 0.5126000046730042]

# %% [markdown]
# * *Is the model converging faster than before?* Much faster! The previous model took 29 epochs to reach the lowest validation loss, while the new model achieved that same loss in just 12 epochs and continued to make progress until the 17th epoch. The BN layers stabilized training and allowed us to use a much larger learning rate, so convergence was faster.
# * *Does BN produce a better model?* Yes! The final model is also much better, with 50.7% validation accuracy instead of 46.7%. It's still not a very good model, but at least it's much better than before (a Convolutional Neural Network would do much better, but that's a different topic, see chapter 14).
# * *How does BN affect training speed?* Although the model converged much faster, each epoch took about 15s instead of 10s, because of the extra computations required by the BN layers. But overall the training time (wall time) to reach the best model was shortened by about 10%.

# %% [markdown]
# ### d.
# *Exercise: Try replacing Batch Normalization with SELU, and make the necessary adjustements to ensure the network self-normalizes (i.e., standardize the input features, use LeCun normal initialization, make sure the DNN contains only a sequence of dense layers, etc.).*

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                    kernel_initializer="lecun_normal",
                                    activation="selu"))

model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.Nadam(learning_rate=7e-4)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    patience=20, restore_best_weights=True)
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    "my_cifar10_selu_model", save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = Path() / "my_cifar10_logs" / f"run_selu_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

X_means = X_train.mean(axis=0)
X_stds = X_train.std(axis=0)
X_train_scaled = (X_train - X_means) / X_stds
X_valid_scaled = (X_valid - X_means) / X_stds
X_test_scaled = (X_test - X_means) / X_stds

model.fit(X_train_scaled, y_train, epochs=100,
          validation_data=(X_valid_scaled, y_valid),
          callbacks=callbacks)

model.evaluate(X_valid_scaled, y_valid)
# Out:
# Epoch 1/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 1.9214 - accuracy: 0.3134INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 11s 6ms/step - loss: 1.9212 - accuracy: 0.3134 - val_loss: 1.8340 - val_accuracy: 0.3312
# Epoch 2/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 1.7069 - accuracy: 0.3946INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.7070 - accuracy: 0.3947 - val_loss: 1.7389 - val_accuracy: 0.3542
# Epoch 3/100
# 1398/1407 [============================>.] - ETA: 0s - loss: 1.6188 - accuracy: 0.4280INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.6185 - accuracy: 0.4282 - val_loss: 1.6569 - val_accuracy: 0.4182
# Epoch 4/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 1.5465 - accuracy: 0.4527INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.5466 - accuracy: 0.4527 - val_loss: 1.6474 - val_accuracy: 0.4226
# Epoch 5/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 1.4930 - accuracy: 0.4753INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4931 - accuracy: 0.4751 - val_loss: 1.5731 - val_accuracy: 0.4474
# Epoch 6/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 1.4484 - accuracy: 0.4934INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.4482 - accuracy: 0.4934 - val_loss: 1.5114 - val_accuracy: 0.4656
# Epoch 7/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 1.4022 - accuracy: 0.5099 - val_loss: 1.5150 - val_accuracy: 0.4712
# Epoch 8/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 1.3570 - accuracy: 0.5261INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3569 - accuracy: 0.5260 - val_loss: 1.4778 - val_accuracy: 0.4836
# Epoch 9/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 1.3260 - accuracy: 0.5397INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3260 - accuracy: 0.5397 - val_loss: 1.4678 - val_accuracy: 0.4836
# Epoch 10/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2894 - accuracy: 0.5522 - val_loss: 1.4771 - val_accuracy: 0.5016
# Epoch 11/100
# 1407/1407 [==============================] - 6s 5ms/step - loss: 1.2599 - accuracy: 0.5618 - val_loss: 1.5208 - val_accuracy: 0.4720
# Epoch 12/100
# 1407/1407 [==============================] - 6s 5ms/step - loss: 1.2319 - accuracy: 0.5686 - val_loss: 1.4752 - val_accuracy: 0.4962
# Epoch 13/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 1.2040 - accuracy: 0.5841INFO:tensorflow:Assets written to: my_cifar10_selu_model/assets
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2039 - accuracy: 0.5841 - val_loss: 1.4626 - val_accuracy: 0.5054
# Epoch 14/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1785 - accuracy: 0.5910 - val_loss: 1.4652 - val_accuracy: 0.5002
# Epoch 15/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1500 - accuracy: 0.5999 - val_loss: 1.5010 - val_accuracy: 0.4978
# Epoch 16/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1235 - accuracy: 0.6129 - val_loss: 1.5176 - val_accuracy: 0.5040
# Epoch 17/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.0975 - accuracy: 0.6209 - val_loss: 1.5063 - val_accuracy: 0.5018
# Epoch 18/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.0810 - accuracy: 0.6275 - val_loss: 1.4855 - val_accuracy: 0.5030
# Epoch 19/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.0642 - accuracy: 0.6326 - val_loss: 1.5460 - val_accuracy: 0.5104
# Epoch 20/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.9742 - accuracy: 0.5032 - val_loss: 1.5706 - val_accuracy: 0.4624
# Epoch 21/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2990 - accuracy: 0.5414 - val_loss: 1.5532 - val_accuracy: 0.4632
# Epoch 22/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2221 - accuracy: 0.5671 - val_loss: 1.5083 - val_accuracy: 0.4902
# Epoch 23/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1338 - accuracy: 0.5999 - val_loss: 1.5031 - val_accuracy: 0.5008
# Epoch 24/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.3569 - accuracy: 0.5854 - val_loss: 1.5006 - val_accuracy: 0.4952
# Epoch 25/100
# 1407/1407 [==============================] - 6s 5ms/step - loss: 1.1238 - accuracy: 0.6057 - val_loss: 1.4887 - val_accuracy: 0.5000
# Epoch 26/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.0840 - accuracy: 0.6203 - val_loss: 1.5241 - val_accuracy: 0.5022
# Epoch 27/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 1.0520 - accuracy: 0.6317 - val_loss: 1.4812 - val_accuracy: 0.5224
# Epoch 28/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 1.0326 - accuracy: 0.6416 - val_loss: 1.5311 - val_accuracy: 0.5034
# Epoch 29/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 1.0124 - accuracy: 0.6493 - val_loss: 1.5785 - val_accuracy: 0.5068
# Epoch 30/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.9973 - accuracy: 0.6545 - val_loss: 1.5630 - val_accuracy: 0.5072
# Epoch 31/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.9773 - accuracy: 0.6623 - val_loss: 1.5387 - val_accuracy: 0.5096
# Epoch 32/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.9667 - accuracy: 0.6673 - val_loss: 1.5693 - val_accuracy: 0.5160
# Epoch 33/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.9580 - accuracy: 0.6713 - val_loss: 1.5282 - val_accuracy: 0.5130
# 157/157 [==============================] - 0s 2ms/step - loss: 1.4626 - accuracy: 0.5054
# [1.4625576734542847, 0.5054000020027161]

# %% [markdown]
# This model reached the first model's validation loss in just 8 epochs. After 14 epochs, it reached its lowest validation loss, with about 50.3% accuracy, which is better than the original model (46.7%), but not quite as good as the model using batch normalization (50.7%). Each epoch took only 9 seconds. So it's the fastest model to train so far.

# %% [markdown]
# ### e.
# *Exercise: Try regularizing the model with alpha dropout. Then, without retraining your model, see if you can achieve better accuracy using MC Dropout.*

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                    kernel_initializer="lecun_normal",
                                    activation="selu"))

model.add(tf.keras.layers.AlphaDropout(rate=0.1))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.Nadam(learning_rate=5e-4)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    patience=20, restore_best_weights=True)
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    "my_cifar10_alpha_dropout_model", save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = Path() / "my_cifar10_logs" / f"run_alpha_dropout_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

X_means = X_train.mean(axis=0)
X_stds = X_train.std(axis=0)
X_train_scaled = (X_train - X_means) / X_stds
X_valid_scaled = (X_valid - X_means) / X_stds
X_test_scaled = (X_test - X_means) / X_stds

model.fit(X_train_scaled, y_train, epochs=100,
          validation_data=(X_valid_scaled, y_valid),
          callbacks=callbacks)

model.evaluate(X_valid_scaled, y_valid)
# Out:
# Epoch 1/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 1.8871 - accuracy: 0.3286INFO:tensorflow:Assets written to: my_cifar10_alpha_dropout_model/assets
# 1407/1407 [==============================] - 11s 7ms/step - loss: 1.8865 - accuracy: 0.3288 - val_loss: 1.7216 - val_accuracy: 0.4120
# Epoch 2/100
# 1398/1407 [============================>.] - ETA: 0s - loss: 1.6633 - accuracy: 0.4165INFO:tensorflow:Assets written to: my_cifar10_alpha_dropout_model/assets
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.6636 - accuracy: 0.4164 - val_loss: 1.6908 - val_accuracy: 0.3984
# Epoch 3/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 1.5731 - accuracy: 0.4487INFO:tensorflow:Assets written to: my_cifar10_alpha_dropout_model/assets
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.5729 - accuracy: 0.4488 - val_loss: 1.6560 - val_accuracy: 0.4244
# Epoch 4/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 1.5068 - accuracy: 0.4701INFO:tensorflow:Assets written to: my_cifar10_alpha_dropout_model/assets
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.5070 - accuracy: 0.4701 - val_loss: 1.6123 - val_accuracy: 0.4458
# Epoch 5/100
# 1407/1407 [==============================] - ETA: 0s - loss: 1.4504 - accuracy: 0.4939INFO:tensorflow:Assets written to: my_cifar10_alpha_dropout_model/assets
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4504 - accuracy: 0.4939 - val_loss: 1.5578 - val_accuracy: 0.4530
# Epoch 6/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 1.4008 - accuracy: 0.5117INFO:tensorflow:Assets written to: my_cifar10_alpha_dropout_model/assets
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.4009 - accuracy: 0.5117 - val_loss: 1.5153 - val_accuracy: 0.4794
# Epoch 7/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3562 - accuracy: 0.5287 - val_loss: 1.5322 - val_accuracy: 0.4832
# Epoch 8/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 1.3153 - accuracy: 0.5421INFO:tensorflow:Assets written to: my_cifar10_alpha_dropout_model/assets
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.3153 - accuracy: 0.5419 - val_loss: 1.4876 - val_accuracy: 0.4930
# Epoch 9/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2857 - accuracy: 0.5569 - val_loss: 1.5307 - val_accuracy: 0.4784
# Epoch 10/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2531 - accuracy: 0.5660 - val_loss: 1.5159 - val_accuracy: 0.4992
# Epoch 11/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2217 - accuracy: 0.5804 - val_loss: 1.5545 - val_accuracy: 0.4998
# Epoch 12/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1907 - accuracy: 0.5895 - val_loss: 1.5361 - val_accuracy: 0.4996
# Epoch 13/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1577 - accuracy: 0.6017 - val_loss: 1.5393 - val_accuracy: 0.4988
# Epoch 14/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1397 - accuracy: 0.6084 - val_loss: 1.5481 - val_accuracy: 0.5132
# Epoch 15/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1113 - accuracy: 0.6177 - val_loss: 1.5341 - val_accuracy: 0.5152
# Epoch 16/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.0880 - accuracy: 0.6273 - val_loss: 1.5954 - val_accuracy: 0.5160
# Epoch 17/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.0687 - accuracy: 0.6330 - val_loss: 1.5533 - val_accuracy: 0.5058
# Epoch 18/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.0374 - accuracy: 0.6459 - val_loss: 1.5922 - val_accuracy: 0.5174
# Epoch 19/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.0191 - accuracy: 0.6520 - val_loss: 1.6999 - val_accuracy: 0.5154
# Epoch 20/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.0045 - accuracy: 0.6568 - val_loss: 1.7489 - val_accuracy: 0.5030
# Epoch 21/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.9755 - accuracy: 0.6655 - val_loss: 1.7109 - val_accuracy: 0.4982
# Epoch 22/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.9650 - accuracy: 0.6717 - val_loss: 1.7778 - val_accuracy: 0.5132
# Epoch 23/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.9358 - accuracy: 0.6821 - val_loss: 1.6848 - val_accuracy: 0.5136
# Epoch 24/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.9212 - accuracy: 0.6868 - val_loss: 1.8121 - val_accuracy: 0.5118
# Epoch 25/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.9110 - accuracy: 0.6908 - val_loss: 1.7382 - val_accuracy: 0.5178
# Epoch 26/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.8954 - accuracy: 0.6984 - val_loss: 1.7594 - val_accuracy: 0.5072
# Epoch 27/100
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.8852 - accuracy: 0.7026 - val_loss: 1.7770 - val_accuracy: 0.5134
# Epoch 28/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.8688 - accuracy: 0.7075 - val_loss: 1.7912 - val_accuracy: 0.5152
# 157/157 [==============================] - 0s 2ms/step - loss: 1.4876 - accuracy: 0.4930
# [1.487607479095459, 0.49300000071525574]

# %% [markdown]
# The model reaches 48.1% accuracy on the validation set. That's worse than without dropout (50.3%). With an extensive hyperparameter search, it might be possible to do better (I tried dropout rates of 5%, 10%, 20% and 40%, and learning rates 1e-4, 3e-4, 5e-4, and 1e-3), but probably not much better in this case.

# %% [markdown]
# Let's use MC Dropout now. We will need the `MCAlphaDropout` class we used earlier, so let's just copy it here for convenience:

# %%
class MCAlphaDropout(tf.keras.layers.AlphaDropout):
    def call(self, inputs):
        return super().call(inputs, training=True)

# %% [markdown]
# Now let's create a new model, identical to the one we just trained (with the same weights), but with `MCAlphaDropout` dropout layers instead of `AlphaDropout` layers:

# %%
mc_model = tf.keras.Sequential([
    (
        MCAlphaDropout(layer.rate)
        if isinstance(layer, tf.keras.layers.AlphaDropout)
        else layer
    )
    for layer in model.layers
])

# %% [markdown]
# Then let's add a couple utility functions. The first will run the model many times (10 by default) and it will return the mean predicted class probabilities. The second will use these mean probabilities to predict the most likely class for each instance:

# %%
def mc_dropout_predict_probas(mc_model, X, n_samples=10):
    Y_probas = [mc_model.predict(X) for sample in range(n_samples)]
    return np.mean(Y_probas, axis=0)

def mc_dropout_predict_classes(mc_model, X, n_samples=10):
    Y_probas = mc_dropout_predict_probas(mc_model, X, n_samples)
    return Y_probas.argmax(axis=1)

# %% [markdown]
# Now let's make predictions for all the instances in the validation set, and compute the accuracy:

# %%
tf.random.set_seed(42)

y_pred = mc_dropout_predict_classes(mc_model, X_valid_scaled)
accuracy = (y_pred == y_valid[:, 0]).mean()
accuracy
# Out:
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 0.4928

# %% [markdown]
# We get back to roughly the accuracy of the model without dropout in this case (about 50.3% accuracy).
#
# So the best model we got in this exercise is the Batch Normalization model.

# %% [markdown]
# ### f.
# *Exercise: Retrain your model using 1cycle scheduling and see if it improves training speed and model accuracy.*

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                    kernel_initializer="lecun_normal",
                                    activation="selu"))

model.add(tf.keras.layers.AlphaDropout(rate=0.1))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.SGD()
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

# %%
batch_size = 128
rates, losses = find_learning_rate(model, X_train_scaled, y_train, epochs=1,
                                   batch_size=batch_size)
plot_lr_vs_loss(rates, losses)
# Out:
# 352/352 [==============================] - 2s 5ms/step - loss: nan - accuracy: 0.1822

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                 kernel_initializer="lecun_normal",
                                 activation="selu"))

model.add(tf.keras.layers.AlphaDropout(rate=0.1))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.SGD(learning_rate=2e-2)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

# %%
n_epochs = 15
n_iterations = math.ceil(len(X_train_scaled) / batch_size) * n_epochs
onecycle = OneCycleScheduler(n_iterations, max_lr=0.05)
history = model.fit(X_train_scaled, y_train, epochs=n_epochs, batch_size=batch_size,
                    validation_data=(X_valid_scaled, y_valid),
                    callbacks=[onecycle])
# Out:
# Epoch 1/15
# 352/352 [==============================] - 3s 6ms/step - loss: 2.0622 - accuracy: 0.2798 - val_loss: 1.8266 - val_accuracy: 0.3792
# Epoch 2/15
# 352/352 [==============================] - 2s 5ms/step - loss: 1.7448 - accuracy: 0.3841 - val_loss: 1.7162 - val_accuracy: 0.3996
# Epoch 3/15
# 352/352 [==============================] - 2s 5ms/step - loss: 1.6154 - accuracy: 0.4272 - val_loss: 1.6635 - val_accuracy: 0.4062
# Epoch 4/15
# 352/352 [==============================] - 2s 5ms/step - loss: 1.5387 - accuracy: 0.4531 - val_loss: 1.6501 - val_accuracy: 0.4400
# Epoch 5/15
# 352/352 [==============================] - 2s 5ms/step - loss: 1.4965 - accuracy: 0.4702 - val_loss: 1.5914 - val_accuracy: 0.4454
# Epoch 6/15
# 352/352 [==============================] - 2s 5ms/step - loss: 1.4546 - accuracy: 0.4825 - val_loss: 1.6672 - val_accuracy: 0.4300
# Epoch 7/15
# 352/352 [==============================] - 2s 5ms/step - loss: 1.4206 - accuracy: 0.4990 - val_loss: 1.5737 - val_accuracy: 0.4666
# Epoch 8/15
# 352/352 [==============================] - 2s 5ms/step - loss: 1.3515 - accuracy: 0.5223 - val_loss: 1.5137 - val_accuracy: 0.4832
# Epoch 9/15
# 352/352 [==============================] - 2s 5ms/step - loss: 1.2786 - accuracy: 0.5463 - val_loss: 1.5074 - val_accuracy: 0.4840
# Epoch 10/15
# 352/352 [==============================] - 2s 5ms/step - loss: 1.2056 - accuracy: 0.5704 - val_loss: 1.5458 - val_accuracy: 0.4978
# Epoch 11/15
# 352/352 [==============================] - 2s 5ms/step - loss: 1.1359 - accuracy: 0.5952 - val_loss: 1.5059 - val_accuracy: 0.5054
# Epoch 12/15
# 352/352 [==============================] - 2s 5ms/step - loss: 1.0677 - accuracy: 0.6181 - val_loss: 1.5090 - val_accuracy: 0.5092
# Epoch 13/15
# 352/352 [==============================] - 2s 5ms/step - loss: 1.0007 - accuracy: 0.6421 - val_loss: 1.5255 - val_accuracy: 0.5210
# Epoch 14/15
# 352/352 [==============================] - 2s 5ms/step - loss: 0.9348 - accuracy: 0.6661 - val_loss: 1.5447 - val_accuracy: 0.5232
# Epoch 15/15
# 352/352 [==============================] - 2s 5ms/step - loss: 0.8959 - accuracy: 0.6792 - val_loss: 1.5730 - val_accuracy: 0.5212

# %% [markdown]
# One cycle allowed us to train the model in just 15 epochs, each taking only 2 seconds (thanks to the larger batch size). This is several times faster than the fastest model we trained so far. Moreover, we improved the model's performance (from 50.7% to 52.0%).

# %%
endTime = time.time()

elapsedTime = time.strftime("%H:%M:%S", time.gmtime(endTime - startTime))

print(todaysDate.strftime('# Run Date: %A, %B %d, %Y'))
print(f"# Run Time: {elapsedTime}")
# Out:
# # Run Date: Wednesday, February 08, 2023
# # Run Time: 00:36:29
